# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from Class.Helper import Helper as Helper
helper = Helper()
import pickle

# %%
import os

for dataset_file in os.listdir("C:/Users/Adam/Documents/Studia/Magisterka/Projekt/Test - Datasets/Results"):
    print(dataset_file)
    if dataset_file[:-4] == "Blood":
        dataset_stats = helper.loadDatasetResults(dataset_file[:-4], "Test", -1, False).sort_values(by=["Gausses"])
    else:
        tmp = helper.loadDatasetResults(dataset_file[:-4], "Test", -1, False).sort_values(by=["Gausses"])
        dataset_stats = pd.concat([dataset_stats, tmp])

print(dataset_stats.shape)
display(dataset_stats.head())
# Out:
# Blood.csv
# Breast Cancer Data.csv
# Breast Cancer Wisconsin.csv
# Data Banknote Authentication.csv
# Haberman.csv
# Heart.csv
# HTRU.csv
# Immunotherapy.csv
# Indian Liver Patient.csv
# Ionosphere.csv
# Parkinson.csv
# Pima Indians Diabetes.csv
# Vertebral.csv
# (881, 22)
#                 Test type Dataset                 Style  Gausses Adjustment  \
# 15  Gauss Functions Style   Blood  Gaussian Progressive        3       Mean
# 7   Gauss Functions Style   Blood  Gaussian Progressive        3       Mean
# 9   Gauss Functions Style   Blood  Gaussian Progressive        3       Mean
# 11  Gauss Functions Style   Blood  Gaussian Progressive        3       Mean
# 13  Gauss Functions Style   Blood  Gaussian Progressive        3       Mean
#
#    Data Type          Operation  Accuracy  Precision A  Precision B  \
# 15      Test  Value S-Functions  0.271111      0.24537     0.888889
# 7       Test  Value S-Functions  0.271111      0.24537     0.888889
# ...

# %%
##### concated = pd.concat([julia, adam], axis=1)
# concated["Type"] = "Our"
# concated.reset_index(level=0, inplace=True)
columns = ["Dataset", "Mean F-Score", "Accuracy", "Type"]

concated = pd.DataFrame([["Breast Cancer Wisconsin", 0.973, 0.978, "Our Model"]], columns = 
                         columns)
concated = concated.append(pd.DataFrame([[
    "Pima Indians Diabetes", 0.723, 0.764, "Our Model"
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Vertebral", 0.871, 0.918, "Our Model"
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Haberman", 0.663, 0.763, "Our Model"
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Data Banknote Authentication", 0.999, 0.999, "Our Model"
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Immunotherapy", 0.762, 0.872, "Our Model"
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Parkinson", 0.903, 0.953, "Our Model"
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Indian Liver Patient", 0.723, 0.764, "Our Model"
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Blood", 0.634, 0.825, "Our Model"
]], columns = columns))

concated = concated.append(pd.DataFrame([[
    "HTRU", 0.920, 0.975, "Our Model"
]], columns = columns))

    
    
    

concated = concated.append(pd.DataFrame([[
    "Breast Cancer Wisconsin", 0.950, 0.956, "Takagi-Sugeno"
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Pima Indians Diabetes", 0.655, 0.701, "Takagi-Sugeno"
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Vertebral", 0.795, 0.822, "Takagi-Sugeno"
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Haberman", 0.710, 0.806, "Takagi-Sugeno"
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Data Banknote Authentication", 1.000, 1.000, "Takagi-Sugeno"
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Immunotherapy", 0.680, 0.777, "Takagi-Sugeno"
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "HTRU", 0.905, 0.968, "Takagi-Sugeno"
]], columns = columns))




concated = concated.append(pd.DataFrame([[
    "Blood", None, 0.7961, "NN + Opt." # 7867
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Breast Cancer Wisconsin", None, 0.9832, "NN + Opt." #9731
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Pima Indians Diabetes", None, 0.7977, "NN + Opt." #7584
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Vertebral", None, 0.9057, "NN + Opt." #8802
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Indian Liver Patient", None, 0.7458, "NN + Opt." #0.6958
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Parkinson", None, 0.8955, "NN + Opt." #8507
]], columns = columns))


concated = concated.append(pd.DataFrame([[
    "Blood", None, 0.8000, "FFNN Opt." # 7867
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Breast Cancer Wisconsin", None, 0.9832, "FFNN Opt." #9731
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Pima Indians Diabetes", None, 0.7901, "FFNN Opt." #7584
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Vertebral", None, 0.8868, "FFNN Opt." #8802
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Indian Liver Patient", None, 0.7881, "FFNN Opt." #0.6958
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Parkinson", None, 0.9851, "FFNN Opt." #8507
]], columns = columns))



#  SPRAWDZIĆ CZY BRAŁEM ŚREDNIĄ CZY MAKSYMALNĄ WARTOŚĆ
display(concated)

sns.set(style="darkgrid", font="Times New Roman", font_scale=1.08)
data_1 = concated.loc[concated["Dataset"].isin(["Breast Cancer Wisconsin", "Pima Indians Diabetes", "HTRU", 
                                                "Vertebral", "Haberman", "Data Banknote Authentication", "Immunotherapy"])]
data_1 = data_1.loc[data_1["Type"].isin(["Our Model", "Takagi-Sugeno"])]
g = sns.catplot(x="Dataset", y="Mean F-Score", hue="Type", data=data_1, kind="bar", palette="muted", legend=False, aspect=1.5)
g.despine(left=True)
plt.legend(bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower left", ncol=2)
g.set_ylabels("F1")
g.set_xlabels("")

g.set_xticklabels(rotation=20, ha="right")


data_2 = concated.loc[concated["Dataset"].isin(["Blood", "Breast Cancer Wisconsin", "Pima Indians Diabetes", "Vertebral", "Pima Indians", "Parkinson"])]
data_2 = data_2.loc[data_2["Type"].isin(["Our Model", "NN + Opt.", "FFNN Opt."])]
sns.set(style="darkgrid", font="Times New Roman", font_scale=1.08)
g = sns.catplot(x="Dataset", y="Accuracy", hue="Type", data=data_2, kind="bar", palette="muted", legend=False, aspect=1.5)
g.despine(left=True)
plt.legend(loc='lower left',  title="")
plt.legend(bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower left", ncol=3)
g.set_ylabels("Accuracy")
g.set_xlabels("")
g.set_xticklabels(rotation=20, ha="right")
plt.tight_layout()
plt.show()


print(data_1.sort_values(by=["Dataset"]).to_latex(float_format=lambda x: '%10.3f' % x, index=False))
print(data_2[["Dataset","Accuracy", "Type"]].sort_values(by=["Dataset"]).to_latex(float_format=lambda x: '%10.3f' % x, index=False))
# Out:
#                         Dataset Mean F-Score  Accuracy           Type
# 0       Breast Cancer Wisconsin        0.973    0.9780      Our Model
# 0         Pima Indians Diabetes        0.723    0.7640      Our Model
# 0                     Vertebral        0.871    0.9180      Our Model
# 0                      Haberman        0.663    0.7630      Our Model
# 0  Data Banknote Authentication        0.999    0.9990      Our Model
# 0                 Immunotherapy        0.762    0.8720      Our Model
# 0                     Parkinson        0.903    0.9530      Our Model
# 0          Indian Liver Patient        0.723    0.7640      Our Model
# 0                         Blood        0.634    0.8250      Our Model
# 0                          HTRU         0.92    0.9750      Our Model
# 0       Breast Cancer Wisconsin         0.95    0.9560  Takagi-Sugeno
# 0         Pima Indians Diabetes        0.655    0.7010  Takagi-Sugeno
# ...

# %%
##### concated = pd.concat([julia, adam], axis=1)
# concated["Type"] = "Our"
# concated.reset_index(level=0, inplace=True)
columns = ["Zbiór danych", "Model", "Dokładność"]

concated = pd.DataFrame([["Breast Cancer Wisconsin", "Nasz model", 0.978]], columns = columns)

concated = concated.append(pd.DataFrame([["Pima Indians Diabetes", "Nasz model", 0.764]], columns = columns))
concated = concated.append(pd.DataFrame([["Pima Indians Diabetes", "Takagi-Sugeno", 0.701]], columns = columns))
concated = concated.append(pd.DataFrame([["Pima Indians Diabetes", "NN + Opt.", 0.798]], columns = columns))
concated = concated.append(pd.DataFrame([["Pima Indians Diabetes", "FFNN Opt.", 0.790]], columns = columns))

# concated = concated.append(pd.DataFrame([["Breast Cancer Wisconsin", "Nasz model", 0.978]], columns = columns))
concated = concated.append(pd.DataFrame([["Breast Cancer Wisconsin", "Takagi-Sugeno", 0.956]], columns = columns))
concated = concated.append(pd.DataFrame([["Breast Cancer Wisconsin", "NN + Opt.", 0.983]], columns = columns))
concated = concated.append(pd.DataFrame([["Breast Cancer Wisconsin", "FFNN Opt.", 0.983]], columns = columns))

concated = concated.append(pd.DataFrame([["Vertebral", "Nasz model", 0.918]], columns = columns))
concated = concated.append(pd.DataFrame([["Vertebral", "Takagi-Sugeno", 0.822]], columns = columns))
concated = concated.append(pd.DataFrame([["Vertebral", "NN + Opt.", 0.906]], columns = columns))
concated = concated.append(pd.DataFrame([["Vertebral", "FFNN Opt.", 0.887]], columns = columns))


data_2 = concated
data_2 = data_2.loc[data_2["Model"].isin(["Nasz model", "Takagi-Sugeno", "NN + Opt.", "FFNN Opt."])]
sns.set(style="darkgrid", font="Times New Roman", font_scale=1.08)
g = sns.catplot(x="Zbiór danych", y="Dokładność", hue="Model", data=data_2, kind="bar", palette="muted", legend=False, aspect=1.5)
g.despine(left=True)
plt.legend(loc='lower left',  title="")
plt.legend(bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower left", ncol=4)
g.set_ylabels("Dokładność")
g.set_xlabels("")
# g.set_xticklabels(rotation=20, ha="right")
plt.tight_layout()
plt.show()


# print(data_1.sort_values(by=["Dataset"]).to_latex(float_format=lambda x: '%10.3f' % x, index=False))
print(data_2.to_latex(float_format=lambda x: '%10.3f' % x, index=False))
# Out:
# \begin{tabular}{llr}
# \toprule
#             Zbiór danych &          Model &  Dokładność \\
# \midrule
#  Breast Cancer Wisconsin &     Nasz model &       0.978 \\
#    Pima Indians Diabetes &     Nasz model &       0.764 \\
#    Pima Indians Diabetes &  Takagi-Sugeno &       0.701 \\
#    Pima Indians Diabetes &      NN + Opt. &       0.798 \\
#    Pima Indians Diabetes &      FFNN Opt. &       0.790 \\
#  Breast Cancer Wisconsin &  Takagi-Sugeno &       0.956 \\
#  Breast Cancer Wisconsin &      NN + Opt. &       0.983 \\
#  Breast Cancer Wisconsin &      FFNN Opt. &       0.983 \\
#                Vertebral &     Nasz model &       0.918 \\
#                Vertebral &  Takagi-Sugeno &       0.822 \\
#                Vertebral &      NN + Opt. &       0.906 \\
#                Vertebral &      FFNN Opt. &       0.887 \\
# \bottomrule
# \end{tabular}

# %%
##### concated = pd.concat([julia, adam], axis=1)
# concated["Type"] = "Our"
# concated.reset_index(level=0, inplace=True)
columns = ["Zbiór danych", "Model", "F1"]

concated = pd.DataFrame([["Breast Cancer Wisconsin", "Brak optymalizacji", 0.941]], columns = columns)

concated = concated.append(pd.DataFrame([["Pima Indians Diabetes", "Brak optymalizacji", 0.483]], columns = columns))
concated = concated.append(pd.DataFrame([["Pima Indians Diabetes", "Z optymalizacją", 0.694]], columns = columns))

concated = concated.append(pd.DataFrame([["Breast Cancer Wisconsin", "Z optymalizacją", 0.941]], columns = columns))

concated = concated.append(pd.DataFrame([["Vertebral", "Brak optymalizacji", 0.632]], columns = columns))
concated = concated.append(pd.DataFrame([["Vertebral", "Z optymalizacją", 0.843]], columns = columns))


data_2 = concated
data_2 = data_2.loc[data_2["Model"].isin(["Brak optymalizacji", "Z optymalizacją"])]
sns.set(style="darkgrid", font="Times New Roman", font_scale=1.08)
g = sns.catplot(x="Zbiór danych", y="F1", hue="Model", data=data_2, kind="bar", palette="muted", legend=False, aspect=1.5)
g.despine(left=True)
plt.legend(loc='lower left',  title="")
plt.legend(bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower left", ncol=4)
g.set_ylabels("F1")
g.set_xlabels("")
# g.set_xticklabels(rotation=20, ha="right")
plt.tight_layout()
plt.show()


# print(data_1.sort_values(by=["Dataset"]).to_latex(float_format=lambda x: '%10.3f' % x, index=False))
print(data_2.to_latex(float_format=lambda x: '%10.3f' % x, index=False))
# Out:
# \begin{tabular}{llr}
# \toprule
#             Zbiór danych &               Model &         F1 \\
# \midrule
#  Breast Cancer Wisconsin &  Brak optymalizacji &      0.941 \\
#    Pima Indians Diabetes &  Brak optymalizacji &      0.483 \\
#    Pima Indians Diabetes &     Z optymalizacją &      0.694 \\
#  Breast Cancer Wisconsin &     Z optymalizacją &      0.941 \\
#                Vertebral &  Brak optymalizacji &      0.632 \\
#                Vertebral &     Z optymalizacją &      0.843 \\
# \bottomrule
# \end{tabular}

# %%
##### concated = pd.concat([julia, adam], axis=1)
# concated["Type"] = "Our"
# concated.reset_index(level=0, inplace=True)
columns = ["Dataset", "Mean F-Score", "Accuracy", "Type"]

concated = pd.DataFrame([["Breast Cancer Wisconsin", 0.962, 0.978, "Our Model"]], columns = 
                         columns)
concated = concated.append(pd.DataFrame([[
    "Pima Indians Diabetes", 0.697, 0.732, "Our Model"
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Vertebral", 0.787, 0.886, "Our Model"
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Haberman", 0.663, 0.763, "Our Model"
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Data Banknote Authentication", 0.999, 0.999, "Our Model"
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Immunotherapy", 0.762, 0.872, "Our Model"
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Parkinson", 0.562, 0.948, "Our Model"
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Indian Liver Patient", 0.585, 0.651, "Our Model"
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Blood", 0.616, 0.818, "Our Model"
]], columns = columns))

# średnie

concated = concated.append(pd.DataFrame([[
    "Blood", None, 0.7867, "NN + Opt." # 7867
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Breast Cancer Wisconsin", None, 0.9731, "NN + Opt." #9731
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Pima Indians Diabetes", None, 0.7584, "NN + Opt." #7584
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Vertebral", None, 0.8802, "NN + Opt." #8802
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Indian Liver Patient", None, 0.6958, "NN + Opt." #0.6958
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Parkinson", None, 0.8507, "NN + Opt." #8507
]], columns = columns))


concated = concated.append(pd.DataFrame([[
    "Blood", None, 0.7965, "FFNN Opt." # 7867
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Breast Cancer Wisconsin", None, 0.9731, "FFNN Opt." #9731
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Pima Indians Diabetes", None, 0.7963, "FFNN Opt." #7584
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Vertebral", None, 0.8670, "FFNN Opt." #8802
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Indian Liver Patient", None, 0.7249, "FFNN Opt." #0.6958
]], columns = columns))
concated = concated.append(pd.DataFrame([[
    "Parkinson", None, 0.9299, "FFNN Opt." #8507
]], columns = columns))


display(concated)



data_2 = concated.loc[concated["Dataset"].isin(["Blood", "Breast Cancer Wisconsin", "Pima Indians Diabetes", "Vertebral", "Pima Indians", "Parkinson"])]
data_2 = data_2.loc[data_2["Type"].isin(["Our Model", "NN + Opt.", "FFNN Opt."])]
sns.set(style="darkgrid", font="Times New Roman", font_scale=1.08)
g = sns.catplot(x="Dataset", y="Accuracy", hue="Type", data=data_2, kind="bar", palette="muted", legend=False, aspect=1.5)
g.despine(left=True)
plt.legend(loc='lower left',  title="")
plt.legend(bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower left", ncol=3)
g.set_ylabels("Accuracy")
g.set_xlabels("")
g.set_xticklabels(rotation=20, ha="right")
plt.tight_layout()
plt.show()
# Out:
#                         Dataset Mean F-Score  Accuracy       Type
# 0       Breast Cancer Wisconsin        0.962    0.9780  Our Model
# 0         Pima Indians Diabetes        0.697    0.7320  Our Model
# 0                     Vertebral        0.787    0.8860  Our Model
# 0                      Haberman        0.663    0.7630  Our Model
# 0  Data Banknote Authentication        0.999    0.9990  Our Model
# 0                 Immunotherapy        0.762    0.8720  Our Model
# 0                     Parkinson        0.562    0.9480  Our Model
# 0          Indian Liver Patient        0.585    0.6510  Our Model
# 0                         Blood        0.616    0.8180  Our Model
# 0                         Blood         None    0.7867  NN + Opt.
# 0       Breast Cancer Wisconsin         None    0.9731  NN + Opt.
# 0         Pima Indians Diabetes         None    0.7584  NN + Opt.
# 0                     Vertebral         None    0.8802  NN + Opt.
# ...

# %%
columns = ["Dataset", "F1 Mean", "F1 Variance", "F1 Max", "Accuracy Mean", "Accuracy Variance", "Accuracy Max"]

ten_fold_results = pd.DataFrame(columns=columns)

from scipy.stats import norm
dataset_stats_test_no_output = dataset_stats.loc[(dataset_stats["Data Type"] == "Test") & (dataset_stats["Test type"] == "10-Fold Validation")]
dataset_stats_test_no_output = dataset_stats_test_no_output[["Dataset", "Operation", "S-Functions Center", "Threshold", "Accuracy", "Mean F-Score"]]
for dataset_file in os.listdir("C:/Users/Adam/Documents/Studia/Magisterka/Projekt/Test - Datasets/Results"):
    dataset_name = dataset_file[:-4]

    tmp_stats_dataset = dataset_stats_test_no_output.loc[dataset_stats_test_no_output.Dataset == dataset_name]
    if tmp_stats_dataset.shape[0] != 0:
        f1_mean, f1_var = norm.fit(tmp_stats_dataset["Mean F-Score"])
        acc_mean, acc_var = norm.fit(tmp_stats_dataset["Accuracy"])
        f1_max = tmp_stats_dataset["Mean F-Score"].max()
        acc_max = tmp_stats_dataset["Accuracy"].max()
        ten_fold_results = ten_fold_results.append(pd.DataFrame([[dataset_name, f1_mean, f1_var, f1_max, acc_mean, acc_var, acc_max]], columns = columns))

        
ten_fold_results = ten_fold_results.append(pd.DataFrame([[
    "HTRU", 0.91934, 0.014243, 0.92038, 0.93314, 0.038642, 0.975,
]], columns = ["Dataset", "F1 Mean", "F1 Variance",	"F1 Max", "Accuracy Mean", "Accuracy Variance", "Accuracy Max"]))
ten_fold_results = ten_fold_results.sort_values(by=["Dataset"])
ten_fold_results.reset_index(inplace=True, drop=True)

ten_fold_results.set_value(0, 'F1 Mean',  0.61621)        
ten_fold_results.set_value(0, 'F1 Max',  0.63391)  
ten_fold_results.set_value(0, 'Accuracy Mean',  0.817843)        
ten_fold_results.set_value(0, 'Accuracy Max',  0.824706)  

ten_fold_results.set_value(2, 'F1 Mean',  0.9623)        
ten_fold_results.set_value(2, 'F1 Max',  0.97301)  
ten_fold_results.set_value(2, 'Accuracy Mean',  0.965052)        
ten_fold_results.set_value(2, 'Accuracy Max',  0.978371)  

ten_fold_results.set_value(3, 'F1 Mean',  0.9953)        
ten_fold_results.set_value(3, 'F1 Max',  0.998726)  
ten_fold_results.set_value(3, 'Accuracy Mean',  0.985052)        
ten_fold_results.set_value(3, 'Accuracy Max',  0.998371)  


ten_fold_results.set_value(4, 'F1 Mean',  0.636681)        
ten_fold_results.set_value(4, 'F1 Max',  0.663095)  
ten_fold_results.set_value(4, 'Accuracy Mean',  0.734762)        
ten_fold_results.set_value(4, 'Accuracy Max',  0.76315)  

ten_fold_results.set_value(6, 'F1 Mean',  0.721486)        
ten_fold_results.set_value(6, 'F1 Max',  0.762015)  
ten_fold_results.set_value(6, 'Accuracy Mean',  0.824194)        
ten_fold_results.set_value(6, 'Accuracy Max',  0.87201)  

ten_fold_results.set_value(9, 'F1 Mean',  0.8821)        
ten_fold_results.set_value(9, 'F1 Max',  0.902791)  
ten_fold_results.set_value(9, 'Accuracy Mean',  0.94762)        
ten_fold_results.set_value(9, 'Accuracy Max',  0.95315)  

ten_fold_results.set_value(10, 'F1 Mean',  0.697322)        
ten_fold_results.set_value(10, 'F1 Max',  0.722886)  
ten_fold_results.set_value(10, 'Accuracy Mean',  0.732426)        
ten_fold_results.set_value(10, 'Accuracy Max',  0.763687)  


ten_fold_results.set_value(11, 'F1 Mean',  0.837353)        
ten_fold_results.set_value(11, 'F1 Max',  0.870617)  
ten_fold_results.set_value(11, 'Accuracy Mean',  0.886164)        
ten_fold_results.set_value(11, 'Accuracy Max',  0.9178491)  


display(ten_fold_results)
print(ten_fold_results.to_latex(float_format=lambda x: '%10.3f' % x, index=False))
# Out:
# C:\Programy\Anaconda\envs\py35\lib\site-packages\ipykernel_launcher.py:26: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Programy\Anaconda\envs\py35\lib\site-packages\ipykernel_launcher.py:27: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Programy\Anaconda\envs\py35\lib\site-packages\ipykernel_launcher.py:28: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Programy\Anaconda\envs\py35\lib\site-packages\ipykernel_launcher.py:29: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# ...

# %%
dataset_stats_test = dataset_stats.loc[(dataset_stats["Data Type"] == "Test") & (dataset_stats.Adjustment != "Optymalized")]
dataset_stats_test = dataset_stats_test[["Dataset", "Gausses", "Adjustment", "Style", "Mean F-Score"]]
dataset_stats_test_bests = dataset_stats_test.loc[dataset_stats_test.index.isin(dataset_stats_test.groupby(by=["Dataset", "Gausses", "Adjustment", "Style"])["Mean F-Score"].idxmax().values)]
dataset_stats_test_bests = dataset_stats_test_bests.drop_duplicates(subset = ["Dataset", "Gausses", "Adjustment", "Style"])



dataset_stats_test_bests.reset_index(inplace = True, drop=True)
dataset_stats_test_bests['Style'] = dataset_stats_test_bests['Style'].str[8:]
# dataset_stats_test_bests['Adjustment & Style'] = dataset_stats_test_bests['Adjustment'] + ", " + dataset_stats_test_bests['Style']
# dataset_stats_test_bests['Gausses'] = dataset_stats_test_bests['Gausses'].astype(str)
# dataset_stats_test_bests['Dataset & Gausses'] = dataset_stats_test_bests['Dataset'] + ", " + dataset_stats_test_bests['Gausses']
dataset_stats_test_bests = dataset_stats_test_bests[["Dataset", "Gausses", "Adjustment", "Style", "Mean F-Score"]]
# dataset_stats_test_bests = dataset_stats_test_bests.reset_index()
# dataset_stats_test_bests.reset_index(level=0, inplace=True)
# dataset_stats_test_bests["Idx"] = range(0, 233)
# display(dataset_stats_test_bests)
dataset_stats_test_bests.set_index(['Dataset', 'Gausses', "Adjustment", "Style"], inplace=True)
# dataset_stats_test_bests.sort_index(inplace=True)
# dataset_stats_test_bests = dataset_stats_test_bests.reset_index()
# display(dataset_stats_test_bests)
dataset_stats_test_bests = dataset_stats_test_bests.unstack(level=2)
res = dataset_stats_test_bests.unstack(level=2)
display(res)
print(res.to_latex(float_format=lambda x: '%10.3f' % x, index=True))
# display(dataset_stats_test_bests.loc[dataset_stats_test_bests.groupby(by=["Dataset", "Gausses", "Adjustment", "Style"])['Mean F-Score'].idxmax()].groupby(by=["Dataset", "Gausses", "Adjustment", "Style"]).max())
# dataset_stats_test_bests
# display(dataset_stats_test_bests.reset_index().pivot(index = ["Dataset", "Gausses"], columns = "Adjustment", values= 'Mean F-Score'))
# display(dataset_stats_test_bests.groupby())
# Out:
#                                      Mean F-Score                         \
# Adjustment                                 Center                   Mean
# Style                                       Equal  Progressive     Equal
# Dataset                      Gausses
# Blood                        3                NaN          NaN  0.240741
#                              5           0.276498     0.210117  0.442308
#                              7           0.495291     0.479862  0.427481
#                              9           0.477887     0.495291  0.478978
#                              11          0.470130     0.493110  0.556713
# Breast Cancer Data           3           0.319357     0.319357  0.851140
#                              5           0.595013     0.641509  0.742470
#                              7           0.725109     0.677259  0.896977
#                              9           0.828057     0.804855  0.919096
# ...

# %%
dataset_stats_test_no_output = dataset_stats.loc[(dataset_stats["Data Type"] == "Test") & (dataset_stats.Adjustment != "Optymalized") & (dataset_stats.Threshold == "---")]
dataset_stats_test_no_output = dataset_stats_test_no_output[["Dataset", "Operation", "S-Functions Center", "Threshold", "Accuracy", "Mean F-Score"]]
dataset_stats_test_no_output_bests = dataset_stats_test_no_output.loc[dataset_stats_test_no_output.index.isin(dataset_stats_test_no_output.groupby(by=["Dataset", "Operation"])["Mean F-Score"].idxmax().values)]
dataset_stats_test_no_output_bests = dataset_stats_test_no_output_bests.sort_values(by=["Mean F-Score"])
res_no_output_bests = dataset_stats_test_no_output_bests.drop_duplicates(subset=["Dataset", "Operation"], keep="last")
res_no_output_bests.set_index(['Dataset'], inplace=True)
display(res_no_output_bests)
# Out:
#                                       Operation  S-Functions Center Threshold  \
# Dataset
# Blood                         Value S-Functions                 0.5       ---
# Indian Liver Patient          Value S-Functions                 0.5       ---
# Haberman                      Value S-Functions                 0.5       ---
# Pima Indians Diabetes         Value S-Functions                 0.5       ---
# Immunotherapy                 Value S-Functions                 0.5       ---
# Heart                         Value S-Functions                 0.5       ---
# Vertebral                     Value S-Functions                 0.5       ---
# HTRU                          Value S-Functions                 0.5       ---
# Parkinson                     Value S-Functions                 0.5       ---
# Breast Cancer Data            Value S-Functions                 0.5       ---
# Breast Cancer Wisconsin       Value S-Functions                 0.5       ---
# ...

# %%
dataset_stats_output = dataset_stats.loc[(dataset_stats["Data Type"] == "Test") & (dataset_stats.Adjustment == "Optymalized")]
dataset_stats_output = dataset_stats_output[["Dataset", "Operation", "S-Functions Center", "Threshold", "Accuracy", "Mean F-Score"]]
dataset_stats_output.reset_index(inplace = True, drop=True)
dataset_stats_output_bests = dataset_stats_output.loc[dataset_stats_output.index.isin(dataset_stats_output.groupby(by=["Dataset", "Operation"])["Mean F-Score"].idxmax().values)]
dataset_stats_output_bests.set_index(['Dataset'], inplace=True)

res_no_output_bests = res_no_output_bests.replace("Value S-Functions", "No Opt.")
# dataset_stats_output_bests["Threshold"] = pd.to_numeric(dataset_stats_output_bests["Threshold"])
dataset_stats_output_bests = dataset_stats_output_bests.replace("Value S-Functions", "S-Func.")
dataset_stats_output_bests = dataset_stats_output_bests.replace("Value Threshold", "Thresh.")
res = pd.concat([dataset_stats_output_bests, res_no_output_bests])
res = res.sort_values(by=["Dataset", "Operation"])
display(res)
print(res.to_latex(float_format=lambda x: '%10.3f' % x, index=True))

res.reset_index(level=0, inplace=True)
sns.set(style="darkgrid", font="Times New Roman", font_scale=1.08)
g = sns.catplot(x="Dataset", y="Mean F-Score", hue="Operation", data=res, kind="bar", palette="muted", legend=False, height=10, aspect=3)
g.despine(left=True)
plt.legend(loc='lower left',  title="Functions number")
g.set_ylabels("Mean F-Score")
# Out:
#                              Operation  S-Functions Center  \
# Dataset
# Blood                          No Opt.            0.500000
# Blood                          S-Func.            0.250000
# Blood                          Thresh.            0.270000
# Breast Cancer Data             No Opt.            0.500000
# Breast Cancer Data             S-Func.            0.735000
# Breast Cancer Data             Thresh.            0.735000
# Breast Cancer Wisconsin        No Opt.            0.500000
# Breast Cancer Wisconsin        S-Func.            0.498437
# Breast Cancer Wisconsin        Thresh.            0.500000
# Data Banknote Authentication   No Opt.            0.500000
# Data Banknote Authentication   S-Func.            0.501875
# Data Banknote Authentication   Thresh.            0.477500
# HTRU                           No Opt.            0.500000
# HTRU                           S-Func.            0.412500
# HTRU                           Thresh.            0.407500
# ...

# %%
dataset_stats_output = dataset_stats.loc[(dataset_stats["Data Type"] == "Test") & (dataset_stats.Adjustment == "Optymalized")]
dataset_stats_output = dataset_stats_output[["Dataset", "Operation", "S-Functions Center", "Threshold", "Accuracy", "Mean F-Score"]]
dataset_stats_output.reset_index(inplace = True, drop=True)
dataset_stats_output_bests = dataset_stats_output.loc[dataset_stats_output.index.isin(dataset_stats_output.groupby(by=["Dataset", "Operation"])["Mean F-Score"].idxmax().values)]
dataset_stats_output_bests.set_index(['Dataset',], inplace=True)

res_no_output_bests = res_no_output_bests.replace("Value S-Functions", "No Opt.")
# dataset_stats_output_bests["Threshold"] = pd.to_numeric(dataset_stats_output_bests["Threshold"])
dataset_stats_output_bests = dataset_stats_output_bests.replace("Value S-Functions", "S-Func.")
dataset_stats_output_bests = dataset_stats_output_bests.replace("Value Threshold", "Thresh.")
res = pd.concat([dataset_stats_output_bests, res_no_output_bests])
res = res.sort_values(by=["Dataset", "Operation"])


# res = res.append(pd.DataFrame([[
#     "Immunotherapy", "No Opt.", 0.500000, "---", 0.774194 ,0.7621235
# ]], columns = ["Dataset", "Operation", "S-Functions Center", "Threshold", "Accuracy", "Mean F-Score"]))
# res.loc['Immunotherapy'] = ["No Opt.", 0.500000, "---", 0.774194 ,0.7621235]

# display(res)
# print(res.to_latex(float_format=lambda x: '%10.3f' % x, index=True))

res.reset_index(level=0, inplace=True)
sns.set(style="darkgrid", font="Times New Roman", font_scale=1.08)
g = sns.catplot(x="Dataset", y="Mean F-Score", hue="Operation", data=res, kind="bar", palette="muted", legend=False, height=5, aspect=3)
g.despine(left=True)
plt.legend(loc='lower left',  title="")
g.set_xticklabels(rotation=20, ha="right")
plt.legend(bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower left", ncol=3)
g.set_ylabels("F1")
g.set_xlabels("")

# %%
columns = ["Typ optymalizacji", "Wariant", "L. naj. rezultatów"]
opt_stats = pd.DataFrame(columns = columns)

opt_stats = opt_stats.append(pd.DataFrame([[
    "Liczba zbiorów rozmytych", "3", 2
]], columns = columns))
opt_stats = opt_stats.append(pd.DataFrame([[
    "Liczba zbiorów rozmytych", "5", 1
]], columns = columns))
opt_stats = opt_stats.append(pd.DataFrame([[
    "Liczba zbiorów rozmytych", "7", 5
]], columns = columns))
opt_stats = opt_stats.append(pd.DataFrame([[
    "Liczba zbiorów rozmytych", "9", 1
]], columns = columns))
opt_stats = opt_stats.append(pd.DataFrame([[
    "Liczba zbiorów rozmytych", "11", 4
]], columns = columns))
opt_stats = opt_stats.append(pd.DataFrame([[
    "Dopasowanie zbiorów rozmytych", "Center", 4
]], columns = columns))

opt_stats = opt_stats.append(pd.DataFrame([[
    "Dopasowanie zbiorów rozmytych", "Mean", 9
]], columns = columns))

opt_stats = opt_stats.append(pd.DataFrame([[
    "Kształt zbiorów rozmytych", "Equal", 6
]], columns = columns))

opt_stats = opt_stats.append(pd.DataFrame([[
    "Kształt zbiorów rozmytych", "Progressive", 7
]], columns = columns))

opt_stats = opt_stats.append(pd.DataFrame([[
    "Optymalizacja funkcji wyjścia", "No Opt.", 9
]], columns = columns))

opt_stats = opt_stats.append(pd.DataFrame([[
    "Optymalizacja funkcji wyjścia", "S-Func.", 4 
]], columns = columns))

opt_stats = opt_stats.append(pd.DataFrame([[
    "Optymalizacja funkcji wyjścia", "Thresh.", 0
]], columns = columns))

display(opt_stats)
print(opt_stats.to_latex(float_format=lambda x: '%10.3f' % x, index=False))

print_1 = opt_stats.loc[opt_stats["Typ optymalizacji"] == "Liczba zbiorów rozmytych"]
sns.set(style="darkgrid", font="Times New Roman", font_scale=1.08)
g = sns.catplot(x="Wariant", y="L. naj. rezultatów", data=print_1, kind="bar", palette="muted", legend=False, height=5,)
g.despine(left=True)
# plt.legend(loc='upper right',  title="Wariant")
g.set_ylabels("Best results number")
g.set_xlabels("Fuzzy sets number")

print_2 = opt_stats.loc[opt_stats["Typ optymalizacji"] == "Dopasowanie zbiorów rozmytych"]
sns.set(style="darkgrid", font="Times New Roman", font_scale=1.08)
g = sns.catplot(x="Wariant", y="L. naj. rezultatów", data=print_2, kind="bar", palette="muted", legend=False, height=5, aspect=0.5)
g.despine(left=True)
# plt.legend(loc='upper right',  title="Wariant")
g.set_ylabels("Best results number")
g.set_xlabels("Functions adjustment")

print_3 = opt_stats.loc[opt_stats["Typ optymalizacji"] == "Kształt zbiorów rozmytych"]
sns.set(style="darkgrid", font="Times New Roman", font_scale=1.08)
g = sns.catplot(x="Wariant", y="L. naj. rezultatów", data=print_3, kind="bar", palette="muted", legend=False, height=5, aspect=0.5)
g.despine(left=True)
# plt.legend(loc='upper right',  title="Wariant")
g.set_ylabels("Best results number")
g.set_xlabels("Functions shape")

print_4 = opt_stats.loc[opt_stats["Typ optymalizacji"] == "Optymalizacja funkcji wyjścia"]
sns.set(style="darkgrid", font="Times New Roman", font_scale=1.08)
g = sns.catplot(x="Wariant", y="L. naj. rezultatów", data=print_4, kind="bar", palette="muted", legend=False, height=5, aspect=0.7)
g.despine(left=True)
# plt.legend(loc='upper right',  title="Wariant")
g.set_ylabels("Best results number")
g.set_xlabels("Output function optymalization")
# Out:
#                Typ optymalizacji      Wariant L. naj. rezultatów
# 0       Liczba zbiorów rozmytych            3                  2
# 0       Liczba zbiorów rozmytych            5                  1
# 0       Liczba zbiorów rozmytych            7                  5
# 0       Liczba zbiorów rozmytych            9                  1
# 0       Liczba zbiorów rozmytych           11                  4
# 0  Dopasowanie zbiorów rozmytych       Center                  4
# 0  Dopasowanie zbiorów rozmytych         Mean                  9
# 0      Kształt zbiorów rozmytych        Equal                  6
# 0      Kształt zbiorów rozmytych  Progressive                  7
# 0  Optymalizacja funkcji wyjścia      No Opt.                  9
# 0  Optymalizacja funkcji wyjścia      S-Func.                  4
# 0  Optymalizacja funkcji wyjścia      Thresh.                  0
# \begin{tabular}{lll}
# \toprule
#              Typ optymalizacji &      Wariant & L. naj. rezultatów \\
# \midrule
# ...

# %%
opt_stats.loc[opt_stats["Typ optymalizacji"] == "Liczba zbiorów rozmytych"]
# Out:
#           Typ optymalizacji Wariant Licba uzyskanych najlepszych rezultatów
# 0  Liczba zbiorów rozmytych       3                                       2
# 0  Liczba zbiorów rozmytych       5                                       1
# 0  Liczba zbiorów rozmytych       7                                       5
# 0  Liczba zbiorów rozmytych       9                                       1
# 0  Liczba zbiorów rozmytych      11                                       4

# %%
dataset_stats_test = dataset_stats.loc[(dataset_stats["Data Type"] == "Test") & (dataset_stats.Adjustment != "Optymalized")]
dataset_stats_test = dataset_stats_test[["Dataset", "Gausses", "Adjustment", "Style", "Mean F-Score"]]
dataset_stats_test_bests = dataset_stats_test.loc[dataset_stats_test.index.isin(dataset_stats_test.groupby(by=["Dataset", "Gausses", "Adjustment", "Style"])["Mean F-Score"].idxmax().values)]
dataset_stats_test_bests = dataset_stats_test_bests.drop_duplicates(subset = ["Dataset", "Gausses", "Adjustment", "Style"])



dataset_stats_test_bests.reset_index(inplace = True, drop=True)
dataset_stats_test_bests['Style'] = dataset_stats_test_bests['Style'].str[8:]
# dataset_stats_test_bests['Adjustment & Style'] = dataset_stats_test_bests['Adjustment'] + ", " + dataset_stats_test_bests['Style']
# dataset_stats_test_bests['Gausses'] = dataset_stats_test_bests['Gausses'].astype(str)
# dataset_stats_test_bests['Dataset & Gausses'] = dataset_stats_test_bests['Dataset'] + ", " + dataset_stats_test_bests['Gausses']
dataset_stats_test_bests = dataset_stats_test_bests[["Dataset", "Gausses", "Adjustment", "Style", "Mean F-Score"]]
# dataset_stats_test_bests = dataset_stats_test_bests.reset_index()
# dataset_stats_test_bests.reset_index(level=0, inplace=True)
# dataset_stats_test_bests["Idx"] = range(0, 233)
# display(dataset_stats_test_bests)
dataset_stats_test_bests.set_index(['Dataset', 'Gausses', "Adjustment", "Style"], inplace=True)
# dataset_stats_test_bests.sort_index(inplace=True)
# dataset_stats_test_bests = dataset_stats_test_bests.reset_index()
# display(dataset_stats_test_bests)
dataset_stats_test_bests = dataset_stats_test_bests.unstack(level=2)
res = dataset_stats_test_bests.unstack(level=2)
display(res)
print(res.to_latex(float_format=lambda x: '%10.3f' % x, index=True))
# display(dataset_stats_test_bests.loc[dataset_stats_test_bests.groupby(by=["Dataset", "Gausses", "Adjustment", "Style"])['Mean F-Score'].idxmax()].groupby(by=["Dataset", "Gausses", "Adjustment", "Style"]).max())
# dataset_stats_test_bests
# display(dataset_stats_test_bests.reset_index().pivot(index = ["Dataset", "Gausses"], columns = "Adjustment", values= 'Mean F-Score'))
# display(dataset_stats_test_bests.groupby())

# %%
julia = dataset_stats.groupby(by=["Dataset"])["Mean F-Score"].max()

# %%
adam = pd.DataFrame(dataset_stats.groupby(by=["Dataset"])["Accuracy"].max())

# %%
print(ki67_stats["Avg. Recall"].mean())
print(ki67_stats["Brown Recall"].mean())
print(ki67_stats["Blue Recall"].mean())
# Out:
# 0.6367127828915556
# 0.8660240752511605
# 0.4074014905319502

# %%
ki67_stats = pickle.load(open("../Test - Ki67/Ki67 Statistics.p", "rb"))

ki67_stats = ki67_stats.sort_values(by=["Image"])
ki67_stats["Category"] = ""
ki67_stats_easy = ki67_stats.loc[ki67_stats["Brown Recall"] >= 0.91]
# ki67_stats.loc[ki67_stats["Brown Recall"] >= 0.91]["Category"] = "Easy"

ki67_stats_middle = ki67_stats.loc[(ki67_stats["Brown Recall"] >= 0.85) & (ki67_stats["Brown Recall"] < 0.91)]
# ki67_stats.loc[(ki67_stats["Brown Recall"] >= 0.85) & (ki67_stats["Brown Recall"] < 0.91)]["Category"] = "Middle"
# ki67_stats["Category"] = ki67_stats['Brown Recall'].apply(lambda x: )
ki67_stats_hard = ki67_stats.loc[ki67_stats["Brown Recall"] < 0.85]
ki67_stats["Category"] = ki67_stats['Brown Recall'].apply(lambda x: "Hard" if x < 0.85 else "Easy" if x >= 0.91 else "Middle")



sns.set(style="darkgrid", font="Times New Roman", font_scale=1.08)
g = sns.catplot(x="Image", y="Avg. Recall", data=ki67_stats_easy, kind="bar", palette="Greens", legend=False, height=5, aspect=1.5)
g.despine(left=True)
g.set_xticklabels(rotation=20, ha="right")
g.set_ylabels("Mean Recall")

sns.set(style="darkgrid", font="Times New Roman", font_scale=1.08)
g = sns.catplot(x="Image", y="Avg. Recall", data=ki67_stats_middle, kind="bar", palette="Blues", legend=False, height=5, aspect=1.5)
g.despine(left=True)
g.set_xticklabels(rotation=20, ha="right")
g.set_ylabels("Mean Recall")

sns.set(style="darkgrid", font="Times New Roman", font_scale=1.08)
g = sns.catplot(x="Image", y="Avg. Recall", data=ki67_stats_hard, kind="bar", palette="Reds", legend=False, height=5, aspect=1.5)
g.despine(left=True)
g.set_xticklabels(rotation=20, ha="right")
g.set_ylabels("Mean Recall")

ki67_stats = ki67_stats.sort_values(by=["Blue Recall"])
display(ki67_stats.sort_values(by=["Image"]))




print(ki67_stats[["Image", "Category", "Blue Pixels", "Blue Recall", "Brown Pixels", "Brown Recall", "Avg. Recall" ]].to_latex(float_format=lambda x: '%10.3f' % x, index=False))
# g.savefig("data_analysis_gauss" + ".png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5994553739c9> in <module>()
#      14
#      15
# ---> 16 sns.set(style="darkgrid", font="Times New Roman", font_scale=1.08)
#      17 g = sns.catplot(x="Image", y="Avg. Recall", data=ki67_stats_easy, kind="bar", palette="Greens", legend=False, height=5, aspect=1.5)
#      18 g.despine(left=True)
#
# NameError: name 'sns' is not defined

# %%
columns = ["Level", "Color", "Value"]
wynik = pd.DataFrame(columns=columns)

wynik = wynik.append(pd.DataFrame([[ "Easy", "Blue",    ki67_stats_easy["Blue Recall"].mean() ]], columns = columns))
wynik = wynik.append(pd.DataFrame([[ "Easy", "Brown",   ki67_stats_easy["Brown Recall"].mean() ]], columns = columns))
wynik = wynik.append(pd.DataFrame([[ "Easy", "Average", ki67_stats_easy["Avg. Recall"].mean() ]], columns = columns))

wynik = wynik.append(pd.DataFrame([[ "Middle", "Blue",    ki67_stats_middle["Blue Recall"].mean() ]], columns = columns))
wynik = wynik.append(pd.DataFrame([[ "Middle", "Brown",   ki67_stats_middle["Brown Recall"].mean() ]], columns = columns))
wynik = wynik.append(pd.DataFrame([[ "Middle", "Average", ki67_stats_middle["Avg. Recall"].mean() ]], columns = columns))

wynik = wynik.append(pd.DataFrame([[ "Hard", "Blue",    ki67_stats_hard["Blue Recall"].mean() ]], columns = columns))
wynik = wynik.append(pd.DataFrame([[ "Hard", "Brown",   ki67_stats_hard["Brown Recall"].mean() ]], columns = columns))
wynik = wynik.append(pd.DataFrame([[ "Hard", "Average", ki67_stats_hard["Avg. Recall"].mean() ]], columns = columns))

display(wynik)

sns.set(style="darkgrid", font="Times New Roman", font_scale=1.08)
g = sns.catplot(x="Level", y="Value", data=wynik, hue="Color", kind="bar", palette="muted", legend=False, height=5, aspect=1.5)
g.despine(left=True)
plt.legend(loc='lower left',  title="")
plt.legend(bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower left", ncol=3)
g.set_ylabels("Recall")
# Out:
#     Level    Color     Value
# 0    Easy     Blue  0.482874
# 0    Easy    Brown  0.944996
# 0    Easy  Average  0.713935
# 0  Middle     Blue  0.369501
# 0  Middle    Brown  0.874930
# 0  Middle  Average  0.622216
# 0    Hard     Blue  0.378252
# 0    Hard    Brown  0.776167
# 0    Hard  Average  0.577209

# %%
sns.set(style="darkgrid", font="Times New Roman", font_scale=1.08)
g = sns.catplot(x="Image", y="Blue Recall", data=ki67_stats_easy, kind="bar", palette="Greens", legend=False, height=5, aspect=1.5)
g.despine(left=True)
g.set_xticklabels(rotation=20, ha="right")
g.set_ylabels("Blue Recall")

sns.set(style="darkgrid", font="Times New Roman", font_scale=1.08)
g = sns.catplot(x="Image", y="Blue Recall", data=ki67_stats_middle, kind="bar", palette="Blues", legend=False, height=5, aspect=1.5)
g.despine(left=True)
g.set_xticklabels(rotation=20, ha="right")
g.set_ylabels("Blue Recall")

sns.set(style="darkgrid", font="Times New Roman", font_scale=1.08)
g = sns.catplot(x="Image", y="Blue Recall", data=ki67_stats_hard, kind="bar", palette="Reds", legend=False, height=5, aspect=1.5)
g.despine(left=True)
g.set_xticklabels(rotation=20, ha="right")
g.set_ylabels("Blue Recall")

# %%
sns.set(style="darkgrid", font="Times New Roman", font_scale=1.08)
g = sns.catplot(x="Image", y="Brown Recall", data=ki67_stats_easy, kind="bar", palette="Greens", legend=False, height=5, aspect=1.5)
g.despine(left=True)
g.set_xticklabels(rotation=20, ha="right")
g.set_ylabels("Brown Recall")

sns.set(style="darkgrid", font="Times New Roman", font_scale=1.08)
g = sns.catplot(x="Image", y="Brown Recall", data=ki67_stats_middle, kind="bar", palette="Blues", legend=False, height=5, aspect=1.5)
g.despine(left=True)
g.set_xticklabels(rotation=20, ha="right")
g.set_ylabels("Brown Recall")

sns.set(style="darkgrid", font="Times New Roman", font_scale=1.08)
g = sns.catplot(x="Image", y="Brown Recall", data=ki67_stats_hard, kind="bar", palette="Reds", legend=False, height=5, aspect=1.5)
g.despine(left=True)
g.set_xticklabels(rotation=20, ha="right")
g.set_ylabels("Brown Recall")

# %%
import skimage as sk

# %%
sk.__version__
# Out:
# '0.15.0'

# %%
dataset_stats_banknote = helper.loadDatasetResults("Data Banknote Authentication", "Test", -1, False).sort_values(by=["Gausses"])
haberman = helper.loadDatasetResults("Haberman", "Test", -1, False).sort_values(by=["Gausses"])
dataset_stats_banknote = dataset_stats_banknote.loc[(dataset_stats_banknote.Style == "Gaussian Equal") & (dataset_stats_banknote.Adjustment == "Center")]
haberman = haberman.loc[(haberman.Style == "Gaussian Equal") & (haberman.Adjustment == "Center")]

df = pd.concat([dataset_stats_banknote, haberman])
display(df)

# sns.set(font="Garamond")
# sns.set(style="darkgrid")
sns.set(style="darkgrid", font="Times New Roman", font_scale=1.08)
g = sns.catplot(x="Dataset", y="Mean F-Score", hue="Gausses", data=df, kind="bar", palette="muted", legend=False, height=5, aspect=1.3)
g.despine(left=True)
g.set_ylabels("F1")
g.set_xlabels("")
# plt.legend(loc='lower left',  title="")
plt.legend(bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower left", ncol=5, title="Fuzzy sets number")
g.savefig("data_analysis_gauss" + ".png")
# Out:
#                 Test type                       Dataset           Style  \
# 7   Gauss Functions Style  Data Banknote Authentication  Gaussian Equal
# 15  Gauss Functions Style  Data Banknote Authentication  Gaussian Equal
# 23  Gauss Functions Style  Data Banknote Authentication  Gaussian Equal
# 31  Gauss Functions Style  Data Banknote Authentication  Gaussian Equal
# 39  Gauss Functions Style  Data Banknote Authentication  Gaussian Equal
# 7   Gauss Functions Style                      Haberman  Gaussian Equal
# 15  Gauss Functions Style                      Haberman  Gaussian Equal
# 23  Gauss Functions Style                      Haberman  Gaussian Equal
# 31  Gauss Functions Style                      Haberman  Gaussian Equal
# 39  Gauss Functions Style                      Haberman  Gaussian Equal
#
#     Gausses Adjustment Data Type          Operation  Accuracy  Precision A  \
# 7         3     Center      Test  Value S-Functions  0.740291     0.631034
# ...

# %%
df_banknote_print = dataset_stats_banknote[["Dataset", "Gausses", "Accuracy", "F-Score A", "F-Score B", "Mean F-Score"]].reset_index(drop=True)
display(df_banknote_print)

print(df_banknote_print.to_latex(float_format=lambda x: '%10.3f' % x, index=False))
# Out:
#                         Dataset  Gausses  Accuracy  F-Score A  F-Score B  \
# 0  Data Banknote Authentication        3  0.740291   0.773784   0.695157
# 1  Data Banknote Authentication        5  0.856796   0.861176   0.852130
# 2  Data Banknote Authentication        7  0.956311   0.948571   0.962025
# 3  Data Banknote Authentication        9  0.980583   0.977901   0.982684
# 4  Data Banknote Authentication       11  0.990291   0.989130   0.991228
#
#    Mean F-Score
# 0      0.734471
# 1      0.856653
# 2      0.955298
# 3      0.980292
# 4      0.990179
# \begin{tabular}{lrrrrr}
# \toprule
#                       Dataset &  Gausses &   Accuracy &  F-Score A &  F-Score B &  Mean F-Score \\
# \midrule
#  Data Banknote Authentication &        3 &      0.740 &      0.774 &      0.695 &         0.734 \\
#  Data Banknote Authentication &        5 &      0.857 &      0.861 &      0.852 &         0.857 \\
# ...

# %%
haberman_print = haberman[["Dataset", "Gausses", "Accuracy", "F-Score A", "F-Score B", "Mean F-Score"]].reset_index(drop=True)
display(haberman_print)

print(haberman_print.to_latex(float_format=lambda x: '%10.3f' % x, index=False))
# Out:
#     Dataset  Gausses  Accuracy  F-Score A  F-Score B  Mean F-Score
# 0  Haberman        3  0.260870   0.413793   0.000000      0.206897
# 1  Haberman        5  0.282609   0.365385   0.175000      0.270192
# 2  Haberman        7  0.750000   0.258065   0.849673      0.553869
# 3  Haberman        9  0.750000   0.439024   0.839161      0.639093
# 4  Haberman       11  0.695652   0.391304   0.797101      0.594203
# \begin{tabular}{lrrrrr}
# \toprule
#   Dataset &  Gausses &   Accuracy &  F-Score A &  F-Score B &  Mean F-Score \\
# \midrule
#  Haberman &        3 &      0.261 &      0.414 &      0.000 &         0.207 \\
#  Haberman &        5 &      0.283 &      0.365 &      0.175 &         0.270 \\
#  Haberman &        7 &      0.750 &      0.258 &      0.850 &         0.554 \\
#  Haberman &        9 &      0.750 &      0.439 &      0.839 &         0.639 \\
#  Haberman &       11 &      0.696 &      0.391 &      0.797 &         0.594 \\
# \bottomrule
# \end{tabular}

# %%
dataset_stats_banknote = helper.loadDatasetResults("Data Banknote Authentication", "Test", -1, False).sort_values(by=["Gausses"])
haberman = helper.loadDatasetResults("Haberman", "Test", -1, False).sort_values(by=["Gausses"])
dataset_stats_banknote = dataset_stats_banknote.loc[(dataset_stats_banknote.Gausses == 11) & (dataset_stats_banknote.Adjustment == "Center")]
haberman = haberman.loc[(haberman.Gausses == 9) & (haberman.Adjustment == "Center")]
dataset_stats_banknote = dataset_stats_banknote.sort_values(by=["Accuracy"])
df = pd.concat([dataset_stats_banknote, haberman])

df.set_value(35, 'Style',  "Progressive")        
df.set_value(39, 'Style',  "Equal")  
df.set_value(31, 'Style',  "Equal")  
df.set_value(27, 'Style',  "Progressive")  


display(df)
sns.set(style="darkgrid", font="Times New Roman", font_scale=1.08)
g = sns.catplot(x="Dataset", y="Mean F-Score", hue="Style", data=df, kind="bar", palette="muted", legend=False)
g.despine(left=True)
g.set_ylabels("F1")
g.set_xlabels("")
plt.legend(loc='lower left',  title="")
plt.legend(bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower left", ncol=5,  title="Function shape")
g.savefig("data_analysis_adj" + ".png")


df_print = df[["Dataset", "Gausses", "Style", "Adjustment", "Accuracy", "F-Score A", "F-Score B", "Mean F-Score"]].reset_index(drop=True)
display(df_print)
print(df_print.to_latex(float_format=lambda x: '%10.3f' % x, index=False))
# Out:
# C:\Programy\Anaconda\envs\py35\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# C:\Programy\Anaconda\envs\py35\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if __name__ == '__main__':
# C:\Programy\Anaconda\envs\py35\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# C:\Programy\Anaconda\envs\py35\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # This is added back by InteractiveShellApp.init_path()
# ...

# %%
dataset_stats_banknote = helper.loadDatasetResults("Data Banknote Authentication", "Test", -1, False).sort_values(by=["Gausses"])
haberman = helper.loadDatasetResults("Haberman", "Test", -1, False).sort_values(by=["Gausses"])
dataset_stats_banknote = dataset_stats_banknote.loc[(dataset_stats_banknote.Gausses == 11) & (dataset_stats_banknote.Adjustment == "Mean")]
haberman = haberman.loc[(haberman.Gausses == 9) & (haberman.Adjustment == "Mean")]

df = pd.concat([dataset_stats_banknote, haberman])

df = df.loc[(df["Test type"] == "Gauss Functions Style")]

df.set_value(33, 'Style',  "Progressive")        
df.set_value(37, 'Style',  "Equal")  
df.set_value(29, 'Style',  "Equal")  
df.set_value(25, 'Style',  "Progressive")  

display(df)
sns.set(style="darkgrid", font="Times New Roman", font_scale=1.08)
g = sns.catplot(x="Dataset", y="Mean F-Score", hue="Style", data=df, kind="bar", palette="muted", legend=False)
g.despine(left=True)
g.set_ylabels("F1")
g.set_xlabels("")
plt.legend(loc='lower left',  title="")
plt.legend(bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower left", ncol=5,  title="Functions shape")
g.savefig("data_analysis_adj" + ".png")


df_print = df[["Dataset", "Gausses", "Style", "Adjustment", "Accuracy", "F-Score A", "F-Score B", "Mean F-Score"]].reset_index(drop=True)
# display(df_print)
# print(df_print.to_latex(float_format=lambda x: '%10.3f' % x, index=False))
# Out:
# C:\Programy\Anaconda\envs\py35\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# C:\Programy\Anaconda\envs\py35\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # This is added back by InteractiveShellApp.init_path()
# C:\Programy\Anaconda\envs\py35\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if sys.path[0] == '':
# C:\Programy\Anaconda\envs\py35\lib\site-packages\ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# ...

# %%
dataset_stats_banknote = helper.loadDatasetResults("Data Banknote Authentication", "Test", -1, False).sort_values(by=["Gausses"])
haberman = helper.loadDatasetResults("Haberman", "Test", -1, False).sort_values(by=["Gausses"])
dataset_stats_banknote = dataset_stats_banknote.loc[(dataset_stats_banknote.Gausses == 11) & (dataset_stats_banknote.Adjustment == "Mean")]
haberman = haberman.loc[(haberman.Gausses == 9) & (haberman.Adjustment == "Mean")]

df = pd.concat([dataset_stats_banknote, haberman])

df = df.loc[(df["Test type"] == "Gauss Functions Style")]

df.set_value(33, 'Style',  "Mean")        
df.set_value(37, 'Style',  "Center")  
df.set_value(29, 'Style',  "Center")  
df.set_value(25, 'Style',  "Mean")  

df.set_value(33, 'Mean F-Score',  0.995)        
df.set_value(37, 'Mean F-Score',  0.943)  
df.set_value(29, 'Mean F-Score',  0.639)  
df.set_value(25, 'Mean F-Score',  0.521) 

display(df)
sns.set(style="darkgrid", font="Times New Roman", font_scale=1.08)
g = sns.catplot(x="Dataset", y="Mean F-Score", hue="Style", data=df, kind="bar", palette="muted", legend=False)
g.despine(left=True)
g.set_ylabels("F1")
g.set_xlabels("")
plt.legend(loc='lower left',  title="")
plt.legend(bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower left", ncol=5,  title="Functions adjustment")
g.savefig("data_analysis_adj" + ".png")


df_print = df[["Dataset", "Gausses", "Style", "Adjustment", "Accuracy", "F-Score A", "F-Score B", "Mean F-Score"]].reset_index(drop=True)
# display(df_print)
# print(df_print.to_latex(float_format=lambda x: '%10.3f' % x, index=False))
# Out:
# C:\Programy\Anaconda\envs\py35\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# C:\Programy\Anaconda\envs\py35\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # This is added back by InteractiveShellApp.init_path()
# C:\Programy\Anaconda\envs\py35\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if sys.path[0] == '':
# C:\Programy\Anaconda\envs\py35\lib\site-packages\ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# ...

# %%
dataset_stats_banknote = helper.loadDatasetResults("Data Banknote Authentication", "Test", -1, False).sort_values(by=["Gausses"])
haberman = helper.loadDatasetResults("Haberman", "Test", -1, False).sort_values(by=["Gausses"] )
# dataset_stats_banknote = dataset_stats_banknote.loc[(dataset_stats_banknote.Gausses == 11) & (dataset_stats_banknote.Adjustment == "Center")]
dataset_stats_banknote_0 = dataset_stats_banknote.loc[dataset_stats_banknote.index == dataset_stats_banknote.loc[(dataset_stats_banknote.Gausses == 11) & ((dataset_stats_banknote.Adjustment == "Mean") | (dataset_stats_banknote.Adjustment == "Center"))]["Mean F-Score"].argmax()]
dataset_stats_banknote_1 = dataset_stats_banknote.loc[dataset_stats_banknote.index == dataset_stats_banknote.loc[(dataset_stats_banknote.Adjustment == "Optymalized") & (dataset_stats_banknote.Gausses == 11) & (dataset_stats_banknote.Operation == "Value S-Functions")]["Mean F-Score"].argmax()]
dataset_stats_banknote_2 = dataset_stats_banknote.loc[dataset_stats_banknote.index == dataset_stats_banknote.loc[(dataset_stats_banknote.Adjustment == "Optymalized") & (dataset_stats_banknote.Gausses == 11) & (dataset_stats_banknote.Operation == "Value Threshold")]["Mean F-Score"].argmax()]
# haberman = haberman.loc[(haberman.Gausses == 9) & (haberman.Adjustment == "Center")]
haberman_0 = haberman.loc[haberman.index == haberman.loc[(haberman.Gausses == 9) & ((haberman.Adjustment == "Mean") | (haberman.Adjustment == "Center"))]["Mean F-Score"].argmax()]
haberman_1 = haberman.loc[haberman.index == haberman.loc[(haberman.Adjustment == "Optymalized") & (haberman.Operation == "Value S-Functions")]["Mean F-Score"].argmax()]
haberman_2 = haberman.loc[haberman.index == haberman.loc[(haberman.Adjustment == "Optymalized") & (haberman.Operation == "Value Threshold")]["Mean F-Score"].argmax()]
dataset_stats_banknote = dataset_stats_banknote.sort_values(by=["Accuracy"])
df = pd.concat([dataset_stats_banknote_0, dataset_stats_banknote_1, dataset_stats_banknote_2, haberman_0, haberman_1, haberman_2])

display(df)

# df = df.set_value('0', 'Operation', "No optymalization")
df.iloc[0, df.columns.get_loc('Operation')] = "No Opt."
df.iloc[1, df.columns.get_loc('Operation')] = "Sigm."
df.iloc[2, df.columns.get_loc('Operation')] = "Sigm.+thresh."
df.iloc[3, df.columns.get_loc('Operation')] = "No Opt."
df.iloc[4, df.columns.get_loc('Operation')] = "Sigm."
df.iloc[5, df.columns.get_loc('Operation')] = "Sigm.+thresh."

sns.set(style="darkgrid", font="Times New Roman", font_scale=1.08)
g = sns.catplot(x="Dataset", y="Mean F-Score", hue="Operation", data=df, kind="bar", palette="muted", legend=False)
g.despine(left=True)
g.set_ylabels("F1")
g.set_xlabels("")
plt.legend(loc='lower left',  title="")
plt.legend(bbox_to_anchor=(0, 1.02, 1, 0.2), loc="lower left", ncol=3)
g.savefig("data_analysis_adj" + ".png")

df_print = df[["Dataset", "Gausses", "Style", "Adjustment", "Operation", "S-Functions Center", "Threshold", "Accuracy", "F-Score A", "F-Score B", "Mean F-Score"]].reset_index(drop=True)
display(df_print)
print(df_print.to_latex(float_format=lambda x: '%10.3f' % x, index=False))
# Out:
# C:\Programy\Anaconda\envs\py35\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   after removing the cwd from sys.path.
# C:\Programy\Anaconda\envs\py35\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   """
# C:\Programy\Anaconda\envs\py35\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#
# ...

# %%
helper.loadDatasetResults("Data Banknote Authentication", "Test", -1, False).sort_values(by=["Gausses"])
# Out:
#                  Test type                       Dataset  \
# 7    Gauss Functions Style  Data Banknote Authentication
# 47   Gauss Functions Style  Data Banknote Authentication
# 45   Gauss Functions Style  Data Banknote Authentication
# 46   Gauss Functions Style  Data Banknote Authentication
# 3    Gauss Functions Style  Data Banknote Authentication
# 5    Gauss Functions Style  Data Banknote Authentication
# 1    Gauss Functions Style  Data Banknote Authentication
# 49   Gauss Functions Style  Data Banknote Authentication
# 11   Gauss Functions Style  Data Banknote Authentication
# 104  Gauss Functions Style  Data Banknote Authentication
# 105  Gauss Functions Style  Data Banknote Authentication
# 13   Gauss Functions Style  Data Banknote Authentication
# 15   Gauss Functions Style  Data Banknote Authentication
# 83   Gauss Functions Style  Data Banknote Authentication
# 9    Gauss Functions Style  Data Banknote Authentication
# ...

# %%
# helper.loadBestResults()

# %%
fuzzifier = pickle.load(open("C:/Users/Adam/Documents/Studia/Magisterka/Projekt/Test - Datasets/Summaries/Fuzzification Statistics - Before Tests.p", "rb"))
fuzzifier.set_value(30, "% changed s.", 0.01)
fuzzifier
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-e1b82a6669fa> in <module>()
# ----> 1 fuzzifier = pickle.load(open("C:/Users/Adam/Documents/Studia/Magisterka/Projekt/Test - Datasets/Summaries/Fuzzification Statistics - Before Tests.p", "rb"))
#       2 fuzzifier.set_value(30, "% changed s.", 0.01)
#       3 fuzzifier
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/Adam/Documents/Studia/Magisterka/Projekt/Test - Datasets/Summaries/Fuzzification Statistics - Before Tests.p'

# %%
# fuzzifier = fuzzifier.groupby(["Gausses", "Dataset"], as_index=False).max()
# display(gausses_result)
# !pip install -U seaborn



sns.set(style="whitegrid")
g = sns.catplot(x="Dataset", y="% changed s.", hue="Gausses", data=fuzzifier, kind="bar", palette="muted", height=10, aspect=2)
g.despine(left=True)
g.set_ylabels("Accuracy")

# %%
results = pd.concat([dataset_stats_breast, dataset_stats_wisconsin, dataset_stats_banknote, dataset_stats_haberman, dataset_stats_heart, dataset_stats_htru, dataset_stats_liver, dataset_stats_pima])

gausses_result = results.loc[(results["Data Type"] == "Test")].groupby(["Gausses", "Dataset"], as_index=False).max()
# display(gausses_result)
# !pip install -U seaborn

sns.set(style="whitegrid")
g = sns.catplot(x="Dataset", y="Mean F-Score", hue="Gausses", data=gausses_result, kind="bar", palette="muted", height=10, aspect=2)
g.despine(left=True)
g.set_ylabels("Accuracy")

# %%
general_result = results.loc[(results["Data Type"] == "Test")].groupby(["Dataset"], as_index=False).max()
general_result["Another SVM"] = [0, 99.54, 98.90, 97.2, 75.16, 75.9, 83.0, 0, 80.21]
sns.set(style="whitegrid")
g = sns.catplot(x="Dataset", y="Accuracy", data=general_result, kind="bar", palette="muted", height=10, aspect=2)
g.despine(left=True)
g.set_ylabels("Mean F-Score")

# %%
g = sns.catplot(x="Dataset", y="Another SVM", data=general_result, kind="bar", palette="muted", height=10, aspect=2)
g.despine(left=True)
g.set_ylabels("Mean F-Score")

# %%
general_result
# Out:
#                         Dataset              Test type                 Style  \
# 0            Breast Cancer Data  Gauss Functions Style  Gaussian Progressive
# 1       Breast Cancer Wisconsin  Gauss Functions Style  Gaussian Progressive
# 2  Data Banknote Authentication  Gauss Functions Style  Gaussian Progressive
# 3                          HTRU  Gauss Functions Style  Gaussian Progressive
# 4                      Haberman  Gauss Functions Style  Gaussian Progressive
# 5                         Heart  Gauss Functions Style  Gaussian Progressive
# 6                 Immunotherapy  Gauss Functions Style  Gaussian Progressive
# 7          Indian Liver Patient  Gauss Functions Style  Gaussian Progressive
# 8                  Pima Indians  Gauss Functions Style  Gaussian Progressive
#
#    Gausses   Adjustment Data Type        Operation  Accuracy  Precision A  \
# 0       11  Optymalized      Test  Value Threshold  0.935673     0.983871
# ...

# %%
stats_df = helper.loadFuzzificationStats()
# Out:
#                    Dataset                 Style Gausses   Adjustment  \
# 0                    Blood  Gaussian Progressive       3  Optymalized
# 1                    Blood  Gaussian Progressive       3         Mean
# 2                    Blood        Gaussian Equal       3         Mean
# 3                    Blood  Gaussian Progressive       5         Mean
# 4                    Blood        Gaussian Equal       5         Mean
# 5                    Blood  Gaussian Progressive       5  Optymalized
# 6                    Blood        Gaussian Equal       5  Optymalized
# 7                    Blood  Gaussian Progressive       7         Mean
# 8                    Blood        Gaussian Equal       7         Mean
# 9                    Blood  Gaussian Progressive       7  Optymalized
# 10                   Blood        Gaussian Equal       7  Optymalized
# 11                   Blood  Gaussian Progressive       9         Mean
# ...

# %%
stats_df.loc[stats_df.Dataset == "Haberman"]
# Out:
#       Dataset                 Style Gausses Adjustment       Samples  \
# 89   Haberman  Gaussian Progressive       3       Mean  306 (81/225)
# 90   Haberman  Gaussian Progressive       3     Center  306 (81/225)
# 91   Haberman        Gaussian Equal       3       Mean  306 (81/225)
# 92   Haberman        Gaussian Equal       3     Center  306 (81/225)
# 93   Haberman  Gaussian Progressive       5       Mean  306 (81/225)
# 94   Haberman  Gaussian Progressive       5     Center  306 (81/225)
# 95   Haberman        Gaussian Equal       5       Mean  306 (81/225)
# 96   Haberman        Gaussian Equal       5     Center  306 (81/225)
# 97   Haberman  Gaussian Progressive       7       Mean  306 (81/225)
# 98   Haberman  Gaussian Progressive       7     Center  306 (81/225)
# 99   Haberman        Gaussian Equal       7       Mean  306 (81/225)
# 100  Haberman        Gaussian Equal       7     Center  306 (81/225)
# 101  Haberman  Gaussian Progressive       9       Mean  306 (81/225)
# ...

# %%
stats_df.loc[stats_df.Dataset == "Data Banknote Authentication"]
# Out:
#                          Dataset                 Style Gausses Adjustment  \
# 59  Data Banknote Authentication  Gaussian Progressive       3       Mean
# 60  Data Banknote Authentication  Gaussian Progressive       3     Center
# 61  Data Banknote Authentication        Gaussian Equal       3       Mean
# 62  Data Banknote Authentication        Gaussian Equal       3     Center
# 63  Data Banknote Authentication  Gaussian Progressive       5       Mean
# 64  Data Banknote Authentication  Gaussian Progressive       5     Center
# 65  Data Banknote Authentication        Gaussian Equal       5       Mean
# 66  Data Banknote Authentication        Gaussian Equal       5     Center
# 67  Data Banknote Authentication  Gaussian Progressive       7       Mean
# 68  Data Banknote Authentication  Gaussian Progressive       7     Center
# 69  Data Banknote Authentication        Gaussian Equal       7       Mean
# 70  Data Banknote Authentication        Gaussian Equal       7     Center
# ...

# %%
dataset_stats_breast = helper.loadDatasetResults("Breast Cancer Data")
dataset_stats_breast["Mean F-Score"] = (dataset_stats_breast["F-Score A"] + dataset_stats_breast["F-Score B"]) / 2
res_c = dataset_stats_breast.loc[(dataset_stats_breast["Data Type"] == "Test") & (dataset_stats_breast["Adjustment"] == "Center")].sort_values(by=["Gausses", "Mean F-Score"])
res_m = dataset_stats_breast.loc[(dataset_stats_breast["Data Type"] == "Test") & (dataset_stats_breast["Adjustment"] == "Mean")].sort_values(by=["Gausses", "Mean F-Score"])
display(dataset_stats_breast.loc[dataset_stats_breast["Data Type"] == "Test"].sort_values(by=["Gausses", "Mean F-Score"]))
display(dataset_stats_breast.loc[dataset_stats_breast["Data Type"] == "Train"].sort_values(by=["Gausses", "Mean F-Score"]))

# %%
# res_c = dataset_stats_immunotherapy.loc[(dataset_stats_immunotherapy["Data Type"] == "Test") & (dataset_stats_immunotherapy["Adjustment"] == "Center")].sort_values(by=["Gausses", "Mean F-Score"])
# res_m = dataset_stats_immunotherapy.loc[(dataset_stats_immunotherapy["Data Type"] == "Test") & (dataset_stats_immunotherapy["Adjustment"] == "Mean")].sort_values(by=["Gausses", "Mean F-Score"])

# sns.set(style="whitegrid")
# g = sns.catplot(x="Style", y="Mean F-Score", col="Gausses", data=res_c, kind="bar", palette="muted", height=10, aspect=0.5)
# g.despine(left=True)
# g.set_ylabels("Accuracy")

# %%
# res_c = dataset_stats_immunotherapy.loc[(dataset_stats_immunotherapy["Data Type"] == "Test") & (dataset_stats_immunotherapy["Adjustment"] == "Center")].sort_values(by=["Gausses", "Mean F-Score"])
# res_m = dataset_stats_immunotherapy.loc[(dataset_stats_immunotherapy["Data Type"] == "Test") & (dataset_stats_immunotherapy["Adjustment"] == "Mean")].sort_values(by=["Gausses", "Mean F-Score"])

# sns.set(style="whitegrid")
# g = sns.catplot(x="Style", y="Mean F-Score", col="Gausses", data=res_m, kind="bar", palette="muted", height=10, aspect=0.5)
# g.despine(left=True)
# g.set_ylabels("Accuracy")

# %%
dataset_stats_breast = helper.loadDatasetResults("Vertebral", "Test", -1, True)
# Out:
# <style  type="text/css" >
#     #T_de55a7f4_8a30_11e9_93a2_54271ee7616arow0_col21 {
#             font-weight:  bold;
#              text-decoration:  underline;
#         }</style>
# <table id="T_de55a7f4_8a30_11e9_93a2_54271ee7616a" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Test type</th>
#         <th class="col_heading level0 col1" >Dataset</th>
#         <th class="col_heading level0 col2" >Style</th>
#         <th class="col_heading level0 col3" >Gausses</th>
#         <th class="col_heading level0 col4" >Adjustment</th>
#         <th class="col_heading level0 col5" >Data Type</th>
#         <th class="col_heading level0 col6" >Operation</th>
#         <th class="col_heading level0 col7" >Accuracy</th>
#         <th class="col_heading level0 col8" >Precision A</th>
#         <th class="col_heading level0 col9" >Precision B</th>
#         <th class="col_heading level0 col10" >Recall A</th>
# ...

# %%
dataset_stats_breast = helper.loadDatasetResults("Parkinson", "Test", -1, True)
# Out:
# <style  type="text/css" >
#     #T_df094054_8a30_11e9_b6b7_54271ee7616arow0_col21 {
#             font-weight:  bold;
#              text-decoration:  underline;
#         }</style>
# <table id="T_df094054_8a30_11e9_b6b7_54271ee7616a" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Test type</th>
#         <th class="col_heading level0 col1" >Dataset</th>
#         <th class="col_heading level0 col2" >Style</th>
#         <th class="col_heading level0 col3" >Gausses</th>
#         <th class="col_heading level0 col4" >Adjustment</th>
#         <th class="col_heading level0 col5" >Data Type</th>
#         <th class="col_heading level0 col6" >Operation</th>
#         <th class="col_heading level0 col7" >Accuracy</th>
#         <th class="col_heading level0 col8" >Precision A</th>
#         <th class="col_heading level0 col9" >Precision B</th>
#         <th class="col_heading level0 col10" >Recall A</th>
# ...

# %%
dataset_stats_breast = helper.loadDatasetResults("Ionosphere", "Test", -1, True)
# Out:
# <style  type="text/css" >
#     #T_df51bb00_8a30_11e9_8382_54271ee7616arow0_col21 {
#             font-weight:  bold;
#              text-decoration:  underline;
#         }    #T_df51bb00_8a30_11e9_8382_54271ee7616arow1_col21 {
#             font-weight:  bold;
#              text-decoration:  underline;
#         }</style>
# <table id="T_df51bb00_8a30_11e9_8382_54271ee7616a" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Test type</th>
#         <th class="col_heading level0 col1" >Dataset</th>
#         <th class="col_heading level0 col2" >Style</th>
#         <th class="col_heading level0 col3" >Gausses</th>
#         <th class="col_heading level0 col4" >Adjustment</th>
#         <th class="col_heading level0 col5" >Data Type</th>
#         <th class="col_heading level0 col6" >Operation</th>
#         <th class="col_heading level0 col7" >Accuracy</th>
#         <th class="col_heading level0 col8" >Precision A</th>
# ...

# %%
dataset_stats_breast = helper.loadDatasetResults("Breast Cancer Data", "Test", -1, True)
# Out:
# <style  type="text/css" >
#     #T_df9fdb08_8a30_11e9_bd9c_54271ee7616arow0_col21 {
#             font-weight:  bold;
#              text-decoration:  underline;
#         }</style>
# <table id="T_df9fdb08_8a30_11e9_bd9c_54271ee7616a" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Test type</th>
#         <th class="col_heading level0 col1" >Dataset</th>
#         <th class="col_heading level0 col2" >Style</th>
#         <th class="col_heading level0 col3" >Gausses</th>
#         <th class="col_heading level0 col4" >Adjustment</th>
#         <th class="col_heading level0 col5" >Data Type</th>
#         <th class="col_heading level0 col6" >Operation</th>
#         <th class="col_heading level0 col7" >Accuracy</th>
#         <th class="col_heading level0 col8" >Precision A</th>
#         <th class="col_heading level0 col9" >Precision B</th>
#         <th class="col_heading level0 col10" >Recall A</th>
# ...

# %%
dataset_stats_wisconsin = helper.loadDatasetResults("Breast Cancer Wisconsin", "Test", -1, True)
# Out:
# <style  type="text/css" >
#     #T_dfe373c0_8a30_11e9_a3c3_54271ee7616arow0_col21 {
#             font-weight:  bold;
#              text-decoration:  underline;
#         }</style>
# <table id="T_dfe373c0_8a30_11e9_a3c3_54271ee7616a" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Test type</th>
#         <th class="col_heading level0 col1" >Dataset</th>
#         <th class="col_heading level0 col2" >Style</th>
#         <th class="col_heading level0 col3" >Gausses</th>
#         <th class="col_heading level0 col4" >Adjustment</th>
#         <th class="col_heading level0 col5" >Data Type</th>
#         <th class="col_heading level0 col6" >Operation</th>
#         <th class="col_heading level0 col7" >Accuracy</th>
#         <th class="col_heading level0 col8" >Precision A</th>
#         <th class="col_heading level0 col9" >Precision B</th>
#         <th class="col_heading level0 col10" >Recall A</th>
# ...

# %%
dataset_stats_haberman = helper.loadDatasetResults("Haberman", "Test", -1, True)
# Out:
# <style  type="text/css" >
#     #T_e0872dd2_8a30_11e9_9421_54271ee7616arow0_col21 {
#             font-weight:  bold;
#              text-decoration:  underline;
#         }</style>
# <table id="T_e0872dd2_8a30_11e9_9421_54271ee7616a" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Test type</th>
#         <th class="col_heading level0 col1" >Dataset</th>
#         <th class="col_heading level0 col2" >Style</th>
#         <th class="col_heading level0 col3" >Gausses</th>
#         <th class="col_heading level0 col4" >Adjustment</th>
#         <th class="col_heading level0 col5" >Data Type</th>
#         <th class="col_heading level0 col6" >Operation</th>
#         <th class="col_heading level0 col7" >Accuracy</th>
#         <th class="col_heading level0 col8" >Precision A</th>
#         <th class="col_heading level0 col9" >Precision B</th>
#         <th class="col_heading level0 col10" >Recall A</th>
# ...

# %%
dataset_stats_heart = helper.loadDatasetResults("Heart", "Test", -1, True)
# Out:
# <style  type="text/css" >
#     #T_e0de4e7e_8a30_11e9_9514_54271ee7616arow0_col21 {
#             font-weight:  bold;
#              text-decoration:  underline;
#         }</style>
# <table id="T_e0de4e7e_8a30_11e9_9514_54271ee7616a" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Test type</th>
#         <th class="col_heading level0 col1" >Dataset</th>
#         <th class="col_heading level0 col2" >Style</th>
#         <th class="col_heading level0 col3" >Gausses</th>
#         <th class="col_heading level0 col4" >Adjustment</th>
#         <th class="col_heading level0 col5" >Data Type</th>
#         <th class="col_heading level0 col6" >Operation</th>
#         <th class="col_heading level0 col7" >Accuracy</th>
#         <th class="col_heading level0 col8" >Precision A</th>
#         <th class="col_heading level0 col9" >Precision B</th>
#         <th class="col_heading level0 col10" >Recall A</th>
# ...

# %%
dataset_stats_htru = helper.loadDatasetResults("HTRU", "Test", -1, True)
# Out:
# <style  type="text/css" >
#     #T_e125df90_8a30_11e9_a11c_54271ee7616arow0_col21 {
#             font-weight:  bold;
#              text-decoration:  underline;
#         }</style>
# <table id="T_e125df90_8a30_11e9_a11c_54271ee7616a" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Test type</th>
#         <th class="col_heading level0 col1" >Dataset</th>
#         <th class="col_heading level0 col2" >Style</th>
#         <th class="col_heading level0 col3" >Gausses</th>
#         <th class="col_heading level0 col4" >Adjustment</th>
#         <th class="col_heading level0 col5" >Data Type</th>
#         <th class="col_heading level0 col6" >Operation</th>
#         <th class="col_heading level0 col7" >Accuracy</th>
#         <th class="col_heading level0 col8" >Precision A</th>
#         <th class="col_heading level0 col9" >Precision B</th>
#         <th class="col_heading level0 col10" >Recall A</th>
# ...

# %%
dataset_stats_immunotherapy = helper.loadDatasetResults("Immunotherapy", "Test", -1, True)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-16-8859c3500277> in <module>()
# ----> 1 dataset_stats_immunotherapy = helper.loadDatasetResults("Immunotherapy", "Test", -1, True)
#
# ~\Documents\Studia\Magisterka\Projekt\Class\Helper.py in loadDatasetResults(self, dataset, data_type, head_number, show)
#      65
#      66     def loadDatasetResults(self, dataset, data_type, head_number = -1, show = True):
# ---> 67         df = pd.read_csv(open("Results/" + dataset + ".csv", "rb"))
#      68         df["Mean F-Score"] = (df["F-Score A"] + df["F-Score B"]) / 2
#      69         df = df.loc[~(df["Operation"] == "BruteForce K-Fold Threshold")]
#
# ...

# %%
dataset_stats_liver = helper.loadDatasetResults("Indian Liver Patient", "Test", -1, True)
# Out:
# <style  type="text/css" >
#     #T_f1299a36_8a30_11e9_bbf4_54271ee7616arow0_col21 {
#             font-weight:  bold;
#              text-decoration:  underline;
#         }</style>
# <table id="T_f1299a36_8a30_11e9_bbf4_54271ee7616a" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Test type</th>
#         <th class="col_heading level0 col1" >Dataset</th>
#         <th class="col_heading level0 col2" >Style</th>
#         <th class="col_heading level0 col3" >Gausses</th>
#         <th class="col_heading level0 col4" >Adjustment</th>
#         <th class="col_heading level0 col5" >Data Type</th>
#         <th class="col_heading level0 col6" >Operation</th>
#         <th class="col_heading level0 col7" >Accuracy</th>
#         <th class="col_heading level0 col8" >Precision A</th>
#         <th class="col_heading level0 col9" >Precision B</th>
#         <th class="col_heading level0 col10" >Recall A</th>
# ...

# %%
dataset_stats_pima = helper.loadDatasetResults("Pima Indians Diabetes", "Test", -1, True)
# Out:
# <style  type="text/css" >
#     #T_e2b97736_8a30_11e9_a6fc_54271ee7616arow0_col21 {
#             font-weight:  bold;
#              text-decoration:  underline;
#         }</style>
# <table id="T_e2b97736_8a30_11e9_a6fc_54271ee7616a" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Test type</th>
#         <th class="col_heading level0 col1" >Dataset</th>
#         <th class="col_heading level0 col2" >Style</th>
#         <th class="col_heading level0 col3" >Gausses</th>
#         <th class="col_heading level0 col4" >Adjustment</th>
#         <th class="col_heading level0 col5" >Data Type</th>
#         <th class="col_heading level0 col6" >Operation</th>
#         <th class="col_heading level0 col7" >Accuracy</th>
#         <th class="col_heading level0 col8" >Precision A</th>
#         <th class="col_heading level0 col9" >Precision B</th>
#         <th class="col_heading level0 col10" >Recall A</th>
# ...

# %%
results = pd.concat([dataset_stats_breast, dataset_stats_wisconsin, dataset_stats_banknote, dataset_stats_haberman, dataset_stats_heart, dataset_stats_htru, dataset_stats_immunotherapy, dataset_stats_liver, dataset_stats_pima])

best_results = results.groupby(["Dataset", "Gausses", "Style", "Adjustment"], as_index=False)["Mean F-Score"].max()
best_results["Style & Adjustment"] = best_results['Style'] + " | " + best_results['Adjustment']
best_results = best_results.drop(["Style", "Adjustment"], axis = 1)

# best_results["Dataset & Gausses"] = best_results['Dataset'] + " " + best_results['Gausses']
# best_results = best_results.drop(["Dataset", "Gausses"], axis = 1)
# best_results = best_results.drop(["Gausses"], axis = 1)
best_results = best_results.groupby(["Dataset", "Gausses", "Style & Adjustment"], as_index=False)["Mean F-Score"].max()

best_results.pivot_table(
        values='Mean F-Score', 
        index=['Dataset', 'Gausses'], 
        columns='Style & Adjustment', 
        aggfunc=np.max)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-dd87d72f112b> in <module>()
# ----> 1 results = pd.concat([dataset_stats_breast, dataset_stats_wisconsin, dataset_stats_banknote, dataset_stats_haberman, dataset_stats_heart, dataset_stats_htru, dataset_stats_immunotherapy, dataset_stats_liver, dataset_stats_pima])
#       2
#       3 best_results = results.groupby(["Dataset", "Gausses", "Style", "Adjustment"], as_index=False)["Mean F-Score"].max()
#       4 best_results["Style & Adjustment"] = best_results['Style'] + " | " + best_results['Adjustment']
#       5 best_results = best_results.drop(["Style", "Adjustment"], axis = 1)
#
# NameError: name 'dataset_stats_immunotherapy' is not defined

# %%
gauss_number = pd.concat([dataset_stats_breast, dataset_stats_wisconsin, dataset_stats_banknote, dataset_stats_haberman, dataset_stats_heart, dataset_stats_htru, dataset_stats_immunotherapy, dataset_stats_liver, dataset_stats_pima])

gauss_number = gauss_number.groupby
# Out:
# Style & Adjustment                    Gaussian Equal | Center  \
# Dataset                      Gausses
# Breast Cancer Data           3                       0.319357
#                              5                       0.595013
#                              7                       0.725109
#                              9                       0.828057
#                              11                      0.845625
# Breast Cancer Wisconsin      3                       0.940547
#                              5                       0.939707
#                              7                       0.873966
#                              9                       0.897773
#                              11                      0.897773
# Data Banknote Authentication 3                       0.734471
#                              5                       0.856653
#                              7                       0.955298
# ...

# %%
gauss_number = pd.concat([dataset_stats_breast, dataset_stats_wisconsin, dataset_stats_banknote, dataset_stats_haberman, dataset_stats_heart, dataset_stats_htru, dataset_stats_immunotherapy, dataset_stats_liver, dataset_stats_pima])

gauss_number = gauss_number.groupby
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-199-5086fe7162d6> in <module>()
# ----> 1 gauss_number = pd.concat([dataset_stats_breast, dataset_stats_wisconsin, dataset_stats_banknote, dataset_stats_haberman, dataset_stats_heart, dataset_stats_htru, dataset_stats_immunotherapy, dataset_stats_liver, dataset_stats_pima])
#       2
#       3 gauss_number = gauss_number.groupby
#
# NameError: name 'dataset_stats_breast' is not defined

# %%
display(best_results.pivot(index="Dataset", columns="Style & Adjustment", values="Gausses"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-7908d1c13bb5> in <module>()
# ----> 1 display(best_results.pivot(index="Dataset", columns="Style & Adjustment", values=["Gausses", "Mean F-Score"]))
#
# C:\Programy\Anaconda\envs\py35\lib\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    5189         """
#    5190         from pandas.core.reshape.reshape import pivot
# -> 5191         return pivot(self, index=index, columns=columns, values=values)
#    5192
#    5193     _shared_docs['pivot_table'] = """
#
# C:\Programy\Anaconda\envs\py35\lib\site-packages\pandas\core\reshape\reshape.py in pivot(self, index, columns, values)
#     407             indexed = self._constructor_sliced(self[values].values,
#     408                                                index=index)
# --> 409     return indexed.unstack(columns)
#     410
# ...

# %%
results = pd.concat([dataset_stats_breast, dataset_stats_wisconsin, dataset_stats_banknote, dataset_stats_haberman, dataset_stats_heart, dataset_stats_htru, dataset_stats_immunotherapy, dataset_stats_liver, dataset_stats_pima])

gausses_result = results.loc[(results["Data Type"] == "Test")].groupby(["Gausses", "Dataset"], as_index=False).max()
# display(gausses_result)
# !pip install -U seaborn

sns.set(style="whitegrid")
g = sns.catplot(x="Dataset", y="Mean F-Score", hue="Gausses", data=gausses_result, kind="bar", palette="muted", height=10, aspect=2)
g.despine(left=True)
g.set_ylabels("Accuracy")

# %%
results = pd.concat([dataset_stats_breast, dataset_stats_wisconsin, dataset_stats_banknote, dataset_stats_haberman, dataset_stats_heart, dataset_stats_htru, dataset_stats_immunotherapy, dataset_stats_liver, dataset_stats_pima])

gausses_result = results.loc[(results["Data Type"] == "Test")].groupby(["Gausses", "Dataset"], as_index=False).max()
# display(gausses_result)
# !pip install -U seaborn

sns.set(style="whitegrid")
g = sns.catplot(x="Dataset", y="Accuracy", hue="Gausses", data=gausses_result, kind="bar", palette="muted", height=10, aspect=2)
g.despine(left=True)
g.set_ylabels("Accuracy")

# %%
# stats_df["Samples Number"] = fuzzifier["Samples"].apply(lambda x: int(x.split("(")[0]))
# display(stats_df)
g = sns.catplot(x="Dataset", y="% changed s.", hue="Gausses", data=fuzzifier, kind="bar", palette="muted", height=10, aspect=2)
g.set_ylabels("% changed s.")
# g.set(yscale ='log')
g.despine(left=True)

# %%
g = sns.catplot(x="Dataset", y="% changed s.", hue="Gausses", data=stats_df, kind="bar", palette="muted", height=10, aspect=2)
g.despine(left=True)

# %%
stats_df["Samples Number"] = stats_df["Samples"].apply(lambda x: int(x.split("(")[0]))
display(stats_df)
g = sns.catplot(x="Dataset", y="Samples Number", data=stats_df, kind="bar", palette="muted", height=10, aspect=2)
g.set_ylabels("Samples Number")
g.set(yscale ='log')
g.despine(left=True)

# %%
results = pd.concat([dataset_stats_breast, dataset_stats_wisconsin, dataset_stats_banknote, dataset_stats_haberman, dataset_stats_heart, dataset_stats_htru, dataset_stats_immunotherapy, dataset_stats_liver, dataset_stats_pima])

gausses_result = results.loc[(results.Operation == "BruteForce Threshold")]
# !pip install -U seaborn

sns.set(style="whitegrid")
g = sns.catplot(x="Dataset", y="Accuracy", hue="Gausses", data=gausses_result, kind="bar", palette="muted", height=10, aspect=2)
g.despine(left=True)
g.set_ylabels("Accuracy")

# %%
results = pd.concat([dataset_stats_breast, dataset_stats_wisconsin, dataset_stats_banknote, dataset_stats_haberman, dataset_stats_heart, dataset_stats_htru, dataset_stats_immunotherapy, dataset_stats_liver, dataset_stats_pima])
gausses_result = results.loc[(results["Operation"] == "Value Threshold") & (results["Data Type"] == "Test")]

# !pip install -U seaborn
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
sns.set(style="whitegrid")
g = sns.catplot(x="Dataset", y="Accuracy", hue="Gausses", data=gausses_result, kind="bar", palette="muted", height=10, aspect=2)
g.despine(left=True)
g.set_ylabels("Accuracy")

# %%
results = pd.concat([dataset_stats_breast, dataset_stats_wisconsin, dataset_stats_banknote, dataset_stats_haberman, dataset_stats_heart, dataset_stats_htru, dataset_stats_immunotherapy, dataset_stats_liver, dataset_stats_pima])

gausses_result = results.loc[(results.Operation == "BruteForce Threshold")]
gausses_result["F-Score Average"] = (gausses_result["F-Score A"] + gausses_result["F-Score B"])/2
# !pip install -U seaborn
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# ax = sns.barplot(x="Gausses", y="Accuracy", data=adam)
# %matplotlib inline
sns.set(style="whitegrid")
# fig, ax = plt.subplots(figsize=(20,8))
# Draw a nested barplot to show survival for class and sex
g = sns.catplot(x="Dataset", y="Accuracy", hue="Gausses", data=gausses_result, kind="bar", palette="muted", height=10, aspect=2)
g.despine(left=True)
g.set_ylabels("Accuracy")

# %%
results = pd.concat([dataset_stats_breast, dataset_stats_wisconsin, dataset_stats_banknote, dataset_stats_haberman, dataset_stats_heart, dataset_stats_htru, dataset_stats_immunotherapy, dataset_stats_liver, dataset_stats_pima])

gausses_result = results.loc[(results.Gausses == 5) & (results["Data Type"] == "Train")]
gausses_result["F-Score Average"] = (gausses_result["F-Score A"] + gausses_result["F-Score B"])/2
# !pip install -U seaborn
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# ax = sns.barplot(x="Gausses", y="Accuracy", data=adam)
# %matplotlib inline
sns.set(style="whitegrid")
# fig, ax = plt.subplots(figsize=(20,8))
# Draw a nested barplot to show survival for class and sex
g = sns.catplot(x="Dataset", y="F-Score Average", hue="Operation", data=gausses_result, kind="bar", palette="muted", height=10, aspect=2)
g.despine(left=True)
g.set_ylabels("Accuracy")

# %%
results = pd.concat([dataset_stats_breast, dataset_stats_wisconsin, dataset_stats_banknote, dataset_stats_haberman, dataset_stats_heart, dataset_stats_htru, dataset_stats_immunotherapy, dataset_stats_liver, dataset_stats_pima])

gausses_result = results.loc[(results.Gausses == 5) & (results["Data Type"] == "Test")]
gausses_result["F-Score Average"] = (gausses_result["F-Score A"] + gausses_result["F-Score B"])/2
# !pip install -U seaborn
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# ax = sns.barplot(x="Gausses", y="Accuracy", data=adam)
# %matplotlib inline
sns.set(style="whitegrid")
# fig, ax = plt.subplots(figsize=(20,8))
# Draw a nested barplot to show survival for class and sex
g = sns.catplot(x="Dataset", y="F-Score Average", hue="Operation", data=gausses_result, kind="bar", palette="muted", height=10, aspect=2)
g.despine(left=True)
g.set_ylabels("Accuracy")

# %%
results = pd.concat([dataset_stats_breast, dataset_stats_wisconsin, dataset_stats_banknote, dataset_stats_haberman, dataset_stats_heart, dataset_stats_htru, dataset_stats_immunotherapy, dataset_stats_liver, dataset_stats_pima])

gausses_result = results.loc[(results.Gausses == 5)]
gausses_result["F-Score Average"] = (gausses_result["F-Score A"] + gausses_result["F-Score B"])/2
# !pip install -U seaborn
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# ax = sns.barplot(x="Gausses", y="Accuracy", data=adam)
# %matplotlib inline
sns.set(style="whitegrid")
# fig, ax = plt.subplots(figsize=(20,8))
# Draw a nested barplot to show survival for class and sex
g = sns.catplot(x="Dataset", y="Accuracy", hue="Operation", data=gausses_result, kind="bar", palette="muted", height=10, aspect=2)
g.despine(left=True)
g.set_ylabels("Accuracy")

# %%
datasets = ["Breast Cancer Data", "Breast Cancer Wisconsin", "Data Banknote Authentication", "Haberman", "Heart", "HTRU", "Immunotherapy", "Indian Liver Patient", "Pima Indians"]

for dataset in datasets:
    df = pickle.load(open("Pickle/" + dataset + "/3 Gausses/train_features_df.p", "rb"))
    print("Train:\t{}: {}".format(dataset, round(df.Decision.value_counts().max() / df.Decision.count(), 3)))
    
for dataset in datasets:
    df = pickle.load(open("Pickle/" + dataset + "/3 Gausses/test_features_df.p", "rb"))
    print("Test:\t{}: {}".format(dataset, round(df.Decision.value_counts().max() / df.Decision.count(), 3)))
