# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from Class.Helper import Helper as Helper
helper = Helper()

# %%
fuzzifier = pickle.load(open("C:/Users/Adam/Documents/Studia/Magisterka/Projekt/Test - Datasets/Summaries/Fuzzification Statistics.p", "rb"))
display(fuzzifier)
# Out:
#                      Dataset                 Style Gausses Adjustment  \
# 0         Breast Cancer Data  Gaussian Progressive       3       Mean
# 1         Breast Cancer Data  Gaussian Progressive       3     Center
# 2         Breast Cancer Data        Gaussian Equal       3       Mean
# 3         Breast Cancer Data        Gaussian Equal       3     Center
# 4         Breast Cancer Data  Gaussian Progressive       5       Mean
# 5         Breast Cancer Data  Gaussian Progressive       5     Center
# 6         Breast Cancer Data        Gaussian Equal       5       Mean
# 7         Breast Cancer Data        Gaussian Equal       5     Center
# 8         Breast Cancer Data  Gaussian Progressive       7       Mean
# 9         Breast Cancer Data  Gaussian Progressive       7     Center
# 10        Breast Cancer Data        Gaussian Equal       7       Mean
# 11        Breast Cancer Data        Gaussian Equal       7     Center
# ...

# %%
       if row[["F0", "F1", "F2"]].values is [0, 0, 0]:

# %%
for idx, row in fuzzifier.iterrows():
        if (row[["Implicants", "Features", "F. after reduct"]].values == [43, 5, 5]).all():
        print(idx)
    break
# Out:
# 0

# %%
dataset_stats_breast = helper.loadDatasetResults("Breast Cancer Data", "Test", -1, False)
dataset_stats_wisconsin = helper.loadDatasetResults("Breast Cancer Wisconsin", "Test", -1, False)
dataset_stats_banknote = helper.loadDatasetResults("Data Banknote Authentication", "Test", -1, False)
dataset_stats_haberman = helper.loadDatasetResults("Haberman", "Test", -1, False)
dataset_stats_heart = helper.loadDatasetResults("Heart", "Test", -1, False)
dataset_stats_htru = helper.loadDatasetResults("HTRU", "Test", -1, False)
