# %% [markdown]
# ## Preparation

# %% [markdown]
# ##### Import Functions

# %%
from Scripts.LoadCSV import LoadCSV as LoadCSV
from Scripts.Fuzzify import Fuzzify as Fuzzify
from Scripts.OptimizeBruteForceKFold import OptimizeBruteForceKFold as OptimizeBruteForceKFold
from Scripts.ValueTest import ValueTest as ValueTest
from Scripts.OptimizeBruteForce import OptimizeBruteForce as OptimizeBruteForce
from Class.Helper import Helper as Helper

# %% [markdown]
# ##### Import Settings

# %%
import Settings.SettingsHeart as settings

# %% [markdown]
# ##### Load CSV File

# %%
# loadCSV = LoadCSV()
# samples_stats, train_stats, test_stats, train_samples = loadCSV.worker(settings.variables)

# %% [markdown]
# ##### Fuzzify Data

# %%
# fuzzify = Fuzzify()
# changed_decisions, features_number_after_reduct, implicants_number, fuzzify_parameters = fuzzify.worker(settings.variables, "", -1)

# %%
# helper = Helper()

# fuzzification_data = [settings.variables["dataset_name"], settings.variables["gausses"], samples_stats, train_stats, test_stats, changed_decisions, round(changed_decisions / train_samples, 2), implicants_number, settings.variables["feature_numbers"], features_number_after_reduct]
# helper.saveFuzzificationStats(fuzzification_data)

# fuzzification_parameters_data = [settings.variables["dataset_name"], settings.variables["gausses"], settings.sigma_mean_params] + fuzzify_parameters
# helper.saveFuzzificationParameters(fuzzification_parameters_data)

# %% [markdown]
# ## Train Set - K-Fold

# %% [markdown]
# ##### Train Set | K-Fold - S Function Optymalization

# %%
# optimizeBruteForceKFold = OptimizeBruteForceKFold(settings.variables, settings.s_function_width)

# %%
# best_s_function_center, mean_s_function_center = optimizeBruteForceKFold.worker(settings.variables, settings.constraints, settings.s_function_width, settings.n_folds)

# %% [markdown]
# ## Test Set | K-Fold Test

# %%
# valueTest = ValueTest(settings.variables, settings.s_function_width, False)

# %% [markdown]
# ##### K-Fold Test Set | S Function Value

# %%
# valueTest.sOptymalizationWorker(settings.variables, best_s_function_center, "Test Value - K-Fold - Best Function Center")

# %%
# valueTest.sOptymalizationWorker(settings.variables, mean_s_function_center, "Test Value - K-Fold - Average Function Center")

# %% [markdown]
# ## Training Set

# %% [markdown]
# ##### Training Set | No Optymalization

# %%
valueTest = ValueTest(settings.variables, settings.s_function_width, True)
valueTest.noOptymalizationWorker(settings.variables)
# Out:
# -----------------------------------------------------------------------------------
# C:\Programy\Anaconda\envs\py35\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy: 0.45454545454545453
# Precision: [0.         0.45454545]
# Recall: [0. 1.]
# F-Score: [0.    0.625]
# Support: [132 110]
# -----------------------------------------------------------------------------------
# Center Point: 0.5
# Time: 68.24428129196167
# -----------------------------------------------------------------------------------
# <style  type="text/css" >
#     #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow0_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow1_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow2_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow3_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow4_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow5_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow6_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow7_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow8_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow9_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow12_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow13_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow14_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow16_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow17_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow19_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow22_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow23_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow24_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow25_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow30_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow33_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow34_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow38_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow39_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow40_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow42_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow43_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow44_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow46_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow47_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow48_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow49_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow50_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow53_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow54_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow57_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow58_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow59_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow62_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow63_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow64_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow68_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow69_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow70_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow72_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow73_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow75_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow76_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow77_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow80_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow81_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow82_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow83_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow84_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow85_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow87_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow89_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow90_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow92_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow93_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow94_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow96_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow97_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow101_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow106_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow107_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow110_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow112_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow113_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow117_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow118_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow121_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow123_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow124_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow125_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee7616arow129_col7 {
#             background-color:  green;
#         }    #T_5ad56ab4_72b4_11e9_a258_54271ee76

# %% [markdown]
# ##### Training Set | S Function Optymalization

# %%
optimizeBruteForce = OptimizeBruteForce(settings.variables, settings.s_function_width)

# %%
s_function_center = optimizeBruteForce.sFunctionsWorker(settings.variables, settings.constraints, settings.s_function_width)
# Out:
# C:\Programy\Anaconda\envs\py35\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy: 0.5454545454545454
# Precision: [0.54545455 0.        ]
# Recall: [1. 0.]
# F-Score: [0.70588235 0.        ]
# Support: [132 110]
# -----------------------------------------------------------------------------------
# Center Point: 0.0
# Train Accuracy: 0.5454545454545454
# Time: 911.210999250412
# -----------------------------------------------------------------------------------

# %% [markdown]
# ##### Training Set | Threshold Optymalization

# %%
threshold = optimizeBruteForce.thresholdWorker(settings.variables, s_function_center, settings.s_function_width)
# Out:
# C:\Programy\Anaconda\envs\py35\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy: 0.5454545454545454
# Precision: [0.54545455 0.        ]
# Recall: [1. 0.]
# F-Score: [0.70588235 0.        ]
# Support: [132 110]
# -----------------------------------------------------------------------------------
# Center Point: 0.0
# Threshold: 0.4988631094019286
# Train Accuracy: 0.5454545454545454
# Time: 32.02099943161011
# -----------------------------------------------------------------------------------

# %% [markdown]
# ## Test Set

# %% [markdown]
# ##### Test Set | No Optymalization

# %%
# valueTest = ValueTest(settings.variables, settings.s_function_width, False)
# valueTest.noOptymalizationWorker(settings.variables)

# %% [markdown]
# ##### Test Set | S Function Value

# %%
# valueTest.sOptymalizationWorker(settings.variables, s_function_center)

# %% [markdown]
# ##### Test Set | Threshold Value

# %%
# valueTest.thresholdWorker(settings.variables, s_function_center, threshold)
