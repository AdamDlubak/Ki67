# %% [markdown]
# ## Preparation

# %% [markdown]
# ##### Import Functions

# %%
from Scripts.LoadCSV import LoadCSV as LoadCSV
from Scripts.Fuzzify import Fuzzify as Fuzzify
from Scripts.OptimizeBruteForceKFold import OptimizeBruteForceKFold as OptimizeBruteForceKFold
from Scripts.ValueTest import ValueTest as ValueTest
from Scripts.OptimizeBruteForce import OptimizeBruteForce as OptimizeBruteForce
from Class.Helper import Helper as Helper

# %%
import sympy as sym
x,y = sym.symbols('x,y')
c1 = sym.Symbol('c1')
f = sym.Eq(2*x**2+y,1)
g = sym.Eq(x+2*y,c1)

sym.solve([f,g],(x,y))
# Out:
# [(-sqrt(-16*c1 + 33)/8 + 1/8, c1/2 + sqrt(-16*c1 + 33)/16 - 1/16),
#  (sqrt(-16*c1 + 33)/8 + 1/8, c1/2 - sqrt(-16*c1 + 33)/16 - 1/16)]

# %%
import numpy as np
from sympy import *
from sympy import symbols, Eq, solve, exp
import sympy.physics.units as units

x, sigma = symbols('x sigma')

eq1 = Eq(exp(-((x - 1/2) ** 2.) / sigma ** 2.) - 0.5)
eq2 = Eq(exp(-((x - 1/3) ** 2.) / sigma ** 2.) - 0.5)

res = solve((eq1,eq2), (x, sigma))

# %%
for x in res:
    if x[1] >= 0:
        res = x[1]
        break

# %%
res
# Out:
# 0.100093534065537

# %% [markdown]
# ##### Import Settings

# %%
import Settings.SettingsHeart as settings

# %% [markdown]
# ##### Load CSV File

# %%
# loadCSV = LoadCSV()
# samples_stats, train_stats, test_stats, train_samples = loadCSV.worker(settings.variables)

# %% [markdown]
# ##### Fuzzify Data

# %%
# fuzzify = Fuzzify()
# changed_decisions, features_number_after_reduct, implicants_number, fuzzify_parameters = fuzzify.worker(settings.variables, "", -1)

# %%
# helper = Helper()

# fuzzification_data = [settings.variables["dataset_name"], settings.variables["gausses"], samples_stats, train_stats, test_stats, changed_decisions, round(changed_decisions / train_samples, 2), implicants_number, settings.variables["feature_numbers"], features_number_after_reduct]
# helper.saveFuzzificationStats(fuzzification_data)

# fuzzification_parameters_data = [settings.variables["dataset_name"], settings.variables["gausses"], settings.sigma_mean_params] + fuzzify_parameters
# helper.saveFuzzificationParameters(fuzzification_parameters_data)

# %% [markdown]
# ## Train Set - K-Fold

# %% [markdown]
# ##### Train Set | K-Fold - S Function Optymalization

# %%
# optimizeBruteForceKFold = OptimizeBruteForceKFold(settings.variables, settings.s_function_width)

# %%
# best_s_function_center, mean_s_function_center = optimizeBruteForceKFold.worker(settings.variables, settings.constraints, settings.s_function_width, settings.n_folds)

# %% [markdown]
# ## Test Set | K-Fold Test

# %%
# valueTest = ValueTest(settings.variables, settings.s_function_width, False)

# %% [markdown]
# ##### K-Fold Test Set | S Function Value

# %%
# valueTest.sOptymalizationWorker(settings.variables, best_s_function_center, "Test Value - K-Fold - Best Function Center")

# %%
# valueTest.sOptymalizationWorker(settings.variables, mean_s_function_center, "Test Value - K-Fold - Average Function Center")

# %% [markdown]
# ## Training Set

# %% [markdown]
# ##### Training Set | No Optymalization

# %%
valueTest = ValueTest(settings.variables, settings.s_function_width, True)
valueTest.noOptymalizationWorker(settings.variables)
# Out:
# -----------------------------------------------------------------------------------
# Accuracy: 0.5495867768595041
# Precision: [0.54771784 1.        ]
# Recall: [1.         0.00909091]
# F-Score: [0.7077748  0.01801802]
# Support: [132 110]
# -----------------------------------------------------------------------------------
# Center Point: 0.5
# Time: 20.150442123413086
# -----------------------------------------------------------------------------------
# <style  type="text/css" >
#     #T_b82fc302_7374_11e9_813f_f07959376ad7row35_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row37_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row38_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row39_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row41_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row42_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row46_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row47_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row49_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row50_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row56_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row58_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row61_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row62_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row64_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row66_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row68_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row70_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row72_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row73_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row77_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row78_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row85_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row87_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row90_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row91_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row92_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row93_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row96_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row98_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row99_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row100_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row102_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row104_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row109_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row112_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row115_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row117_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row118_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row121_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row127_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row130_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row132_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row133_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row136_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row138_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row141_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row142_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row143_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row145_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row148_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row150_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row153_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row155_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row158_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row159_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row160_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row161_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row163_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row165_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row167_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row171_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row175_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row176_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row179_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row182_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row185_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row191_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row192_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row194_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row195_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row198_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row199_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row200_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row203_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row204_col8 {
#             background-color:  green;
#         }    #T_b82fc302_7374_11e9_813f_f07959376ad7row205_col8 {
#             background-color:  green;

# %% [markdown]
# ##### Training Set | S Function Optymalization

# %%
optimizeBruteForce = OptimizeBruteForce(settings.variables, settings.s_function_width)

# %%
s_function_center = optimizeBruteForce.sFunctionsWorker(settings.variables, settings.constraints, settings.s_function_width)
# Out:
# Accuracy: 0.5495867768595041
# Precision: [0.54771784 1.        ]
# Recall: [1.         0.00909091]
# F-Score: [0.7077748  0.01801802]
# Support: [132 110]
# -----------------------------------------------------------------------------------
# Center Point: 0.5
# Train Accuracy: 0.5495867768595041
# Time: 954.6226897239685
# -----------------------------------------------------------------------------------
#            F0        F4        F7        F3   F6  F10   F1        F9 Decision  \
# 124  0.208333  0.166667  0.824427  0.000000  0.5  1.0  0.0  0.000000      One
# 115  0.166667  0.203196  0.755725  0.245283  0.5  1.0  0.0  0.000000      One
# 134  0.250000  0.410959  0.702290  0.301887  0.5  1.0  0.0  0.000000      One
# 93   0.520833  0.369863  0.671756  0.358491  0.0  1.0  0.0  0.000000      One
# 157  0.125000  0.150685  0.786260  0.264151  0.5  1.0  1.0  0.000000      One
# 74   0.291667  0.198630  0.717557  0.264151  0.5  0.5  0.0  0.032258      One
# 113  0.291667  0.194064  0.687023  0.150943  0.5  1.0  1.0  0.000000      One
# 111  0.583333  0.000000  0.778626  0.528302  0.5  1.0  1.0  0.032258      One
# 87   0.354167  0.162100  0.648855  0.066038  0.5  1.0  1.0  0.000000      One
# 118  0.354167  0.178082  0.770992  0.103774  0.5  1.0  0.0  0.000000      One
# 30   0.250000  0.164384  0.740458  0.103774  0.5  1.0  0.0  0.000000      One
# 148  0.312500  0.228311  0.748092  0.245283  0.5  1.0  1.0  0.000000      One
# 17   0.770833  0.228311  0.328244  0.528302  0.5  0.0  0.0  0.419355      One
# 69   0.687500  0.189498  0.702290  0.283019  0.5  1.0  0.0  0.000000      One
# 121  0.625000  0.331050  0.847328  0.415094  0.0  1.0  1.0  0.000000      One
# 77   0.625000  0.216895  0.709924  0.433962  0.5  1.0  1.0  0.000000      One
# 56   0.395833  0.219178  0.877863  0.264151  0.0  1.0  1.0  0.000000      One
# 22   0.270833  0.228311  0.816794  0.433962  0.5  1.0  1.0  0.000000      One
# 102  0.708333  0.157534  0.824427  0.433962  0.5  1.0  0.0  0.000000      One
# 156  0.375000  0.289954  0.824427  0.339623  0.5  1.0  1.0  0.000000      One
# 95   0.500000  0.228311  0.305344  0.452830  0.0  1.0  1.0  0.000000      One
# 91   0.583333  0.184932  0.740458  0.358491  0.5  1.0  1.0  0.000000      One
# 122  0.250000  0.324201  0.770992  0.169811  0.0  1.0  0.0  0.000000      One
# 46   0.312500  0.248858  0.832061  0.433962  0.0  1.0  1.0  0.000000      One
# 90   0.395833  0.294521  0.793893  0.283019  0.5  1.0  1.0  0.000000      One
# 82   0.645833  0.438356  0.679389  0.075472  0.5  1.0  0.0  0.000000      One
# 11   0.395833  0.340183  0.519084  0.339623  0.5  1.0  0.0  0.032258      One
# 32   0.312500  0.212329  0.893130  0.339623  0.0  1.0  1.0  0.000000      One
# 1    0.166667  0.283105  0.885496  0.339623  0.5  0.0  1.0  0.564516      One
# 149  0.270833  0.123288  0.603053  0.339623  0.5  1.0  1.0  0.000000      One
# ..        ...       ...       ...       ...  ...  ...  ...       ...      ...
# 256  0.604167  0.303653  0.450382  0.320755  0.0  0.5  1.0  0.483871     Zero
# 177  0.729167  0.477169  0.664122  0.433962  0.5  1.0  1.0  0.000000     Zero
# 178  0.291667  0.116438  0.374046  0.245283  0.0  0.5  1.0  0.403226     Zero
# 167  0.687500  0.324201  0.679389  0.433962  0.0  0.0  0.0  0.580645     Zero
# 209  0.625000  0.116438  0.694656  0.433962  0.5  1.0  1.0  0.000000     Zero
# 201  0.645833  0.301370  0.534351  0.292453  0.0  0.5  1.0  0.451613     Zero
# 207  0.645833  0.301370  0.656489  0.528302  0.0  0.5  0.0  0.419355     Zero
# 211  0.666667  0.305936  0.526718  0.245283  0.5  0.5  1.0  0.580645     Zero
# 223  0.562500  0.369863  0.473282  1.000000  0.0  0.0  0.0  0.645161     Zero
# 182  0.666667  0.465753  0.748092  0.339623  0.0  1.0  0.0  0.000000     Zero
# 279  0.666667  0.091324  0.412214  0.415094  0.0  0.5  1.0  0.580645     Zero
# 247  0.770833  0.273973  0.374046  0.622642  0.5  0.5  1.0  0.000000     Zero
# 219  0.395833  0.296804  0.603053  0.339623  0.0  1.0  1.0  0.000000     Zero
# 244  0.562500  0.132420  0.259542  0.358491  0.0  0.5  1.0  0.338710     Zero
# 254  0.625000  0.335616  0.412214  0.622642  0.0  1.0  1.0  0.000000     Zero
# 248  0.520833  0.358447  0.946565  0.924528  0.0  1.0  1.0  0.000000     Zero
# 241  0.625000  0.280822  0.549618  0.754717  0.5  0.5  0.0  0.000000     Zero
# 187  0.520833  0.319635  0.290076  0.283019  0.0  0.5  1.0  0.354839     Zero
# 240  0.854167  0.326484  0.312977  0.622642  0.5  0.5  1.0  0.467742     Zero
# 204  0.687500  0.086758  0.564885  0.622642  0.0  0.0  0.0  1.000000     Zero
# 268  0.520833  0.365297  0.343511  0.264151  0.0  0.5  1.0  0.516129     Zero
# 295  0.708333  0.139269  0.557252  0.433962  0.0  1.0  1.0  0.645161     Zero
# 194  0.645833  0.134703  0.641221  0.433962  0.0  0.5  1.0  0.483871     Zero
# 221  0.541667  0.207763  0.305344  0.433962  0.5  0.0  1.0  0.903226     Zero
# 195  0.625000  0.456621  0.526718  0.716981  0.0  0.0  1.0  0.548387     Zero
# 218  0.750000  0.292237  0.427481  0.386792  0.0  0.5  1.0  0.451613     Zero
# 184  0.437500  0.267123  0.435115  0.528302  0.0  0.5  1.0  0.419355     Zero
# 215  0.291667  0.490868  0.496183  0.358491  0.0  0.5  0.0  0.483871     Zero
# 233  0.729167  0.273973  0.190840  0.245283  0.0  0.0  1.0  0.354839     Zero
# 166  0.791667  0.235160  0.442748  0.245283  0.0  0.5  1.0  0.419355     Zero
#
#     Decision Fuzzy  Predicted Value
# 124            One         0.485588
# 115            One         0.490587
# 134            One         0.491018
# 93             One         0.492055
# 157            One         0.492304
# 74             One         0.492816
# 113            One         0.493152
# 111            One         0.493461
# 87             One         0.493474
# 118            One         0.493623
# 30             One         0.493623
# 148            One         0.493656
# 17             One         0.493656
# 69             One         0.493688
# 121            One         0.493689
# 77             One         0.493689
# 56             One         0.493689
# 22             One         0.493689
# 102            One         0.493689
# 156            One         0.493689
# 95             One         0.493689
# 91             One         0.493689
# 122            One         0.493689
# 46             One         0.493689
# 90             One         0.493689
# 82             One         0.493742
# 11             One         0.493754
# 32             One         0.493754
# 1              One         0.493754
# 149            One         0.493754
# ..             ...              ...
# 256            One         0.493872
# 177            One         0.493873
# 178            One         0.493883
# 167            One         0.493885
# 209            One         0.493926
# 201            One         0.493926
# 207            One         0.493926
# 211            One         0.493963
# 223            One         0.493987
# 182            One         0.493987
# 279            One         0.493988
# 247            One         0.494070
# 219            One         0.494076
# 244            One         0.494137
# 254            One         0.494159
# 248            One         0.494159
# 241            One         0.494159
# 187            One         0.494161
# 240            One         0.494201
# 204            One         0.494516
# 268            One         0.494531
# 295            One         0.494532
# 194            One         0.494532
# 221            One         0.494532
# 195            One         0.494707
# 218            One         0.495180
# 184            One         0.495221
# 215            One         0.495985
# 233            One         0.496007
# 166           Zero         0.511452
#
# [242 rows x 11 columns]

# %% [markdown]
# ##### Training Set | Threshold Optymalization

# %%
threshold = optimizeBruteForce.thresholdWorker(settings.variables, s_function_center, settings.s_function_width)
# Out:
# Accuracy: 0.6528925619834711
# Precision: [0.61111111 1.        ]
# Recall: [1.         0.23636364]
# F-Score: [0.75862069 0.38235294]
# Support: [132 110]
# -----------------------------------------------------------------------------------
# Center Point: 0.5
# Threshold: 0.49391183238290104
# Train Accuracy: 0.6528925619834711
# Time: 22.647278547286987
# -----------------------------------------------------------------------------------
#            F0        F4        F3   F1   F6  F10        F9        F7 Decision  \
# 124  0.208333  0.166667  0.000000  0.0  0.5  1.0  0.000000  0.824427      One
# 115  0.166667  0.203196  0.245283  0.0  0.5  1.0  0.000000  0.755725      One
# 134  0.250000  0.410959  0.301887  0.0  0.5  1.0  0.000000  0.702290      One
# 93   0.520833  0.369863  0.358491  0.0  0.0  1.0  0.000000  0.671756      One
# 157  0.125000  0.150685  0.264151  1.0  0.5  1.0  0.000000  0.786260      One
# 74   0.291667  0.198630  0.264151  0.0  0.5  0.5  0.032258  0.717557      One
# 113  0.291667  0.194064  0.150943  1.0  0.5  1.0  0.000000  0.687023      One
# 111  0.583333  0.000000  0.528302  1.0  0.5  1.0  0.032258  0.778626      One
# 87   0.354167  0.162100  0.066038  1.0  0.5  1.0  0.000000  0.648855      One
# 118  0.354167  0.178082  0.103774  0.0  0.5  1.0  0.000000  0.770992      One
# 30   0.250000  0.164384  0.103774  0.0  0.5  1.0  0.000000  0.740458      One
# 148  0.312500  0.228311  0.245283  1.0  0.5  1.0  0.000000  0.748092      One
# 17   0.770833  0.228311  0.528302  0.0  0.5  0.0  0.419355  0.328244      One
# 69   0.687500  0.189498  0.283019  0.0  0.5  1.0  0.000000  0.702290      One
# 121  0.625000  0.331050  0.415094  1.0  0.0  1.0  0.000000  0.847328      One
# 77   0.625000  0.216895  0.433962  1.0  0.5  1.0  0.000000  0.709924      One
# 56   0.395833  0.219178  0.264151  1.0  0.0  1.0  0.000000  0.877863      One
# 22   0.270833  0.228311  0.433962  1.0  0.5  1.0  0.000000  0.816794      One
# 102  0.708333  0.157534  0.433962  0.0  0.5  1.0  0.000000  0.824427      One
# 156  0.375000  0.289954  0.339623  1.0  0.5  1.0  0.000000  0.824427      One
# 95   0.500000  0.228311  0.452830  1.0  0.0  1.0  0.000000  0.305344      One
# 91   0.583333  0.184932  0.358491  1.0  0.5  1.0  0.000000  0.740458      One
# 122  0.250000  0.324201  0.169811  0.0  0.0  1.0  0.000000  0.770992      One
# 46   0.312500  0.248858  0.433962  1.0  0.0  1.0  0.000000  0.832061      One
# 90   0.395833  0.294521  0.283019  1.0  0.5  1.0  0.000000  0.793893      One
# 82   0.645833  0.438356  0.075472  0.0  0.5  1.0  0.000000  0.679389      One
# 11   0.395833  0.340183  0.339623  0.0  0.5  1.0  0.032258  0.519084      One
# 32   0.312500  0.212329  0.339623  1.0  0.0  1.0  0.000000  0.893130      One
# 1    0.166667  0.283105  0.339623  1.0  0.5  0.0  0.564516  0.885496      One
# 149  0.270833  0.123288  0.339623  1.0  0.5  1.0  0.000000  0.603053      One
# ..        ...       ...       ...  ...  ...  ...       ...       ...      ...
# 256  0.604167  0.303653  0.320755  1.0  0.0  0.5  0.483871  0.450382     Zero
# 177  0.729167  0.477169  0.433962  1.0  0.5  1.0  0.000000  0.664122     Zero
# 178  0.291667  0.116438  0.245283  1.0  0.0  0.5  0.403226  0.374046     Zero
# 167  0.687500  0.324201  0.433962  0.0  0.0  0.0  0.580645  0.679389     Zero
# 209  0.625000  0.116438  0.433962  1.0  0.5  1.0  0.000000  0.694656     Zero
# 201  0.645833  0.301370  0.292453  1.0  0.0  0.5  0.451613  0.534351     Zero
# 207  0.645833  0.301370  0.528302  0.0  0.0  0.5  0.419355  0.656489     Zero
# 211  0.666667  0.305936  0.245283  1.0  0.5  0.5  0.580645  0.526718     Zero
# 223  0.562500  0.369863  1.000000  0.0  0.0  0.0  0.645161  0.473282     Zero
# 182  0.666667  0.465753  0.339623  0.0  0.0  1.0  0.000000  0.748092     Zero
# 279  0.666667  0.091324  0.415094  1.0  0.0  0.5  0.580645  0.412214     Zero
# 247  0.770833  0.273973  0.622642  1.0  0.5  0.5  0.000000  0.374046     Zero
# 219  0.395833  0.296804  0.339623  1.0  0.0  1.0  0.000000  0.603053     Zero
# 244  0.562500  0.132420  0.358491  1.0  0.0  0.5  0.338710  0.259542     Zero
# 254  0.625000  0.335616  0.622642  1.0  0.0  1.0  0.000000  0.412214     Zero
# 248  0.520833  0.358447  0.924528  1.0  0.0  1.0  0.000000  0.946565     Zero
# 241  0.625000  0.280822  0.754717  0.0  0.5  0.5  0.000000  0.549618     Zero
# 187  0.520833  0.319635  0.283019  1.0  0.0  0.5  0.354839  0.290076     Zero
# 240  0.854167  0.326484  0.622642  1.0  0.5  0.5  0.467742  0.312977     Zero
# 204  0.687500  0.086758  0.622642  0.0  0.0  0.0  1.000000  0.564885     Zero
# 268  0.520833  0.365297  0.264151  1.0  0.0  0.5  0.516129  0.343511     Zero
# 295  0.708333  0.139269  0.433962  1.0  0.0  1.0  0.645161  0.557252     Zero
# 194  0.645833  0.134703  0.433962  1.0  0.0  0.5  0.483871  0.641221     Zero
# 221  0.541667  0.207763  0.433962  1.0  0.5  0.0  0.903226  0.305344     Zero
# 195  0.625000  0.456621  0.716981  1.0  0.0  0.0  0.548387  0.526718     Zero
# 218  0.750000  0.292237  0.386792  1.0  0.0  0.5  0.451613  0.427481     Zero
# 184  0.437500  0.267123  0.528302  1.0  0.0  0.5  0.419355  0.435115     Zero
# 215  0.291667  0.490868  0.358491  0.0  0.0  0.5  0.483871  0.496183     Zero
# 233  0.729167  0.273973  0.245283  1.0  0.0  0.0  0.354839  0.190840     Zero
# 166  0.791667  0.235160  0.245283  1.0  0.0  0.5  0.419355  0.442748     Zero
#
#     Decision Fuzzy  Predicted Value
# 124            One         0.485588
# 115            One         0.490587
# 134            One         0.491018
# 93             One         0.492055
# 157            One         0.492304
# 74             One         0.492816
# 113            One         0.493152
# 111            One         0.493461
# 87             One         0.493474
# 118            One         0.493623
# 30             One         0.493623
# 148            One         0.493656
# 17             One         0.493656
# 69             One         0.493688
# 121            One         0.493689
# 77             One         0.493689
# 56             One         0.493689
# 22             One         0.493689
# 102            One         0.493689
# 156            One         0.493689
# 95             One         0.493689
# 91             One         0.493689
# 122            One         0.493689
# 46             One         0.493689
# 90             One         0.493689
# 82             One         0.493742
# 11             One         0.493754
# 32             One         0.493754
# 1              One         0.493754
# 149            One         0.493754
# ..             ...              ...
# 256            One         0.493872
# 177            One         0.493873
# 178            One         0.493883
# 167            One         0.493885
# 209           Zero         0.493926
# 201           Zero         0.493926
# 207           Zero         0.493926
# 211           Zero         0.493963
# 223           Zero         0.493987
# 182           Zero         0.493987
# 279           Zero         0.493988
# 247           Zero         0.494070
# 219           Zero         0.494076
# 244           Zero         0.494137
# 254           Zero         0.494159
# 248           Zero         0.494159
# 241           Zero         0.494159
# 187           Zero         0.494161
# 240           Zero         0.494201
# 204           Zero         0.494516
# 268           Zero         0.494531
# 295           Zero         0.494532
# 194           Zero         0.494532
# 221           Zero         0.494532
# 195           Zero         0.494707
# 218           Zero         0.495180
# 184           Zero         0.495221
# 215           Zero         0.495985
# 233           Zero         0.496007
# 166           Zero         0.511452
#
# [242 rows x 11 columns]

# %%
import pickle
fuzzifier = pickle.load(open(settings.variables["backup_folder"] + "decision.p", "rb"))
fuzzifier.view()
# Out:
# D:\Anaconda\envs\py35\lib\site-packages\matplotlib\figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# ## Test Set

# %% [markdown]
# ##### Test Set | No Optymalization

# %%
# valueTest = ValueTest(settings.variables, settings.s_function_width, False)
# valueTest.noOptymalizationWorker(settings.variables)

# %% [markdown]
# ##### Test Set | S Function Value

# %%
# valueTest.sOptymalizationWorker(settings.variables, s_function_center)

# %% [markdown]
# ##### Test Set | Threshold Value

# %%
# valueTest.thresholdWorker(settings.variables, s_function_center, threshold)
