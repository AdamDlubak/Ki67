# %% [markdown]
# ## Preparation

# %% [markdown]
# ##### Import Functions

# %%
from Scripts.LoadCSV import LoadCSV as LoadCSV
from Scripts.Fuzzify import Fuzzify as Fuzzify
from Scripts.OptimizeBruteForceKFold import OptimizeBruteForceKFold as OptimizeBruteForceKFold
from Scripts.ValueTest import ValueTest as ValueTest
from Scripts.OptimizeBruteForce import OptimizeBruteForce as OptimizeBruteForce
from Class.Helper import Helper as Helper

# %% [markdown]
# ##### Import Settings

# %%
import Settings.SettingsDataBanknoteAuthentication as settings

# %% [markdown]
# ##### Load CSV File

# %%
# loadCSV = LoadCSV()
# samples_stats, train_stats, test_stats, train_samples = loadCSV.worker(settings.variables)

# %% [markdown]
# ##### Fuzzify Data

# %%
# fuzzify = Fuzzify()
# changed_decisions, features_number_after_reduct, implicants_number, fuzzify_parameters = fuzzify.worker(settings.variables, "", -1)

# %%
# helper = Helper()

# fuzzification_data = [settings.variables["dataset_name"], settings.variables["gausses"], samples_stats, train_stats, test_stats, changed_decisions, round(changed_decisions / train_samples, 2), implicants_number, settings.variables["feature_numbers"], features_number_after_reduct]
# helper.saveFuzzificationStats(fuzzification_data)

# fuzzification_parameters_data = [settings.variables["dataset_name"], settings.variables["gausses"], settings.sigma_mean_params] + fuzzify_parameters
# helper.saveFuzzificationParameters(fuzzification_parameters_data)

# %% [markdown]
# ## Train Set - K-Fold

# %% [markdown]
# ##### Train Set | K-Fold - S Function Optymalization

# %%
# optimizeBruteForceKFold = OptimizeBruteForceKFold(settings.variables, settings.s_function_width)

# %%
# best_s_function_center, mean_s_function_center = optimizeBruteForceKFold.worker(settings.variables, settings.constraints, settings.s_function_width, settings.n_folds)

# %% [markdown]
# ### Test Set | K-Fold Test

# %%
# valueTest = ValueTest(settings.variables, settings.s_function_width, False)

# %% [markdown]
# ##### K-Fold Test Set | S Function Value

# %%
# valueTest.sOptymalizationWorker(settings.variables, best_s_function_center, "Test Value - K-Fold - Best Function Center")

# %%
# valueTest.sOptymalizationWorker(settings.variables, mean_s_function_center, "Test Value - K-Fold - Average Function Center")

# %% [markdown]
# ## Training Set

# %% [markdown]
# ##### Training Set | No Optymalization

# %%
valueTest = ValueTest(settings.variables, settings.s_function_width, True)
valueTest.noOptymalizationWorker(settings.variables)
# Out:
# -----------------------------------------------------------------------------------
# Accuracy: 0.6608933454876937
# Precision: [1.         0.62079511]
# Recall: [0.23770492 1.        ]
# F-Score: [0.38410596 0.76603774]
# Support: [488 609]
# -----------------------------------------------------------------------------------
# Center Point: 0.5
# Time: 50.97471761703491
# -----------------------------------------------------------------------------------
# <style  type="text/css" >
#     #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow478_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow481_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow482_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow486_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow488_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow490_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow491_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow492_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow494_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow495_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow496_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow498_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow499_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow503_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow504_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow505_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow507_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow508_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow510_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow512_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow515_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow523_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow524_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow525_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow526_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow527_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow528_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow530_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow531_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow533_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow536_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow537_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow539_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow541_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow543_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow544_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow546_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow547_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow548_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow549_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow550_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow552_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow553_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow554_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow555_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow556_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow557_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow558_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow559_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow561_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow562_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow563_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow567_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow568_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow569_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow571_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow573_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow575_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow576_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow579_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow580_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow581_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow583_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow585_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow587_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow588_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow593_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow594_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow596_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow597_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow598_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow599_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow602_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow603_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow604_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow608_col4 {
#             background-color:  green;
#         }    #T_57cf5e4c_72b4_11e9_a84b_54271ee7616arow609_col4 {
#             b

# %% [markdown]
# ##### Training Set | S Function Optymalization

# %%
optimizeBruteForce = OptimizeBruteForce(settings.variables, settings.s_function_width)

# %%
s_function_center = optimizeBruteForce.sFunctionsWorker(settings.variables, settings.constraints, settings.s_function_width)
# Out:
# Accuracy: 0.8851412944393802
# Precision: [0.79478827 1.        ]
# Recall: [1.         0.79310345]
# F-Score: [0.88566243 0.88461538]
# Support: [488 609]
# -----------------------------------------------------------------------------------
# Center Point: 0.4949996948242189
# Train Accuracy: 0.8851412944393802
# Time: 1469.8169977664948
# -----------------------------------------------------------------------------------

# %%
data = pd.read_csv(settings.variables['results_folder'] + settings.variables["results_file"])
display(data)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-14-868651b31d8f> in <module>()
# ----> 1 data = pd.read_csv(settings.variables['results_folder'] + settings.variables["results_file"])
#       2 display(data)
#
# C:\Programy\Anaconda\envs\py35\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# C:\Programy\Anaconda\envs\py35\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     444
#     445     try:
# --> 446         data = parser.read(nrows)
#     447     finally:
#     448         parser.close()
#
# C:\Programy\Anaconda\envs\py35\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1034                 raise ValueError('skipfooter not supported for iteration')
#    1035
# -> 1036         ret = self._engine.read(nrows)
#    1037
#    1038         # May alter columns / col_dict
#
# C:\Programy\Anaconda\envs\py35\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1846     def read(self, nrows=None):
#    1847         try:
# -> 1848             data = self._reader.read(nrows)
#    1849         except StopIteration:
#    1850             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 17 fields in line 12, saw 19

# %% [markdown]
# ##### Training Set | Threshold Optymalization

# %%
# threshold = optimizeBruteForce.thresholdWorker(settings.variables, s_function_center, settings.s_function_width)

# %% [markdown]
# ## Test Set

# %% [markdown]
# ##### Test Set | No Optymalization

# %%
# valueTest = ValueTest(settings.variables, settings.s_function_width, False)
# valueTest.noOptymalizationWorker(settings.variables)

# %% [markdown]
# ##### Test Set | S Function Value

# %%
# valueTest.sOptymalizationWorker(settings.variables, s_function_center)

# %% [markdown]
# ##### Test Set | Threshold Value

# %%
# valueTest.thresholdWorker(settings.variables, s_function_center, threshold)
