# %% [markdown]
# ## Preparation

# %% [markdown]
# ##### Import Functions

# %%
from Scripts.LoadCSV import LoadCSV as LoadCSV
from Scripts.Fuzzify import Fuzzify as Fuzzify
from Scripts.OptimizeBruteForceKFold import OptimizeBruteForceKFold as OptimizeBruteForceKFold
from Scripts.ValueTest import ValueTest as ValueTest
from Scripts.OptimizeBruteForce import OptimizeBruteForce as OptimizeBruteForce
from Class.Helper import Helper as Helper

# %% [markdown]
# ##### Import Settings

# %%
import Settings.SettingsImmunotherapy as settings

# %% [markdown]
# ##### Load CSV File

# %%
# loadCSV = LoadCSV()
# samples_stats, train_stats, test_stats, train_samples = loadCSV.worker(settings.variables)

# %% [markdown]
# ##### Fuzzify Data

# %%
# fuzzify = Fuzzify()
# changed_decisions, features_number_after_reduct, implicants_number, fuzzify_parameters = fuzzify.worker(settings.variables, "", -1)

# %%
# helper = Helper()

# fuzzification_data = [settings.variables["dataset_name"], settings.variables["gausses"], samples_stats, train_stats, test_stats, changed_decisions, round(changed_decisions / train_samples, 2), implicants_number, settings.variables["feature_numbers"], features_number_after_reduct]
# helper.saveFuzzificationStats(fuzzification_data)

# fuzzification_parameters_data = [settings.variables["dataset_name"], settings.variables["gausses"], settings.sigma_mean_params] + fuzzify_parameters
# helper.saveFuzzificationParameters(fuzzification_parameters_data)

# %% [markdown]
# ## Train Set - K-Fold

# %% [markdown]
# ##### Train Set | K-Fold - S Function Optymalization

# %%
# optimizeBruteForceKFold = OptimizeBruteForceKFold(settings.variables, settings.s_function_width)

# %%
# best_s_function_center, mean_s_function_center = optimizeBruteForceKFold.worker(settings.variables, settings.constraints, settings.s_function_width, settings.n_folds)

# %% [markdown]
# ## Test Set | K-Fold Test

# %%
# valueTest = ValueTest(settings.variables, settings.s_function_width, False)

# %% [markdown]
# ##### K-Fold Test Set | S Function Value

# %%
# valueTest.sOptymalizationWorker(settings.variables, best_s_function_center, "Test Value - K-Fold - Best Function Center")

# %%
# valueTest.sOptymalizationWorker(settings.variables, mean_s_function_center, "Test Value - K-Fold - Average Function Center")

# %% [markdown]
# ## Training Set

# %% [markdown]
# ##### Training Set | No Optymalization

# %%
valueTest = ValueTest(settings.variables, settings.s_function_width, True)
valueTest.noOptymalizationWorker(settings.variables)
# Out:
# -----------------------------------------------------------------------------------
# D:\Anaconda\envs\py35\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy: 0.20833333333333334
# Precision: [0.         0.20833333]
# Recall: [0. 1.]
# F-Score: [0.         0.34482759]
# Support: [57 15]
# -----------------------------------------------------------------------------------
# Center Point: 0.5
# Time: 1.5220870971679688
# -----------------------------------------------------------------------------------
# <style  type="text/css" >
#     #T_9b055a70_731c_11e9_8823_f07959376ad7row0_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row1_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row2_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row3_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row4_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row5_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row6_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row7_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row8_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row9_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row11_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row12_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row13_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row14_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row15_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row16_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row19_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row20_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row21_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row22_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row23_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row24_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row25_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row26_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row28_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row30_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row32_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row33_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row35_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row36_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row37_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row38_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row39_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row41_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row42_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row44_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row46_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row48_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row50_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row52_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row53_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row55_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row56_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row57_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row58_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row59_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row60_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row61_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row62_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row63_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row64_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row65_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row67_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row68_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row69_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row70_col5 {
#             background-color:  green;
#         }    #T_9b055a70_731c_11e9_8823_f07959376ad7row71_col5 {
#             background-color:  green;
#         }</style>
# <table id="T_9b055a70_731c_11e9_8823_f07959376ad7" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >F5</th>
#         <th class="col_heading level0 col1" >F4</th>
#         <th class="col_heading level0 col2" >F3</th>
#         <th class="col_heading level0 col3" >F2</th>
#         <th class="col_heading level0 col4" >F1</th>
#         <th class="col_heading level0 col5" >Decision</th>
#         <th class="col_heading level0 col6" >Decision Fuzzy</th>
#         <th class="col_heading level0 col7" >Predicted Value</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_9b055a70_731c_11e9_8823_f07959376ad7level0_row0" class="row_heading level0 row0" >23</th>
#         <td id="T_9b055a70_731c_11e9_8823_f07959376ad7row0_col0" class="data row0 col0" >0.328859</td>
#         <td id="T_9b055a70_731c_11e9_8823_f07959376ad7row0_col1" class="data row0 col1" >0</td>
#         <td id="T_9b055a70_731c_11e9_8823_f07959376ad7row0_col2" class="data row0 col2" >0.0555556</td>
#         <td id="T_9b055a70_731c_11e9_8823_f07959376ad7row0_col3" class="data row0 col3" >0.431818</td>
#         <td id="T_9b055a70_731c_11e9_8823_f07959376ad7row0_col4" class="data row0 col4" >0.243902</td>
#         <td id="T_9b055a70_731c_11e9_8823_f07959376ad7row0_col5" class="data row0 col5" >One</td>
#         <td id="T_9b055a70_731c_11e9_8823_f07959376ad7row0_col6" class="data row0 col6" >Zero</td>
#         <td id="T_9b055a70_731c_11e9_8823_f07959376ad7row0_col7" class="data row0 col7" >0.475171</td>
#     </tr>    <tr>
#         <th id="T_9b055a70_731c_11e9_8823_f07959376ad7level0_row1" class="row_heading level0 row1" >73</th>
#         <td id="T_9b055a70_731c_11e9_8823_f07959376ad7row1_col0" class="data row1 col0" >0.0659955</td>
#         <td id="T_9b055a70_731c_11e9_8823_f07959376ad7row1_col1" class="data row1 col1" >0</td>
#         <td id="T_9b055a70_731c_11e9_8823_f07959376ad7row1_col2" class="data row1 col2" >0</td>
#         <td id="T_9b055a70_731c_11e9_8823_f07959376ad7row1_col3" class="data row1 col3" >0.272727</td>
#         <td id="T_9b055a70_731c_11

# %% [markdown]
# ##### Training Set | S Function Optymalization

# %%
optimizeBruteForce = OptimizeBruteForce(settings.variables, settings.s_function_width)

# %%
s_function_center = optimizeBruteForce.sFunctionsWorker(settings.variables, settings.constraints, settings.s_function_width)
# Out:
# D:\Anaconda\envs\py35\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy: 0.7916666666666666
# Precision: [0.79166667 0.        ]
# Recall: [1. 0.]
# F-Score: [0.88372093 0.        ]
# Support: [57 15]
# -----------------------------------------------------------------------------------
# Center Point: 0.0
# Train Accuracy: 0.7916666666666666
# Time: 42.5934362411499
# -----------------------------------------------------------------------------------

# %% [markdown]
# ##### Training Set | Threshold Optymalization

# %%
threshold = optimizeBruteForce.thresholdWorker(settings.variables, s_function_center, settings.s_function_width)
# Out:
# D:\Anaconda\envs\py35\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy: 0.7916666666666666
# Precision: [0.79166667 0.        ]
# Recall: [1. 0.]
# F-Score: [0.88372093 0.        ]
# Support: [57 15]
# -----------------------------------------------------------------------------------
# Center Point: 0.0
# Threshold: 0.4824741026106495
# Train Accuracy: 0.7916666666666666
# Time: 1.8561060428619385
# -----------------------------------------------------------------------------------

# %% [markdown]
# ## Test Set

# %% [markdown]
# ##### Test Set | No Optymalization

# %%
# valueTest = ValueTest(settings.variables, settings.s_function_width, False)
# valueTest.noOptymalizationWorker(settings.variables)

# %% [markdown]
# ##### Test Set | S Function Value

# %%
# valueTest.sOptymalizationWorker(settings.variables, s_function_center)

# %% [markdown]
# ##### Test Set | Threshold Value

# %%
# valueTest.thresholdWorker(settings.variables, s_function_center, threshold)
