# %% [markdown]
# ## Preparation

# %% [markdown]
# ##### Import Functions

# %%
from Scripts.LoadCSV import LoadCSV as LoadCSV
from Scripts.Fuzzify import Fuzzify as Fuzzify
from Scripts.OptimizeBruteForceKFold import OptimizeBruteForceKFold as OptimizeBruteForceKFold
from Scripts.ValueTest import ValueTest as ValueTest
from Scripts.OptimizeBruteForce import OptimizeBruteForce as OptimizeBruteForce
from Class.Helper import Helper as Helper

# %% [markdown]
# ##### Import Settings

# %%
import Settings.SettingsBreastCancerData as settings

# %% [markdown]
# ##### Load CSV File

# %%
# loadCSV = LoadCSV()
# samples_stats, train_stats, test_stats, train_samples = loadCSV.worker(settings.variables)

# %% [markdown]
# ##### Fuzzify Data

# %%
# fuzzify = Fuzzify()
# changed_decisions, features_number_after_reduct, implicants_number, fuzzify_parameters = fuzzify.worker(settings.variables, "", -1)

# %%
# helper = Helper()

# fuzzification_data = [settings.variables["dataset_name"], settings.variables["gausses"], samples_stats, train_stats, test_stats, changed_decisions, round(changed_decisions / train_samples, 2), implicants_number, settings.variables["feature_numbers"], features_number_after_reduct]
# helper.saveFuzzificationStats(fuzzification_data)

# fuzzification_parameters_data = [settings.variables["dataset_name"], settings.variables["gausses"], settings.sigma_mean_params] + fuzzify_parameters
# helper.saveFuzzificationParameters(fuzzification_parameters_data)

# %% [markdown]
# ## Train Set - K-Fold

# %% [markdown]
# ##### Train Set | K-Fold - S Function Optymalization

# %%
# optimizeBruteForceKFold = OptimizeBruteForceKFold(settings.variables, settings.s_function_width)

# %%
# best_s_function_center, mean_s_function_center = optimizeBruteForceKFold.worker(settings.variables, settings.constraints, settings.s_function_width, settings.n_folds)

# %% [markdown]
# ## Test Set | K-Fold Test

# %%
# valueTest = ValueTest(settings.variables, settings.s_function_width, False)

# %% [markdown]
# ##### K-Fold Test Set | S Function Value

# %%
# valueTest.sOptymalizationWorker(settings.variables, best_s_function_center, "Test Value - K-Fold - Best Function Center")

# %%
# valueTest.sOptymalizationWorker(settings.variables, mean_s_function_center, "Test Value - K-Fold - Average Function Center")

# %% [markdown]
# ## Training Set

# %% [markdown]
# ##### Training Set | No Optymalization

# %%
valueTest = ValueTest(settings.variables, settings.s_function_width, True)
valueTest.noOptymalizationWorker(settings.variables)
# Out:
# -----------------------------------------------------------------------------------
# Accuracy: 0.5032967032967033
# Precision: [1.         0.42929293]
# Recall: [0.20701754 1.        ]
# F-Score: [0.34302326 0.60070671]
# Support: [285 170]
# -----------------------------------------------------------------------------------
# Center Point: 0.5
# Time: 6.579376220703125
# -----------------------------------------------------------------------------------
# <style  type="text/css" >
#     #T_a889676e_7319_11e9_a78e_f07959376ad7row93_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row113_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row117_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row120_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row122_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row123_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row124_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row125_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row127_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row128_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row129_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row130_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row131_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row132_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row133_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row134_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row135_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row138_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row140_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row142_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row143_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row144_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row145_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row146_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row147_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row148_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row149_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row153_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row154_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row156_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row157_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row158_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row159_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row161_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row163_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row164_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row165_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row166_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row167_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row168_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row169_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row170_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row172_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row173_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row174_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row175_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row176_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row178_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row179_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row180_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row181_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row183_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row184_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row185_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row186_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row187_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row188_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row190_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row191_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row194_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row195_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row197_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row199_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row200_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row201_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row202_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row204_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row207_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row211_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row212_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row213_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row215_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row217_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row218_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row219_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row220_col5 {
#             background-color:  green;
#         }    #T_a889676e_7319_11e9_a78e_f07959376ad7row221_col5 {
#             ba

# %% [markdown]
# ##### Training Set | S Function Optymalization

# %%
optimizeBruteForce = OptimizeBruteForce(settings.variables, settings.s_function_width)

# %%
s_function_center = optimizeBruteForce.sFunctionsWorker(settings.variables, settings.constraints, settings.s_function_width)
# Out:
# Accuracy: 0.8791208791208791
# Precision: [0.8422619  0.98319328]
# Recall: [0.99298246 0.68823529]
# F-Score: [0.91143317 0.80968858]
# Support: [285 170]
# -----------------------------------------------------------------------------------
# Center Point: 0.49500000000000005
# Train Accuracy: 0.8791208791208791
# Time: 600.0823228359222
# -----------------------------------------------------------------------------------

# %% [markdown]
# ##### Training Set | Threshold Optymalization

# %%
threshold = optimizeBruteForce.thresholdWorker(settings.variables, s_function_center, settings.s_function_width)
# Out:
# Accuracy: 0.865934065934066
# Precision: [0.8255814  0.99099099]
# Recall: [0.99649123 0.64705882]
# F-Score: [0.90302067 0.78291815]
# Support: [285 170]
# -----------------------------------------------------------------------------------
# Center Point: 0.49500000000000005
# Threshold: 0.4949075910186951
# Train Accuracy: 0.865934065934066
# Time: 29.65169596672058
# -----------------------------------------------------------------------------------

# %% [markdown]
# ## Test Set

# %% [markdown]
# ##### Test Set | No Optymalization

# %%
# valueTest = ValueTest(settings.variables, settings.s_function_width, False)
# valueTest.noOptymalizationWorker(settings.variables)

# %% [markdown]
# ##### Test Set | S Function Value

# %%
# valueTest.sOptymalizationWorker(settings.variables, s_function_center)

# %% [markdown]
# ##### Test Set | Threshold Value

# %%
# valueTest.thresholdWorker(settings.variables, s_function_center, threshold)
