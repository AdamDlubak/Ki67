# %%
import SettingsDataBanknoteAuthentication as settings
from Functions.Helper import Helper as Helper

# %%
helper = Helper()

# %%
helper.printDF(settings.variables)
# Out:
#       index        F0        F1        F3        F2 Decision Decision Fuzzy  \
# 0       464  0.921792  0.498799  0.902416  0.244093     Zero
# 1       529  0.407705  0.983199  0.090883  0.257492     Zero
# 2       229  0.904059  0.573286  0.952617  0.229513     Zero
# 3        64  0.897403  0.631513  0.919583  0.178021     Zero
# 4       664  0.894266  0.655903  0.875374  0.152997     Zero
# 5       253  0.889088  0.637242  0.883367  0.168609     Zero
# 6       274  0.888281  0.520557  0.881248  0.232945     Zero
# 7        51  0.887300  0.664423  0.869136  0.160635     Zero
# 8       594  0.883060  0.646769  0.869373  0.173705     Zero
# 9       642  0.877932  0.514208  0.878666  0.241767     Zero
# 10      708  0.880889  0.663570  0.814347  0.142292     Zero
# 11      102  0.876548  0.496709  0.879011  0.254797     Zero
# 12      151  0.380921  0.961440  0.475018  0.342977     Zero
# 13      608  0.874608  0.638095  0.879011  0.173003     Zero
# ...

# %%
helper.pairPlot(settings.variables)

# %%
helper.featuresHistogram(settings.variables)

# %%
fuzzy = pickle.load( open( "1. Data - Pima Indians/fuzzifier.p ", "rb" ) )

# %%
fuzzy.decision.view()
# Out:
# C:\Programy\Anaconda\envs\py35\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
fuzzy.features[2].view()
# Out:
# C:\Programy\Anaconda\envs\py35\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
