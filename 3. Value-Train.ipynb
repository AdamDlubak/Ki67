# %%
import settings as settings
from Scripts.ValueTrain import ValueTrain as ValueTrain

# %%
valueTrain = ValueTrain(settings.variables, settings.threshold_value)
valueTrain.worker(settings.variables)
# Out:
# Accuracy: 0.8210862619808307
# Precision: [0.78947368 1.        ]
# Recall: [1.         0.45631068]
# F-Score: [0.88235294 0.62666667]
# Support: [210 103]

# %%
valueTrain.printAllDataframe()
# Out:
#      index        F8        F3        F4        F5        F6        F0  \
# 0      373  0.000000  0.111111  0.222222  0.000000  0.222222  0.444444
# 1      161  1.000000  1.000000  0.555556  0.000000  0.222222  1.000000
# 2      257  0.000000  0.000000  0.111111  0.000000  0.222222  0.444444
# 3      403  0.111111  0.111111  0.111111  0.111111  0.222222  0.444444
# 4      365  0.000000  0.000000  0.333333  0.000000  0.222222  0.444444
# 5      398  0.000000  0.000000  0.111111  0.000000  0.222222  0.444444
# 6      582  0.000000  0.000000  0.111111  0.000000  0.222222  0.444444
# 7      560  0.000000  0.000000  0.111111  0.000000  0.222222  0.444444
# 8      522  0.000000  0.000000  0.111111  0.000000  0.222222  0.444444
# 9       75  0.000000  0.111111  0.111111  0.000000  0.111111  0.444444
# 10     408  0.000000  0.000000  0.111111  0.000000  0.111111  0.444444
# 11     318  0.000000  0.111111  0.111111  0.000000  0.111111  0.444444
# ...

# %%
valueTrain.plotHistogram()
