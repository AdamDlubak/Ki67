# 252     Middle     Zero
# 209  Middle High     Zero
# 48         Low      One
# 218  Middle High     Zero
# 168  Middle High     Zero
# 145     Middle      One
# 10      Middle      One
# 19      Middle      One
# 207  Middle High     Zero
# 6       Middle      One
# 148     Middle      One
# 249  Middle High     Zero
# 248  Middle High     Zero
# 237  Middle High     Zero
# 125     Middle      One
# 79   Middle High      One
# 15      Middle      One
# 277  Middle High     Zero
# 93      Middle      One
# 23      Middle      One
# 104     Middle      One
# 17      Middle      One
# 29      Middle      One
# 120     Middle      One
# 179   Middle Low     Zero
# 250  Middle High     Zero
# 16      Middle      One
#
# [242 rows x 15 columns]
# 232it [02:25,  1.59it/s]
# Finished!

# %% [markdown]
# ##### Brute Force

# %%
from Scripts.OptimizeBruteForce import OptimizeBruteForce as OptimizeBruteForce

optimizeBruteForce = OptimizeBruteForce(settings.variables, settings.constraints, settings.sigma_mean_params)
bruteforce_threshold = optimizeBruteForce.worker(settings.variables)
# Out:
# Global minimum: [0.41458594]
# Function value at global minimum: 0.09090909090909094
# Accuracy: 0.9090909090909091
# Time: 26.719999313354492

# %% [markdown]
# ##### PSO

# %%
from Scripts.OptimizePSO import OptimizePSO as OptimizePSO

optimizePSO = OptimizePSO(settings.variables, settings.swarm_size, settings.dim, settings.epsilon, settings.iters, settings.options, settings.borders, settings.sigma_mean_params)
optimizePSO.worker(settings.variables)
# Out:
# 2019-03-28 09:05:34,652 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'c2': 0.3, 'c1': 0.5, 'w': 0.9}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.095
# 2019-03-28 09:07:03,839 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.0950413223140496, best pos: [0.41494339]
# Global minimum: [0.41494339]
# Function value at global minimum: 0.0950413223140496
# Accuracy: 0.9049586776859504
# Time: 89.21000146865845
# array([0.41494339])

# %% [markdown]
# ##### Value Train without optimalization

# %%
from Scripts.ValueTrain import ValueTrain as ValueTrain
valueTrain = ValueTrain(settings.variables, threshold_value = -1)
valueTrain.worker(settings.variables)
# Out:
# Accuracy: 0.9008264462809917
# Precision: [0.88652482 0.92079208]
# Recall: [0.93984962 0.85321101]
# F-Score: [0.91240876 0.88571429]
# Support: [133 109]

# %% [markdown]
# ##### Value Train with optimalization

# %%
from Scripts.ValueTrain import ValueTrain as ValueTrain

valueTrain = ValueTrain(settings.variables, threshold_value = bruteforce_threshold)
valueTrain.worker(settings.variables)
# Out:
# Accuracy: 0.9090909090909091
# Precision: [0.88275862 0.94845361]
# Recall: [0.96240602 0.8440367 ]
# F-Score: [0.92086331 0.89320388]
# Support: [133 109]

# %% [markdown]
# ##### Value Test without optimalization

# %%
from Scripts.ValueTest import ValueTest as ValueTest

valueTest = ValueTest(settings.variables, threshold_value = -1)
valueTest.worker(settings.variables)
# Out:
# Accuracy: 0.639344262295082
# Precision: [0.63888889 0.64      ]
# Recall: [0.71875    0.55172414]
# F-Score: [0.67647059 0.59259259]
# Support: [32 29]

# %% [markdown]
# ##### Value Test with optimalization

# %%
from Scripts.ValueTest import ValueTest as ValueTest

valueTest = ValueTest(settings.variables, threshold_value = bruteforce_threshold)
valueTest.worker(settings.variables)
# Out:
# Accuracy: 0.6065573770491803
# Precision: [0.58695652 0.66666667]
# Recall: [0.84375    0.34482759]
# F-Score: [0.69230769 0.45454545]
# Support: [32 29]

# %% [markdown]
# ##### PSO K-Fold

# %%
from Scripts.OptimizePSOKFold import OptimizePSOKFold as OptimizePSOKFold

optimizePSOKFold = OptimizePSOKFold(settings.variables, settings.swarm_size, settings.dim, settings.epsilon, settings.iters, settings.options, settings.borders, settings.sigma_mean_params)
optimizePSOKFold.worker(settings.variables)
# Out:
# 2019-03-28 09:08:33,938 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'c2': 0.3, 'c1': 0.5, 'w': 0.9}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████████|20/20, best_cost=0.0992
# 2019-03-28 09:10:05,353 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.09917355371900827, best pos: [0.41342387]
# ------------------------------------- Fold 0 --------------------------------------
# Global minimum: [0.41342387]
# Train Accuracy: 0.9008264462809917
# Test Accuracy: 0.96
# Time: 91.46299719810486
# -----------------------------------------------------------------------------------
# 2019-03-28 09:10:05,435 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'c2': 0.3, 'c1': 0.5, 'w': 0.9}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████████|20/20, best_cost=0.0909
# 2019-03-28 09:11:35,629 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.09090909090909094, best pos: [0.41469839]
# ------------------------------------- Fold 1 --------------------------------------
# Global minimum: [0.41469839]
# Train Accuracy: 0.9090909090909091
# Test Accuracy: 0.88
# Time: 90.24300479888916
# -----------------------------------------------------------------------------------
# 2019-03-28 09:11:35,703 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'c2': 0.3, 'c1': 0.5, 'w': 0.9}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████████|20/20, best_cost=0.0909
# 2019-03-28 09:13:03,765 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.09090909090909094, best pos: [0.41469839]
# ------------------------------------- Fold 2 --------------------------------------
# Global minimum: [0.41469839]
# Train Accuracy: 0.9090909090909091
# Test Accuracy: 0.88
# Time: 88.11201357841492
# -----------------------------------------------------------------------------------
# 2019-03-28 09:13:03,856 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'c2': 0.3, 'c1': 0.5, 'w': 0.9}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████████|20/20, best_cost=0.0909
# 2019-03-28 09:14:33,440 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.09090909090909094, best pos: [0.41469839]
# ------------------------------------- Fold 3 --------------------------------------
# Global minimum: [0.41469839]
# Train Accuracy: 0.9090909090909091
# Test Accuracy: 0.8333333333333334
# Time: 89.65597987174988
# -----------------------------------------------------------------------------------
# 2019-03-28 09:14:33,546 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'c2': 0.3, 'c1': 0.5, 'w': 0.9}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████████|20/20, best_cost=0.0909
# 2019-03-28 09:16:04,328 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.09090909090909094, best pos: [0.41469839]
# ------------------------------------- Fold 4 --------------------------------------
# Global minimum: [0.41469839]
# Train Accuracy: 0.9090909090909091
# Test Accuracy: 0.9166666666666666
# Time: 90.82400155067444
# -----------------------------------------------------------------------------------
# 2019-03-28 09:16:04,392 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'c2': 0.3, 'c1': 0.5, 'w': 0.9}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████████|20/20, best_cost=0.0909
# 2019-03-28 09:17:36,277 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.09090909090909094, best pos: [0.41469839]
# ------------------------------------- Fold 5 --------------------------------------
# Global minimum: [0.41469839]
# Train Accuracy: 0.9090909090909091
# Test Accuracy: 0.875
# Time: 91.923752784729
# -----------------------------------------------------------------------------------
# 2019-03-28 09:17:36,339 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'c2': 0.3, 'c1': 0.5, 'w': 0.9}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████████|20/20, best_cost=0.0909
# 2019-03-28 09:19:08,571 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.09090909090909094, best pos: [0.41469839]
# ------------------------------------- Fold 6 --------------------------------------
# Global minimum: [0.41469839]
# Train Accuracy: 0.9090909090909091
# Test Accuracy: 0.875
# Time: 92.27000141143799
# -----------------------------------------------------------------------------------
# 2019-03-28 09:19:08,638 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'c2': 0.3, 'c1': 0.5, 'w': 0.9}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████████|20/20, best_cost=0.0909
# 2019-03-28 09:20:37,175 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.09090909090909094, best pos: [0.41469839]
# ------------------------------------- Fold 7 --------------------------------------
# Global minimum: [0.41469839]
# Train Accuracy: 0.9090909090909091
# Test Accuracy: 0.9166666666666666
# Time: 88.57599949836731
# -----------------------------------------------------------------------------------
# 2019-03-28 09:20:37,243 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'c2': 0.3, 'c1': 0.5, 'w': 0.9}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████████|20/20, best_cost=0.0909
# 2019-03-28 09:22:06,226 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.09090909090909094, best pos: [0.41469839]
# ------------------------------------- Fold 8 --------------------------------------
# Global minimum: [0.41469839]
# Train Accuracy: 0.9090909090909091
# Test Accuracy: 0.9166666666666666
# Time: 89.02598357200623
# -----------------------------------------------------------------------------------
# 2019-03-28 09:22:06,303 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'c2': 0.3, 'c1': 0.5, 'w': 0.9}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████████|20/20, best_cost=0.0909
# 2019-03-28 09:23:29,715 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.09090909090909094, best pos: [0.41469839]
# ------------------------------------- Fold 9 --------------------------------------
# Global minimum: [0.41469839]
# Train Accuracy: 0.9090909090909091
# Test Accuracy: 1.0
# Time: 83.45601058006287
# -----------------------------------------------------------------------------------

# %% [markdown]
# ##### Brute Force K-Fold

# %%
from Scripts.OptimizeBruteForceKFold import OptimizeBruteForceKFold as OptimizeBruteForceKFold

optimizeBruteForceKFold = OptimizeBruteForceKFold(settings.variables, settings.constraints, settings.sigma_mean_params)
optimizeBruteForceKFold.worker(settings.variables)
# Out:
# ------------------------------------- Fold 0 --------------------------------------
# Global minimum: [0.41458594]
# Train Accuracy: 0.8986175115207373
# Test Accuracy: 1.0
# Time: 21.556018829345703
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 1 --------------------------------------
# Global minimum: [0.41458594]
# Train Accuracy: 0.9124423963133641
# Test Accuracy: 0.88
# Time: 21.555983781814575
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 2 --------------------------------------
# Global minimum: [0.41475]
# Train Accuracy: 0.9124423963133641
# Test Accuracy: 0.84
# Time: 21.75801372528076
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 3 --------------------------------------
# Global minimum: [0.41458594]
# Train Accuracy: 0.9174311926605505
# Test Accuracy: 0.8333333333333334
# Time: 21.375982761383057
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 4 --------------------------------------
# Global minimum: [0.41458594]
# Train Accuracy: 0.908256880733945
# Test Accuracy: 0.9166666666666666
# Time: 22.12100863456726
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 5 --------------------------------------
# Global minimum: [0.41458594]
# Train Accuracy: 0.9128440366972477
# Test Accuracy: 0.875
# Time: 21.80500864982605
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 6 --------------------------------------
# Global minimum: [0.41458594]
# Train Accuracy: 0.9128440366972477
# Test Accuracy: 0.875
# Time: 21.677515268325806
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 7 --------------------------------------
# Global minimum: [0.41458594]
# Train Accuracy: 0.908256880733945
# Test Accuracy: 0.9166666666666666
# Time: 22.596075534820557
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 8 --------------------------------------
# Global minimum: [0.41458594]
# Train Accuracy: 0.908256880733945
# Test Accuracy: 0.9166666666666666
# Time: 22.013017416000366
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 9 --------------------------------------
# Global minimum: [0.41458594]
# Train Accuracy: 0.8995433789954338
# Test Accuracy: 1.0
# Time: 21.328320264816284
# -----------------------------------------------------------------------------------
