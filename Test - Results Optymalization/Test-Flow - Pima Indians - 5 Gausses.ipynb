# 83   Middle High   Middle Low  negatif
# 267   Middle Low   Middle Low  negatif
# 371   Middle Low  Middle High  positif
# 182   Middle Low   Middle Low  negatif
# 132   Middle Low  Middle High  negatif
# 281  Middle High       High  positif
# 155     Middle   Middle Low  positif
# 245   Middle Low  Middle High  positif
# 39    Middle Low  Middle High  negatif
# 45    Middle Low   Middle Low  negatif
# 67    Middle Low   Middle Low  negatif
# 157   Middle Low   Middle Low  negatif
# 251     Middle   Middle Low  negatif
# 241     Middle   Middle Low  negatif
# 330     Middle     Middle  positif
# 163  Middle High     Middle  positif
# 46   Middle High   Middle Low  negatif
# 261   Middle Low   Middle Low  negatif
#
# [313 rows x 10 columns]
# 241it [02:37,  1.53it/s]
# Finished!

# %% [markdown]
# ##### Brute Force

# %%
from Scripts.OptimizeBruteForce import OptimizeBruteForce as OptimizeBruteForce

optimizeBruteForce = OptimizeBruteForce(settings.variables, settings.constraints, settings.sigma_mean_params)
bruteforce_threshold = optimizeBruteForce.worker(settings.variables)
# Out:
# Global minimum: [0.41220215]
# Function value at global minimum: 0.18849840255591055
# Accuracy: 0.8115015974440895
# Time: 33.06727743148804

# %% [markdown]
# ##### PSO

# %%
from Scripts.OptimizePSO import OptimizePSO as OptimizePSO

optimizePSO = OptimizePSO(settings.variables, settings.swarm_size, settings.dim, settings.epsilon, settings.iters, settings.options, settings.borders, settings.sigma_mean_params)
optimizePSO.worker(settings.variables)
# Out:
# 2019-03-28 02:28:18,752 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'w': 0.9, 'c1': 0.5, 'c2': 0.3}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.252
# 2019-03-28 02:30:07,197 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.25239616613418525, best pos: [0.41391315]
# Global minimum: [0.41391315]
# Function value at global minimum: 0.25239616613418525
# Accuracy: 0.7476038338658147
# Time: 108.45994758605957
# array([0.41391315])

# %% [markdown]
# ##### Value Train without optimalization

# %%
from Scripts.ValueTrain import ValueTrain as ValueTrain
valueTrain = ValueTrain(settings.variables, threshold_value = -1)
valueTrain.worker(settings.variables)
# Out:
# Accuracy: 0.6837060702875399
# Precision: [0.90076336 0.52747253]
# Recall: [0.57843137 0.88073394]
# F-Score: [0.70447761 0.65979381]
# Support: [204 109]

# %% [markdown]
# ##### Value Test without optimalization

# %%
from Scripts.ValueTest import ValueTest as ValueTest

valueTest = ValueTest(settings.variables, threshold_value = -1)
valueTest.worker(settings.variables)
# Out:
# Accuracy: 0.5189873417721519
# Precision: [0.77777778 0.30232558]
# Recall: [0.48275862 0.61904762]
# F-Score: [0.59574468 0.40625   ]
# Support: [58 21]

# %% [markdown]
# ##### Value Train with optimalization

# %%
from Scripts.ValueTrain import ValueTrain as ValueTrain

valueTrain = ValueTrain(settings.variables, threshold_value = bruteforce_threshold)
valueTrain.worker(settings.variables)
# Out:
# Accuracy: 0.8115015974440895
# Precision: [0.80851064 0.82051282]
# Recall: [0.93137255 0.58715596]
# F-Score: [0.86560364 0.68449198]
# Support: [204 109]

# %% [markdown]
# ##### Value Test with optimalization

# %%
from Scripts.ValueTest import ValueTest as ValueTest

valueTest = ValueTest(settings.variables, threshold_value = bruteforce_threshold)
valueTest.worker(settings.variables)
# Out:
# Accuracy: 0.7341772151898734
# Precision: [0.7761194 0.5      ]
# Recall: [0.89655172 0.28571429]
# F-Score: [0.832      0.36363636]
# Support: [58 21]

# %% [markdown]
# ##### PSO K-Fold

# %%
from Scripts.OptimizePSOKFold import OptimizePSOKFold as OptimizePSOKFold

optimizePSOKFold = OptimizePSOKFold(settings.variables, settings.swarm_size, settings.dim, settings.epsilon, settings.iters, settings.options, settings.borders, settings.sigma_mean_params)
optimizePSOKFold.worker(settings.variables)
# Out:
# 2019-03-28 02:30:36,929 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'w': 0.9, 'c1': 0.5, 'c2': 0.3}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.201
# 2019-03-28 02:32:24,636 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.20127795527156545, best pos: [0.41272547]
# ------------------------------------- Fold 0 --------------------------------------
# Global minimum: [0.41272547]
# Train Accuracy: 0.7987220447284346
# Test Accuracy: 0.71875
# Time: 107.75498175621033
# -----------------------------------------------------------------------------------
# 2019-03-28 02:32:24,715 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'w': 0.9, 'c1': 0.5, 'c2': 0.3}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.198
# 2019-03-28 02:34:06,373 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.19808306709265178, best pos: [0.41244497]
# ------------------------------------- Fold 1 --------------------------------------
# Global minimum: [0.41244497]
# Train Accuracy: 0.8019169329073482
# Test Accuracy: 0.75
# Time: 101.7016921043396
# -----------------------------------------------------------------------------------
# 2019-03-28 02:34:06,447 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'w': 0.9, 'c1': 0.5, 'c2': 0.3}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.185
# 2019-03-28 02:35:52,780 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.18530351437699677, best pos: [0.41287801]
# ------------------------------------- Fold 2 --------------------------------------
# Global minimum: [0.41287801]
# Train Accuracy: 0.8146964856230032
# Test Accuracy: 0.84375
# Time: 106.37905526161194
# -----------------------------------------------------------------------------------
# 2019-03-28 02:35:52,849 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'w': 0.9, 'c1': 0.5, 'c2': 0.3}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.185
# 2019-03-28 02:37:40,686 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.18530351437699677, best pos: [0.41287801]
# ------------------------------------- Fold 3 --------------------------------------
# Global minimum: [0.41287801]
# Train Accuracy: 0.8146964856230032
# Test Accuracy: 0.90625
# Time: 107.88642692565918
# -----------------------------------------------------------------------------------
# 2019-03-28 02:37:40,762 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'w': 0.9, 'c1': 0.5, 'c2': 0.3}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.185
# 2019-03-28 02:39:33,852 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.18530351437699677, best pos: [0.41287801]
# ------------------------------------- Fold 4 --------------------------------------
# Global minimum: [0.41287801]
# Train Accuracy: 0.8146964856230032
# Test Accuracy: 0.7419354838709677
# Time: 113.13249635696411
# -----------------------------------------------------------------------------------
# 2019-03-28 02:39:33,927 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'w': 0.9, 'c1': 0.5, 'c2': 0.3}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.185
# 2019-03-28 02:41:32,584 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.18530351437699677, best pos: [0.41287801]
# ------------------------------------- Fold 5 --------------------------------------
# Global minimum: [0.41287801]
# Train Accuracy: 0.8146964856230032
# Test Accuracy: 0.9032258064516129
# Time: 118.70078563690186
# -----------------------------------------------------------------------------------
# 2019-03-28 02:41:32,653 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'w': 0.9, 'c1': 0.5, 'c2': 0.3}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.185
# 2019-03-28 02:43:26,420 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.18530351437699677, best pos: [0.41287801]
# ------------------------------------- Fold 6 --------------------------------------
# Global minimum: [0.41287801]
# Train Accuracy: 0.8146964856230032
# Test Accuracy: 0.8064516129032258
# Time: 113.8167245388031
# -----------------------------------------------------------------------------------
# 2019-03-28 02:43:26,496 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'w': 0.9, 'c1': 0.5, 'c2': 0.3}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.185
# 2019-03-28 02:45:14,477 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.18530351437699677, best pos: [0.41287801]
# ------------------------------------- Fold 7 --------------------------------------
# Global minimum: [0.41287801]
# Train Accuracy: 0.8146964856230032
# Test Accuracy: 0.8387096774193549
# Time: 108.02800154685974
# -----------------------------------------------------------------------------------
# 2019-03-28 02:45:14,560 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'w': 0.9, 'c1': 0.5, 'c2': 0.3}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.185
# 2019-03-28 02:47:03,431 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.18530351437699677, best pos: [0.41287801]
# ------------------------------------- Fold 8 --------------------------------------
# Global minimum: [0.41287801]
# Train Accuracy: 0.8146964856230032
# Test Accuracy: 0.8709677419354839
# Time: 108.9308249950409
# -----------------------------------------------------------------------------------
# 2019-03-28 02:47:03,508 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'w': 0.9, 'c1': 0.5, 'c2': 0.3}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.185
# 2019-03-28 02:48:53,628 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.18530351437699677, best pos: [0.41287801]
# ------------------------------------- Fold 9 --------------------------------------
# Global minimum: [0.41287801]
# Train Accuracy: 0.8146964856230032
# Test Accuracy: 0.7333333333333333
# Time: 110.15977549552917
# -----------------------------------------------------------------------------------

# %% [markdown]
# ##### Brute Force K-Fold

# %%
from Scripts.OptimizeBruteForceKFold import OptimizeBruteForceKFold as OptimizeBruteForceKFold

optimizeBruteForceKFold = OptimizeBruteForceKFold(settings.variables, settings.constraints, settings.sigma_mean_params)
optimizeBruteForceKFold.worker(settings.variables)
# Out:
# ------------------------------------- Fold 0 --------------------------------------
# Global minimum: [0.41224219]
# Train Accuracy: 0.8149466192170819
# Test Accuracy: 0.75
# Time: 31.239005088806152
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 1 --------------------------------------
# Global minimum: [0.41220215]
# Train Accuracy: 0.8185053380782918
# Test Accuracy: 0.75
# Time: 31.60599994659424
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 2 --------------------------------------
# Global minimum: [0.41220215]
# Train Accuracy: 0.8078291814946619
# Test Accuracy: 0.84375
# Time: 30.08100938796997
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 3 --------------------------------------
# Global minimum: [0.41216211]
# Train Accuracy: 0.800711743772242
# Test Accuracy: 0.875
# Time: 29.889987230300903
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 4 --------------------------------------
# Global minimum: [0.41220215]
# Train Accuracy: 0.8191489361702128
# Test Accuracy: 0.7419354838709677
# Time: 30.70200490951538
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 5 --------------------------------------
# Global minimum: [0.41220215]
# Train Accuracy: 0.8014184397163121
# Test Accuracy: 0.9032258064516129
# Time: 30.47299098968506
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 6 --------------------------------------
# Global minimum: [0.41220215]
# Train Accuracy: 0.8156028368794326
# Test Accuracy: 0.7741935483870968
# Time: 30.730000257492065
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 7 --------------------------------------
# Global minimum: [0.41192188]
# Train Accuracy: 0.8014184397163121
# Test Accuracy: 0.7741935483870968
# Time: 29.435999631881714
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 8 --------------------------------------
# Global minimum: [0.41224219]
# Train Accuracy: 0.8085106382978723
# Test Accuracy: 0.8064516129032258
# Time: 29.111002922058105
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 9 --------------------------------------
# Global minimum: [0.41220215]
# Train Accuracy: 0.8197879858657244
# Test Accuracy: 0.7333333333333333
# Time: 29.965003967285156
# -----------------------------------------------------------------------------------
