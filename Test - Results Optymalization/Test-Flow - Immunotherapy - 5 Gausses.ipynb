# 88   Middle Low     Middle  Middle High  Middle High   Middle Low   Middle Low
# 47   Middle Low       High  Middle High   Middle Low  Middle High   Middle Low
# 73  Middle High       High   Middle Low   Middle Low   Middle Low   Middle Low
# 31   Middle Low   Middle Low   Middle Low   Middle Low       High     Middle
# 33  Middle High   Middle Low   Middle Low   Middle Low   Middle Low  Middle High
# 36  Middle High  Middle High  Middle High  Middle High  Middle High   Middle Low
# 58  Middle High       High  Middle High     Middle   Middle Low   Middle Low
# 55   Middle Low       High     Middle  Middle High       High   Middle Low
# 86   Middle Low  Middle High     Middle  Middle High  Middle High   Middle Low
# 80   Middle Low     Middle        Low   Middle Low   Middle Low     Middle
# 67  Middle High       High     Middle     Middle   Middle Low   Middle Low
# 2    Middle Low   Middle Low  Middle High   Middle Low   Middle Low     Middle
# 65   Middle Low     Middle   Middle Low  Middle High       High   Middle Low
# 45   Middle Low   Middle Low     Middle   Middle Low   Middle Low   Middle Low
#
#            F6 Decision Image
# 78   Middle Low      One
# 49   Middle Low     Zero
# 76   Middle Low      One
# 10   Middle Low      One
# 7    Middle Low      One
# 30       High      One
# 40   Middle Low      One
# 62  Middle High      One
# 57  Middle High      One
# 37   Middle Low      One
# 52   Middle Low      One
# 25   Middle Low      One
# 42   Middle Low     Zero
# 1        High      One
# 48   Middle Low      One
# 81   Middle Low      One
# 34   Middle Low      One
# 12   Middle Low     Zero
# 82   Middle Low     Zero
# 50   Middle Low      One
# 21   Middle Low      One
# 83   Middle Low      One
# 23   Middle Low      One
# 87  Middle High     Zero
# 84   Middle Low      One
# 28       High     Zero
# 0        High      One
# 16   Middle Low      One
# 9    Middle Low     Zero
# 5    Middle Low      One
# ..        ...      ...   ...
# 46   Middle Low      One
# 85   Middle Low      One
# 44   Middle Low      One
# 70   Middle Low      One
# 18   Middle Low      One
# 35   Middle Low     Zero
# 39   Middle Low     Zero
# 61       High      One
# 17   Middle Low      One
# 8    Middle Low      One
# 60       High      One
# 75   Middle Low      One
# 63  Middle High      One
# 72   Middle Low     Zero
# 26       High      One
# 89   Middle Low      One
# 88       High     Zero
# 47   Middle Low      One
# 73   Middle Low      One
# 31       High      One
# 33  Middle High      One
# 36   Middle Low     Zero
# 58       High     Zero
# 55   Middle Low      One
# 86       High      One
# 80   Middle Low      One
# 67   Middle Low      One
# 2   Middle High      One
# 65   Middle Low      One
# 45   Middle Low      One
#
# [72 rows x 9 columns]
# 58it [00:11,  5.04it/s]
# Finished!

# %% [markdown]
# ##### Brute Force

# %%
from Scripts.OptimizeBruteForce import OptimizeBruteForce as OptimizeBruteForce

optimizeBruteForce = OptimizeBruteForce(settings.variables, settings.constraints, settings.sigma_mean_params)
bruteforce_threshold = optimizeBruteForce.worker(settings.variables)
# Out:
# Global minimum: [0.]
# Function value at global minimum: 0.20833333333333337
# Accuracy: 0.7916666666666666
# Time: 6.900015354156494

# %% [markdown]
# ##### PSO

# %%
from Scripts.OptimizePSO import OptimizePSO as OptimizePSO

optimizePSO = OptimizePSO(settings.variables, settings.swarm_size, settings.dim, settings.epsilon, settings.iters, settings.options, settings.borders, settings.sigma_mean_params)
optimizePSO.worker(settings.variables)
# Out:
# 2019-03-29 06:59:05,287 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'w': 0.9, 'c2': 0.3, 'c1': 0.5}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.208
# 2019-03-29 06:59:29,980 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.20833333333333337, best pos: [0.3730405]
# Global minimum: [0.3730405]
# Function value at global minimum: 0.20833333333333337
# Accuracy: 0.7916666666666666
# Time: 24.706608772277832
# array([0.3730405])

# %% [markdown]
# ##### Value Train without optimalization

# %%
from Scripts.ValueTrain import ValueTrain as ValueTrain
valueTrain = ValueTrain(settings.variables, threshold_value = -1)
valueTrain.worker(settings.variables)
# Out:
# Accuracy: 0.375
# Precision: [0.64285714 0.        ]
# Recall: [0.47368421 0.        ]
# F-Score: [0.54545455 0.        ]
# Support: [57 15]

# %% [markdown]
# ##### Value Train with optimalization

# %%
from Scripts.ValueTrain import ValueTrain as ValueTrain

valueTrain = ValueTrain(settings.variables, threshold_value = bruteforce_threshold)
valueTrain.worker(settings.variables)
# Out:
# C:\Programy\Anaconda\envs\py35\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy: 0.7916666666666666
# Precision: [0.79166667 0.        ]
# Recall: [1. 0.]
# F-Score: [0.88372093 0.        ]
# Support: [57 15]

# %% [markdown]
# ##### Value Test without optimalization

# %%
from Scripts.ValueTest import ValueTest as ValueTest

valueTest = ValueTest(settings.variables, threshold_value = -1)
valueTest.worker(settings.variables)
# Out:
# Accuracy: 0.6111111111111112
# Precision: [0.76923077 0.2       ]
# Recall: [0.71428571 0.25      ]
# F-Score: [0.74074074 0.22222222]
# Support: [14  4]

# %% [markdown]
# ##### Value Test with optimalization

# %%
from Scripts.ValueTest import ValueTest as ValueTest

valueTest = ValueTest(settings.variables, threshold_value = bruteforce_threshold)
valueTest.worker(settings.variables)
# Out:
# C:\Programy\Anaconda\envs\py35\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy: 0.7777777777777778
# Precision: [0.77777778 0.        ]
# Recall: [1. 0.]
# F-Score: [0.875 0.   ]
# Support: [14  4]

# %% [markdown]
# ##### PSO K-Fold

# %%
from Scripts.OptimizePSOKFold import OptimizePSOKFold as OptimizePSOKFold

optimizePSOKFold = OptimizePSOKFold(settings.variables, settings.swarm_size, settings.dim, settings.epsilon, settings.iters, settings.options, settings.borders, settings.sigma_mean_params)
optimizePSOKFold.worker(settings.variables)
# Out:
# 2019-03-29 06:59:33,469 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'w': 0.9, 'c2': 0.3, 'c1': 0.5}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.208
# 2019-03-29 06:59:57,943 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.20833333333333337, best pos: [0.05383559]
# ------------------------------------- Fold 0 --------------------------------------
# Global minimum: [0.05383559]
# Train Accuracy: 0.7916666666666666
# Test Accuracy: 0.75
# Time: 24.49638319015503
# -----------------------------------------------------------------------------------
# 2019-03-29 06:59:57,994 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'w': 0.9, 'c2': 0.3, 'c1': 0.5}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.208
# 2019-03-29 07:00:23,031 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.20833333333333337, best pos: [0.05383559]
# ------------------------------------- Fold 1 --------------------------------------
# Global minimum: [0.05383559]
# Train Accuracy: 0.7916666666666666
# Test Accuracy: 0.75
# Time: 25.061046600341797
# -----------------------------------------------------------------------------------
# 2019-03-29 07:00:23,081 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'w': 0.9, 'c2': 0.3, 'c1': 0.5}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.208
# 2019-03-29 07:00:47,341 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.20833333333333337, best pos: [0.05383559]
# ------------------------------------- Fold 2 --------------------------------------
# Global minimum: [0.05383559]
# Train Accuracy: 0.7916666666666666
# Test Accuracy: 0.75
# Time: 24.28299832344055
# -----------------------------------------------------------------------------------
# 2019-03-29 07:00:47,386 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'w': 0.9, 'c2': 0.3, 'c1': 0.5}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.208
# 2019-03-29 07:01:12,039 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.20833333333333337, best pos: [0.05383559]
# ------------------------------------- Fold 3 --------------------------------------
# Global minimum: [0.05383559]
# Train Accuracy: 0.7916666666666666
# Test Accuracy: 0.75
# Time: 24.675004482269287
# -----------------------------------------------------------------------------------
# 2019-03-29 07:01:12,087 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'w': 0.9, 'c2': 0.3, 'c1': 0.5}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.208
# 2019-03-29 07:01:37,270 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.20833333333333337, best pos: [0.05383559]
# ------------------------------------- Fold 4 --------------------------------------
# Global minimum: [0.05383559]
# Train Accuracy: 0.7916666666666666
# Test Accuracy: 0.75
# Time: 25.20731520652771
# -----------------------------------------------------------------------------------
# 2019-03-29 07:01:37,328 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'w': 0.9, 'c2': 0.3, 'c1': 0.5}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.208
# 2019-03-29 07:02:02,947 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.20833333333333337, best pos: [0.05383559]
# ------------------------------------- Fold 5 --------------------------------------
# Global minimum: [0.05383559]
# Train Accuracy: 0.7916666666666666
# Test Accuracy: 0.8571428571428571
# Time: 25.646666765213013
# -----------------------------------------------------------------------------------
# 2019-03-29 07:02:03,006 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'w': 0.9, 'c2': 0.3, 'c1': 0.5}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.208
# 2019-03-29 07:02:27,715 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.20833333333333337, best pos: [0.05383559]
# ------------------------------------- Fold 6 --------------------------------------
# Global minimum: [0.05383559]
# Train Accuracy: 0.7916666666666666
# Test Accuracy: 0.8571428571428571
# Time: 24.734416246414185
# -----------------------------------------------------------------------------------
# 2019-03-29 07:02:27,770 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'w': 0.9, 'c2': 0.3, 'c1': 0.5}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.208
# 2019-03-29 07:02:53,152 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.20833333333333337, best pos: [0.05383559]
# ------------------------------------- Fold 7 --------------------------------------
# Global minimum: [0.05383559]
# Train Accuracy: 0.7916666666666666
# Test Accuracy: 0.8333333333333334
# Time: 25.40524959564209
# -----------------------------------------------------------------------------------
# 2019-03-29 07:02:53,210 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'w': 0.9, 'c2': 0.3, 'c1': 0.5}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.208
# 2019-03-29 07:03:19,582 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.20833333333333337, best pos: [0.05383559]
# ------------------------------------- Fold 8 --------------------------------------
# Global minimum: [0.05383559]
# Train Accuracy: 0.7916666666666666
# Test Accuracy: 0.8333333333333334
# Time: 26.395538806915283
# -----------------------------------------------------------------------------------
# 2019-03-29 07:03:19,639 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'w': 0.9, 'c2': 0.3, 'c1': 0.5}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.208
# 2019-03-29 07:03:44,184 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.20833333333333337, best pos: [0.05383559]
# ------------------------------------- Fold 9 --------------------------------------
# Global minimum: [0.05383559]
# Train Accuracy: 0.7916666666666666
# Test Accuracy: 0.8333333333333334
# Time: 24.565998077392578
# -----------------------------------------------------------------------------------

# %% [markdown]
# ##### Brute Force K-Fold

# %%
from Scripts.OptimizeBruteForceKFold import OptimizeBruteForceKFold as OptimizeBruteForceKFold

optimizeBruteForceKFold = OptimizeBruteForceKFold(settings.variables, settings.constraints, settings.sigma_mean_params)
optimizeBruteForceKFold.worker(settings.variables)
# Out:
# ------------------------------------- Fold 0 --------------------------------------
# Global minimum: [0.]
# Train Accuracy: 0.796875
# Test Accuracy: 0.75
# Time: 5.428999662399292
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 1 --------------------------------------
# Global minimum: [0.]
# Train Accuracy: 0.796875
# Test Accuracy: 0.75
# Time: 5.398973226547241
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 2 --------------------------------------
# Global minimum: [0.]
# Train Accuracy: 0.796875
# Test Accuracy: 0.75
# Time: 5.415000915527344
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 3 --------------------------------------
# Global minimum: [0.]
# Train Accuracy: 0.796875
# Test Accuracy: 0.75
# Time: 5.507016897201538
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 4 --------------------------------------
# Global minimum: [0.]
# Train Accuracy: 0.796875
# Test Accuracy: 0.75
# Time: 5.4169981479644775
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 5 --------------------------------------
# Global minimum: [0.]
# Train Accuracy: 0.7846153846153846
# Test Accuracy: 0.8571428571428571
# Time: 5.518015384674072
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 6 --------------------------------------
# Global minimum: [0.]
# Train Accuracy: 0.7846153846153846
# Test Accuracy: 0.8571428571428571
# Time: 5.433014869689941
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 7 --------------------------------------
# Global minimum: [0.]
# Train Accuracy: 0.7878787878787878
# Test Accuracy: 0.8333333333333334
# Time: 5.5060155391693115
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 8 --------------------------------------
# Global minimum: [0.]
# Train Accuracy: 0.7878787878787878
# Test Accuracy: 0.8333333333333334
# Time: 5.616982698440552
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 9 --------------------------------------
# Global minimum: [0.]
# Train Accuracy: 0.7878787878787878
# Test Accuracy: 0.8333333333333334
# Time: 5.5770204067230225
# -----------------------------------------------------------------------------------
