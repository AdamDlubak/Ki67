# %%
import SettingsPimaIndians as settings

# %% [markdown]
# ##### Main Notebook - CSV

# %%
from Scripts.LoadCSV import LoadCSV as LoadCSV

loadCSV = LoadCSV()
loadCSV.workerCSV(settings.variables)
# Out:
# 61it [00:17,  3.57it/s]
# Finished!

# %% [markdown]
# ##### Brute Force

# %%
from Scripts.OptimizeBruteForce import OptimizeBruteForce as OptimizeBruteForce

optimizeBruteForce = OptimizeBruteForce(settings.variables, settings.constraints, settings.sigma_mean_params)
bruteforce_threshold = optimizeBruteForce.worker(settings.variables)
# Out:
# Global minimum: [0.4]
# Function value at global minimum: 0.26517571884984026
# Accuracy: 0.7348242811501597
# Time: 39.31326198577881

# %% [markdown]
# ##### PSO

# %%
from Scripts.OptimizePSO import OptimizePSO as OptimizePSO

optimizePSO = OptimizePSO(settings.variables, settings.swarm_size, settings.dim, settings.epsilon, settings.iters, settings.options, settings.borders, settings.sigma_mean_params)
optimizePSO.worker(settings.variables)
# Out:
# 2019-03-28 01:12:09,732 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.265
# 2019-03-28 01:14:07,986 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.26517571884984026, best pos: [0.40018572]
# Global minimum: [0.40018572]
# Function value at global minimum: 0.26517571884984026
# Accuracy: 0.7348242811501597
# Time: 118.2873330116272
# array([0.40018572])

# %% [markdown]
# ##### Value Train without optimalization

# %%
from Scripts.ValueTrain import ValueTrain as ValueTrain
valueTrain = ValueTrain(settings.variables, threshold_value = -1)
valueTrain.worker(settings.variables)
# Out:
# Accuracy: 0.7124600638977636
# Precision: [0.82320442 0.56060606]
# Recall: [0.71980676 0.69811321]
# F-Score: [0.76804124 0.62184874]
# Support: [207 106]

# %% [markdown]
# ##### Value Test without optimalization

# %%
from Scripts.ValueTest import ValueTest as ValueTest

valueTest = ValueTest(settings.variables, threshold_value = -1)
valueTest.worker(settings.variables)
# Out:
# Accuracy: 0.6075949367088608
# Precision: [0.75       0.38709677]
# Recall: [0.65454545 0.5       ]
# F-Score: [0.69902913 0.43636364]
# Support: [55 24]

# %% [markdown]
# ##### Value Train with optimalization

# %%
from Scripts.ValueTrain import ValueTrain as ValueTrain

valueTrain = ValueTrain(settings.variables, threshold_value = bruteforce_threshold)
valueTrain.worker(settings.variables)
# Out:
# Accuracy: 0.7348242811501597
# Precision: [0.87804878 0.57718121]
# Recall: [0.69565217 0.81132075]
# F-Score: [0.77628032 0.6745098 ]
# Support: [207 106]

# %% [markdown]
# ##### Value Test with optimalization

# %%
from Scripts.ValueTest import ValueTest as ValueTest

valueTest = ValueTest(settings.variables, threshold_value = bruteforce_threshold)
valueTest.worker(settings.variables)
# Out:
# Accuracy: 0.6075949367088608
# Precision: [0.75       0.38709677]
# Recall: [0.65454545 0.5       ]
# F-Score: [0.69902913 0.43636364]
# Support: [55 24]

# %% [markdown]
# ##### PSO K-Fold

# %%
from Scripts.OptimizePSOKFold import OptimizePSOKFold as OptimizePSOKFold

optimizePSOKFold = OptimizePSOKFold(settings.variables, settings.swarm_size, settings.dim, settings.epsilon, settings.iters, settings.options, settings.borders, settings.sigma_mean_params)
optimizePSOKFold.worker(settings.variables)
# Out:
# 2019-03-28 01:41:15,844 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
#
#
#
#
#
#
# pyswarms.single.global_best:   0%|                                                                                |0/20
#
#
#
#
#
# pyswarms.single.global_best:   0%|                                                               |0/20, best_cost=0.297
#
#
#
#
#
# pyswarms.single.global_best:   5%|███▏                                                           |1/20, best_cost=0.297
#
#
#
#
#
# pyswarms.single.global_best:   5%|███▏                                                           |1/20, best_cost=0.272
#
#
#
#
#
# pyswarms.single.global_best:  10%|██████▎                                                        |2/20, best_cost=0.272
#
#
#
#
#
# pyswarms.single.global_best:  10%|██████▎                                                        |2/20, best_cost=0.272
#
#
#
#
#
# pyswarms.single.global_best:  15%|█████████▍                                                     |3/20, best_cost=0.272
#
#
#
#
#
# pyswarms.single.global_best:  15%|█████████▍                                                     |3/20, best_cost=0.272
#
#
#
#
#
# pyswarms.single.global_best:  20%|████████████▌                                                  |4/20, best_cost=0.272
#
#
#
#
#
# pyswarms.single.global_best:  20%|████████████▌                                                  |4/20, best_cost=0.272
#
#
#
#
#
# pyswarms.single.global_best:  25%|███████████████▊                                               |5/20, best_cost=0.272
#
#
#
#
#
# pyswarms.single.global_best:  25%|███████████████▊                                               |5/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  30%|██████████████████▉                                            |6/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  30%|██████████████████▉                                            |6/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  35%|██████████████████████                                         |7/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  35%|██████████████████████                                         |7/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  40%|█████████████████████████▏                                     |8/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  40%|█████████████████████████▏                                     |8/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  45%|████████████████████████████▎                                  |9/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  45%|████████████████████████████▎                                  |9/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  50%|███████████████████████████████                               |10/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  50%|███████████████████████████████                               |10/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  55%|██████████████████████████████████                            |11/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  55%|██████████████████████████████████                            |11/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  60%|█████████████████████████████████████▏                        |12/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  60%|█████████████████████████████████████▏                        |12/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  65%|████████████████████████████████████████▎                     |13/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  65%|████████████████████████████████████████▎                     |13/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  70%|███████████████████████████████████████████▍                  |14/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  70%|███████████████████████████████████████████▍                  |14/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  75%|██████████████████████████████████████████████▌               |15/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  75%|██████████████████████████████████████████████▌               |15/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  80%|█████████████████████████████████████████████████▌            |16/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  80%|█████████████████████████████████████████████████▌            |16/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  85%|████████████████████████████████████████████████████▋         |17/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  85%|████████████████████████████████████████████████████▋         |17/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  90%|███████████████████████████████████████████████████████▊      |18/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  90%|███████████████████████████████████████████████████████▊      |18/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  95%|██████████████████████████████████████████████████████████▉   |19/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  95%|██████████████████████████████████████████████████████████▉   |19/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.265
#
#
#
#
#
# 2019-03-28 01:43:10,734 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.26517571884984026, best pos: [0.40571146]
# ------------------------------------- Fold 0 --------------------------------------
# Global minimum: [0.40571146]
# Train Accuracy: 0.7348242811501597
# Test Accuracy: 0.78125
# Time: 114.93970704078674
# -----------------------------------------------------------------------------------
# 2019-03-28 01:43:10,810 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
#
#
#
#
#
#
# pyswarms.single.global_best:   0%|                                                                                |0/20
#
#
#
#
#
# pyswarms.single.global_best:   0%|                                                               |0/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:   5%|███▏                                                           |1/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:   5%|███▏                                                           |1/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  10%|██████▎                                                        |2/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  10%|██████▎                                                        |2/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  15%|█████████▍                                                     |3/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  15%|█████████▍                                                     |3/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  20%|████████████▌                                                  |4/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  20%|████████████▌                                                  |4/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  25%|███████████████▊                                               |5/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  25%|███████████████▊                                               |5/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  30%|██████████████████▉                                            |6/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  30%|██████████████████▉                                            |6/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  35%|██████████████████████                                         |7/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  35%|██████████████████████                                         |7/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  40%|█████████████████████████▏                                     |8/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  40%|█████████████████████████▏                                     |8/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  45%|████████████████████████████▎                                  |9/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  45%|████████████████████████████▎                                  |9/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  50%|███████████████████████████████                               |10/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  50%|███████████████████████████████                               |10/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  55%|██████████████████████████████████                            |11/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  55%|██████████████████████████████████                            |11/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  60%|█████████████████████████████████████▏                        |12/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  60%|█████████████████████████████████████▏                        |12/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  65%|████████████████████████████████████████▎                     |13/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  65%|████████████████████████████████████████▎                     |13/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  70%|███████████████████████████████████████████▍                  |14/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  70%|███████████████████████████████████████████▍                  |14/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  75%|██████████████████████████████████████████████▌               |15/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  75%|██████████████████████████████████████████████▌               |15/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  80%|█████████████████████████████████████████████████▌            |16/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  80%|█████████████████████████████████████████████████▌            |16/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  85%|████████████████████████████████████████████████████▋         |17/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  85%|████████████████████████████████████████████████████▋         |17/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  90%|███████████████████████████████████████████████████████▊      |18/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  90%|███████████████████████████████████████████████████████▊      |18/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  95%|██████████████████████████████████████████████████████████▉   |19/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  95%|██████████████████████████████████████████████████████████▉   |19/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.265
#
#
#
#
#
# 2019-03-28 01:45:07,031 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.26517571884984026, best pos: [0.40571146]
# ------------------------------------- Fold 1 --------------------------------------
# Global minimum: [0.40571146]
# Train Accuracy: 0.7348242811501597
# Test Accuracy: 0.6875
# Time: 116.27358150482178
# -----------------------------------------------------------------------------------
# 2019-03-28 01:45:07,112 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
#
#
#
#
#
#
# pyswarms.single.global_best:   0%|                                                                                |0/20
#
#
#
#
#
# pyswarms.single.global_best:   0%|                                                               |0/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:   5%|███▏                                                           |1/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:   5%|███▏                                                           |1/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  10%|██████▎                                                        |2/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  10%|██████▎                                                        |2/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  15%|█████████▍                                                     |3/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  15%|█████████▍                                                     |3/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  20%|████████████▌                                                  |4/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  20%|████████████▌                                                  |4/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  25%|███████████████▊                                               |5/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  25%|███████████████▊                                               |5/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  30%|██████████████████▉                                            |6/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  30%|██████████████████▉                                            |6/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  35%|██████████████████████                                         |7/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  35%|██████████████████████                                         |7/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  40%|█████████████████████████▏                                     |8/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  40%|█████████████████████████▏                                     |8/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  45%|████████████████████████████▎                                  |9/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  45%|████████████████████████████▎                                  |9/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  50%|███████████████████████████████                               |10/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  50%|███████████████████████████████                               |10/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  55%|██████████████████████████████████                            |11/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  55%|██████████████████████████████████                            |11/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  60%|█████████████████████████████████████▏                        |12/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  60%|█████████████████████████████████████▏                        |12/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  65%|████████████████████████████████████████▎                     |13/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  65%|████████████████████████████████████████▎                     |13/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  70%|███████████████████████████████████████████▍                  |14/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  70%|███████████████████████████████████████████▍                  |14/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  75%|██████████████████████████████████████████████▌               |15/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  75%|██████████████████████████████████████████████▌               |15/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  80%|█████████████████████████████████████████████████▌            |16/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  80%|█████████████████████████████████████████████████▌            |16/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  85%|████████████████████████████████████████████████████▋         |17/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  85%|████████████████████████████████████████████████████▋         |17/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  90%|███████████████████████████████████████████████████████▊      |18/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  90%|███████████████████████████████████████████████████████▊      |18/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  95%|██████████████████████████████████████████████████████████▉   |19/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  95%|██████████████████████████████████████████████████████████▉   |19/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.265
#
#
#
#
#
# 2019-03-28 01:47:01,875 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.26517571884984026, best pos: [0.40571146]
# ------------------------------------- Fold 2 --------------------------------------
# Global minimum: [0.40571146]
# Train Accuracy: 0.7348242811501597
# Test Accuracy: 0.8125
# Time: 114.81632471084595
# -----------------------------------------------------------------------------------
# 2019-03-28 01:47:01,952 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
#
#
#
#
#
#
# pyswarms.single.global_best:   0%|                                                                                |0/20
#
#
#
#
#
# pyswarms.single.global_best:   0%|                                                               |0/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:   5%|███▏                                                           |1/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:   5%|███▏                                                           |1/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  10%|██████▎                                                        |2/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  10%|██████▎                                                        |2/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  15%|█████████▍                                                     |3/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  15%|█████████▍                                                     |3/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  20%|████████████▌                                                  |4/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  20%|████████████▌                                                  |4/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  25%|███████████████▊                                               |5/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  25%|███████████████▊                                               |5/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  30%|██████████████████▉                                            |6/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  30%|██████████████████▉                                            |6/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  35%|██████████████████████                                         |7/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  35%|██████████████████████                                         |7/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  40%|█████████████████████████▏                                     |8/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  40%|█████████████████████████▏                                     |8/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  45%|████████████████████████████▎                                  |9/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  45%|████████████████████████████▎                                  |9/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  50%|███████████████████████████████                               |10/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  50%|███████████████████████████████                               |10/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  55%|██████████████████████████████████                            |11/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  55%|██████████████████████████████████                            |11/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  60%|█████████████████████████████████████▏                        |12/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  60%|█████████████████████████████████████▏                        |12/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  65%|████████████████████████████████████████▎                     |13/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  65%|████████████████████████████████████████▎                     |13/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  70%|███████████████████████████████████████████▍                  |14/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  70%|███████████████████████████████████████████▍                  |14/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  75%|██████████████████████████████████████████████▌               |15/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  75%|██████████████████████████████████████████████▌               |15/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  80%|█████████████████████████████████████████████████▌            |16/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  80%|█████████████████████████████████████████████████▌            |16/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  85%|████████████████████████████████████████████████████▋         |17/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  85%|████████████████████████████████████████████████████▋         |17/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  90%|███████████████████████████████████████████████████████▊      |18/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  90%|███████████████████████████████████████████████████████▊      |18/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  95%|██████████████████████████████████████████████████████████▉   |19/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  95%|██████████████████████████████████████████████████████████▉   |19/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.265
#
#
#
#
#
# 2019-03-28 01:48:56,757 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.26517571884984026, best pos: [0.40571146]
# ------------------------------------- Fold 3 --------------------------------------
# Global minimum: [0.40571146]
# Train Accuracy: 0.7348242811501597
# Test Accuracy: 0.8125
# Time: 114.85465455055237
# -----------------------------------------------------------------------------------
# 2019-03-28 01:48:56,838 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
#
#
#
#
#
#
# pyswarms.single.global_best:   0%|                                                                                |0/20
#
#
#
#
#
# pyswarms.single.global_best:   0%|                                                               |0/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:   5%|███▏                                                           |1/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:   5%|███▏                                                           |1/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  10%|██████▎                                                        |2/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  10%|██████▎                                                        |2/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  15%|█████████▍                                                     |3/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  15%|█████████▍                                                     |3/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  20%|████████████▌                                                  |4/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  20%|████████████▌                                                  |4/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  25%|███████████████▊                                               |5/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  25%|███████████████▊                                               |5/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  30%|██████████████████▉                                            |6/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  30%|██████████████████▉                                            |6/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  35%|██████████████████████                                         |7/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  35%|██████████████████████                                         |7/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  40%|█████████████████████████▏                                     |8/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  40%|█████████████████████████▏                                     |8/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  45%|████████████████████████████▎                                  |9/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  45%|████████████████████████████▎                                  |9/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  50%|███████████████████████████████                               |10/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  50%|███████████████████████████████                               |10/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  55%|██████████████████████████████████                            |11/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  55%|██████████████████████████████████                            |11/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  60%|█████████████████████████████████████▏                        |12/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  60%|█████████████████████████████████████▏                        |12/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  65%|████████████████████████████████████████▎                     |13/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  65%|████████████████████████████████████████▎                     |13/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  70%|███████████████████████████████████████████▍                  |14/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  70%|███████████████████████████████████████████▍                  |14/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  75%|██████████████████████████████████████████████▌               |15/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  75%|██████████████████████████████████████████████▌               |15/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  80%|█████████████████████████████████████████████████▌            |16/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  80%|█████████████████████████████████████████████████▌            |16/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  85%|████████████████████████████████████████████████████▋         |17/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  85%|████████████████████████████████████████████████████▋         |17/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  90%|███████████████████████████████████████████████████████▊      |18/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  90%|███████████████████████████████████████████████████████▊      |18/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  95%|██████████████████████████████████████████████████████████▉   |19/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  95%|██████████████████████████████████████████████████████████▉   |19/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.265
#
#
#
#
#
# 2019-03-28 01:50:53,836 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.26517571884984026, best pos: [0.40571146]
# ------------------------------------- Fold 4 --------------------------------------
# Global minimum: [0.40571146]
# Train Accuracy: 0.7348242811501597
# Test Accuracy: 0.75
# Time: 117.0473985671997
# -----------------------------------------------------------------------------------
# 2019-03-28 01:50:53,914 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
#
#
#
#
#
#
# pyswarms.single.global_best:   0%|                                                                                |0/20
#
#
#
#
#
# pyswarms.single.global_best:   0%|                                                               |0/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:   5%|███▏                                                           |1/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:   5%|███▏                                                           |1/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  10%|██████▎                                                        |2/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  10%|██████▎                                                        |2/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  15%|█████████▍                                                     |3/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  15%|█████████▍                                                     |3/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  20%|████████████▌                                                  |4/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  20%|████████████▌                                                  |4/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  25%|███████████████▊                                               |5/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  25%|███████████████▊                                               |5/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  30%|██████████████████▉                                            |6/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  30%|██████████████████▉                                            |6/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  35%|██████████████████████                                         |7/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  35%|██████████████████████                                         |7/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  40%|█████████████████████████▏                                     |8/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  40%|█████████████████████████▏                                     |8/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  45%|████████████████████████████▎                                  |9/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  45%|████████████████████████████▎                                  |9/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  50%|███████████████████████████████                               |10/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  50%|███████████████████████████████                               |10/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  55%|██████████████████████████████████                            |11/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  55%|██████████████████████████████████                            |11/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  60%|█████████████████████████████████████▏                        |12/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  60%|█████████████████████████████████████▏                        |12/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  65%|████████████████████████████████████████▎                     |13/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  65%|████████████████████████████████████████▎                     |13/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  70%|███████████████████████████████████████████▍                  |14/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  70%|███████████████████████████████████████████▍                  |14/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  75%|██████████████████████████████████████████████▌               |15/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  75%|██████████████████████████████████████████████▌               |15/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  80%|█████████████████████████████████████████████████▌            |16/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  80%|█████████████████████████████████████████████████▌            |16/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  85%|████████████████████████████████████████████████████▋         |17/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  85%|████████████████████████████████████████████████████▋         |17/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  90%|███████████████████████████████████████████████████████▊      |18/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  90%|███████████████████████████████████████████████████████▊      |18/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  95%|██████████████████████████████████████████████████████████▉   |19/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  95%|██████████████████████████████████████████████████████████▉   |19/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.265
#
#
#
#
#
# 2019-03-28 01:52:47,739 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.26517571884984026, best pos: [0.40571146]
# ------------------------------------- Fold 5 --------------------------------------
# Global minimum: [0.40571146]
# Train Accuracy: 0.7348242811501597
# Test Accuracy: 0.8125
# Time: 113.87110638618469
# -----------------------------------------------------------------------------------
# 2019-03-28 01:52:47,809 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
#
#
#
#
#
#
# pyswarms.single.global_best:   0%|                                                                                |0/20
#
#
#
#
#
# pyswarms.single.global_best:   0%|                                                               |0/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:   5%|███▏                                                           |1/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:   5%|███▏                                                           |1/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  10%|██████▎                                                        |2/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  10%|██████▎                                                        |2/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  15%|█████████▍                                                     |3/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  15%|█████████▍                                                     |3/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  20%|████████████▌                                                  |4/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  20%|████████████▌                                                  |4/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  25%|███████████████▊                                               |5/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  25%|███████████████▊                                               |5/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  30%|██████████████████▉                                            |6/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  30%|██████████████████▉                                            |6/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  35%|██████████████████████                                         |7/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  35%|██████████████████████                                         |7/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  40%|█████████████████████████▏                                     |8/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  40%|█████████████████████████▏                                     |8/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  45%|████████████████████████████▎                                  |9/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  45%|████████████████████████████▎                                  |9/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  50%|███████████████████████████████                               |10/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  50%|███████████████████████████████                               |10/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  55%|██████████████████████████████████                            |11/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  55%|██████████████████████████████████                            |11/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  60%|█████████████████████████████████████▏                        |12/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  60%|█████████████████████████████████████▏                        |12/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  65%|████████████████████████████████████████▎                     |13/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  65%|████████████████████████████████████████▎                     |13/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  70%|███████████████████████████████████████████▍                  |14/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  70%|███████████████████████████████████████████▍                  |14/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  75%|██████████████████████████████████████████████▌               |15/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  75%|██████████████████████████████████████████████▌               |15/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  80%|█████████████████████████████████████████████████▌            |16/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  80%|█████████████████████████████████████████████████▌            |16/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  85%|████████████████████████████████████████████████████▋         |17/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  85%|████████████████████████████████████████████████████▋         |17/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  90%|███████████████████████████████████████████████████████▊      |18/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  90%|███████████████████████████████████████████████████████▊      |18/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  95%|██████████████████████████████████████████████████████████▉   |19/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  95%|██████████████████████████████████████████████████████████▉   |19/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.265
#
#
#
#
#
# 2019-03-28 01:54:34,202 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.26517571884984026, best pos: [0.40571146]
# ------------------------------------- Fold 6 --------------------------------------
# Global minimum: [0.40571146]
# Train Accuracy: 0.7348242811501597
# Test Accuracy: 0.6451612903225806
# Time: 106.4378924369812
# -----------------------------------------------------------------------------------
# 2019-03-28 01:54:34,272 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
#
#
#
#
#
#
# pyswarms.single.global_best:   0%|                                                                                |0/20
#
#
#
#
#
# pyswarms.single.global_best:   0%|                                                               |0/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:   5%|███▏                                                           |1/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:   5%|███▏                                                           |1/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  10%|██████▎                                                        |2/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  10%|██████▎                                                        |2/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  15%|█████████▍                                                     |3/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  15%|█████████▍                                                     |3/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  20%|████████████▌                                                  |4/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  20%|████████████▌                                                  |4/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  25%|███████████████▊                                               |5/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  25%|███████████████▊                                               |5/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  30%|██████████████████▉                                            |6/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  30%|██████████████████▉                                            |6/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  35%|██████████████████████                                         |7/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  35%|██████████████████████                                         |7/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  40%|█████████████████████████▏                                     |8/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  40%|█████████████████████████▏                                     |8/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  45%|████████████████████████████▎                                  |9/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  45%|████████████████████████████▎                                  |9/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  50%|███████████████████████████████                               |10/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  50%|███████████████████████████████                               |10/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  55%|██████████████████████████████████                            |11/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  55%|██████████████████████████████████                            |11/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  60%|█████████████████████████████████████▏                        |12/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  60%|█████████████████████████████████████▏                        |12/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  65%|████████████████████████████████████████▎                     |13/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  65%|████████████████████████████████████████▎                     |13/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  70%|███████████████████████████████████████████▍                  |14/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  70%|███████████████████████████████████████████▍                  |14/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  75%|██████████████████████████████████████████████▌               |15/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  75%|██████████████████████████████████████████████▌               |15/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  80%|█████████████████████████████████████████████████▌            |16/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  80%|█████████████████████████████████████████████████▌            |16/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  85%|████████████████████████████████████████████████████▋         |17/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  85%|████████████████████████████████████████████████████▋         |17/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  90%|███████████████████████████████████████████████████████▊      |18/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  90%|███████████████████████████████████████████████████████▊      |18/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  95%|██████████████████████████████████████████████████████████▉   |19/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  95%|██████████████████████████████████████████████████████████▉   |19/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.265
#
#
#
#
#
# 2019-03-28 01:56:19,272 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.26517571884984026, best pos: [0.40571146]
# ------------------------------------- Fold 7 --------------------------------------
# Global minimum: [0.40571146]
# Train Accuracy: 0.7348242811501597
# Test Accuracy: 0.7333333333333333
# Time: 105.05200815200806
# -----------------------------------------------------------------------------------
# 2019-03-28 01:56:19,360 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
#
#
#
#
#
#
# pyswarms.single.global_best:   0%|                                                                                |0/20
#
#
#
#
#
# pyswarms.single.global_best:   0%|                                                               |0/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:   5%|███▏                                                           |1/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:   5%|███▏                                                           |1/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  10%|██████▎                                                        |2/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  10%|██████▎                                                        |2/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  15%|█████████▍                                                     |3/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  15%|█████████▍                                                     |3/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  20%|████████████▌                                                  |4/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  20%|████████████▌                                                  |4/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  25%|███████████████▊                                               |5/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  25%|███████████████▊                                               |5/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  30%|██████████████████▉                                            |6/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  30%|██████████████████▉                                            |6/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  35%|██████████████████████                                         |7/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  35%|██████████████████████                                         |7/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  40%|█████████████████████████▏                                     |8/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  40%|█████████████████████████▏                                     |8/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  45%|████████████████████████████▎                                  |9/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  45%|████████████████████████████▎                                  |9/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  50%|███████████████████████████████                               |10/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  50%|███████████████████████████████                               |10/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  55%|██████████████████████████████████                            |11/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  55%|██████████████████████████████████                            |11/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  60%|█████████████████████████████████████▏                        |12/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  60%|█████████████████████████████████████▏                        |12/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  65%|████████████████████████████████████████▎                     |13/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  65%|████████████████████████████████████████▎                     |13/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  70%|███████████████████████████████████████████▍                  |14/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  70%|███████████████████████████████████████████▍                  |14/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  75%|██████████████████████████████████████████████▌               |15/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  75%|██████████████████████████████████████████████▌               |15/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  80%|█████████████████████████████████████████████████▌            |16/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  80%|█████████████████████████████████████████████████▌            |16/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  85%|████████████████████████████████████████████████████▋         |17/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  85%|████████████████████████████████████████████████████▋         |17/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  90%|███████████████████████████████████████████████████████▊      |18/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  90%|███████████████████████████████████████████████████████▊      |18/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  95%|██████████████████████████████████████████████████████████▉   |19/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  95%|██████████████████████████████████████████████████████████▉   |19/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.265
#
#
#
#
#
# 2019-03-28 01:58:03,894 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.26517571884984026, best pos: [0.40571146]
# ------------------------------------- Fold 8 --------------------------------------
# Global minimum: [0.40571146]
# Train Accuracy: 0.7348242811501597
# Test Accuracy: 0.7
# Time: 104.5805766582489
# -----------------------------------------------------------------------------------
# 2019-03-28 01:58:03,961 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'c1': 0.5, 'c2': 0.3, 'w': 0.9}
#
#
#
#
#
#
# pyswarms.single.global_best:   0%|                                                                                |0/20
#
#
#
#
#
# pyswarms.single.global_best:   0%|                                                               |0/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:   5%|███▏                                                           |1/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:   5%|███▏                                                           |1/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  10%|██████▎                                                        |2/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  10%|██████▎                                                        |2/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  15%|█████████▍                                                     |3/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  15%|█████████▍                                                     |3/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  20%|████████████▌                                                  |4/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  20%|████████████▌                                                  |4/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  25%|███████████████▊                                               |5/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  25%|███████████████▊                                               |5/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  30%|██████████████████▉                                            |6/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  30%|██████████████████▉                                            |6/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  35%|██████████████████████                                         |7/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  35%|██████████████████████                                         |7/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  40%|█████████████████████████▏                                     |8/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  40%|█████████████████████████▏                                     |8/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  45%|████████████████████████████▎                                  |9/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  45%|████████████████████████████▎                                  |9/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  50%|███████████████████████████████                               |10/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  50%|███████████████████████████████                               |10/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  55%|██████████████████████████████████                            |11/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  55%|██████████████████████████████████                            |11/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  60%|█████████████████████████████████████▏                        |12/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  60%|█████████████████████████████████████▏                        |12/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  65%|████████████████████████████████████████▎                     |13/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  65%|████████████████████████████████████████▎                     |13/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  70%|███████████████████████████████████████████▍                  |14/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  70%|███████████████████████████████████████████▍                  |14/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  75%|██████████████████████████████████████████████▌               |15/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  75%|██████████████████████████████████████████████▌               |15/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  80%|█████████████████████████████████████████████████▌            |16/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  80%|█████████████████████████████████████████████████▌            |16/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  85%|████████████████████████████████████████████████████▋         |17/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  85%|████████████████████████████████████████████████████▋         |17/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  90%|███████████████████████████████████████████████████████▊      |18/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  90%|███████████████████████████████████████████████████████▊      |18/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  95%|██████████████████████████████████████████████████████████▉   |19/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best:  95%|██████████████████████████████████████████████████████████▉   |19/20, best_cost=0.265
#
#
#
#
#
# pyswarms.single.global_best: 100%|██████████████████████████████████████████████████████████████|20/20, best_cost=0.265
#
#
#
#
#
# 2019-03-28 01:59:53,149 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.26517571884984026, best pos: [0.40571146]
# ------------------------------------- Fold 9 --------------------------------------
# Global minimum: [0.40571146]
# Train Accuracy: 0.7348242811501597
# Test Accuracy: 0.6
# Time: 109.23003768920898
# -----------------------------------------------------------------------------------

# %% [markdown]
# ##### Brute Force K-Fold

# %%
from Scripts.OptimizeBruteForceKFold import OptimizeBruteForceKFold as OptimizeBruteForceKFold

optimizeBruteForceKFold = OptimizeBruteForceKFold(settings.variables, settings.constraints, settings.sigma_mean_params)
optimizeBruteForceKFold.worker(settings.variables)
# Out:
# ------------------------------------- Fold 0 --------------------------------------
# Global minimum: [0.39]
# Train Accuracy: 0.7330960854092526
# Test Accuracy: 0.65625
# Time: 32.25135636329651
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 1 --------------------------------------
# Global minimum: [0.405]
# Train Accuracy: 0.7402135231316725
# Test Accuracy: 0.6875
# Time: 33.694000482559204
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 2 --------------------------------------
# Global minimum: [0.4]
# Train Accuracy: 0.7330960854092526
# Test Accuracy: 0.75
# Time: 32.29699397087097
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 3 --------------------------------------
# Global minimum: [0.405]
# Train Accuracy: 0.7259786476868327
# Test Accuracy: 0.8125
# Time: 35.379008531570435
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 4 --------------------------------------
# Global minimum: [0.4]
# Train Accuracy: 0.7366548042704626
# Test Accuracy: 0.71875
# Time: 36.606998443603516
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 5 --------------------------------------
# Global minimum: [0.4]
# Train Accuracy: 0.7259786476868327
# Test Accuracy: 0.8125
# Time: 34.13299059867859
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 6 --------------------------------------
# Global minimum: [0.4]
# Train Accuracy: 0.7446808510638298
# Test Accuracy: 0.6451612903225806
# Time: 33.065983057022095
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 7 --------------------------------------
# Global minimum: [0.405]
# Train Accuracy: 0.734982332155477
# Test Accuracy: 0.7333333333333333
# Time: 35.31800556182861
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 8 --------------------------------------
# Global minimum: [0.405]
# Train Accuracy: 0.7385159010600707
# Test Accuracy: 0.7
# Time: 34.01010727882385
# -----------------------------------------------------------------------------------
# ------------------------------------- Fold 9 --------------------------------------
# Global minimum: [0.4]
# Train Accuracy: 0.7491166077738516
# Test Accuracy: 0.6
# Time: 34.645034074783325
# -----------------------------------------------------------------------------------
