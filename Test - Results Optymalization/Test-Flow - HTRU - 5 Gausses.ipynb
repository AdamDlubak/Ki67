# %%
import SettingsHTRUFiveGausses as settings

# %% [markdown]
# ##### Main Notebook - CSV

# %%
from Scripts.LoadCSV import LoadCSV as LoadCSV

loadCSV = LoadCSV()
loadCSV.workerCSV(settings.variables)
# Out:
# C:\Programy\Anaconda\envs\py35\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
#               F0         F1         F2         F3         F4         F5  \
# 7547      Middle     Middle     Middle   Very Low   Very Low   Very Low
# 10009     Middle     Middle     Middle   Very Low   Very Low   Very Low
# 16973     Middle     Middle     Middle   Very Low   Very Low   Very Low
# 5884    Very Low   Very Low  Very High  Very High   Very Low   Very Low
# 3236      Middle       High     Middle   Very Low       High       High
# 13270  Very High     Middle   Very Low   Very Low  Very High       High
# 13215     Middle     Middle     Middle   Very Low  Very High       High
# 9925      Middle   Very Low     Middle     Middle     Middle  Very High
# 17265     Middle     Middle     Middle   Very Low   Very Low   Very Low
# 13478     Middle     Middle     Middle   Very Low   Very Low   Very Low
# 7834      Middle  Very High     Middle   Very Low   Very Low   Very Low
# 13641     Middle   Very Low     Middle     Middle   Very Low   Very Low
# 8343   Very High     Middle     Middle   Very Low   Very Low   Very Low
# 4116      Middle     Middle     Middle     Middle   Very Low   Very Low
# 8594      Middle   Very Low     Middle   Very Low   Very Low     Middle
# 17024  Very High     Middle   Very Low   Very Low       High       High
# 14494     Middle  Very High     Middle   Very Low   Very Low   Very Low
# 14346     Middle   Very Low     Middle  Very High   Very Low   Very Low
# 9204      Middle     Middle     Middle   Very Low   Very Low   Very Low
# 9354      Middle  Very High     Middle   Very Low   Very Low   Very Low
# 10012        Low     Middle       High       High       High       High
# 6413    Very Low   Very Low     Middle     Middle   Very Low     Middle
# 3398    Very Low   Very Low       High       High       High       High
# 9252      Middle     Middle     Middle   Very Low       High  Very High
# 790       Middle     Middle     Middle   Very Low   Very Low     Middle
# 16923     Middle     Middle     Middle   Very Low   Very Low   Very Low
# 6760      Middle  Very High     Middle   Very Low   Very Low   Very Low
# 1756      Middle     Middle     Middle   Very Low   Very Low   Very Low
# 5428      Middle     Middle     Middle   Very Low   Very Low   Very Low
# 13806   Very Low   Very Low  Very High  Very High   Very Low  Very High
# ...          ...        ...        ...        ...        ...        ...
# 5577      Middle     Middle     Middle   Very Low   Very Low   Very Low
# 10525     Middle     Middle   Very Low   Very Low   Very Low   Very Low
# 4337      Middle     Middle     Middle   Very Low   Very Low   Very Low
# 15768     Middle     Middle     Middle   Very Low   Very Low   Very Low
# 5622    Very Low     Middle  Very High  Very High  Very High       High
# 2867      Middle     Middle     Middle   Very Low   Very Low   Very Low
# 14590  Very High     Middle     Middle   Very Low   Very Low   Very Low
# 8046    Very Low   Very Low       High       High  Very High  Very High
# 15123     Middle     Middle     Middle   Very Low   Very Low   Very Low
# 12119     Middle     Middle     Middle   Very Low   Very Low   Very Low
# 3485      Middle     Middle     Middle   Very Low   Very Low   Very Low
# 6276      Middle     Middle     Middle   Very Low   Very Low  Very High
# 15819     Middle  Very High     Middle   Very Low   Very Low   Very Low
# 1779      Middle     Middle     Middle   Very Low   Very Low     Middle
# 14743     Middle  Very High     Middle   Very Low   Very Low     Middle
# 8332      Middle   Very Low     Middle     Middle   Very Low   Very Low
# 9823      Middle     Middle     Middle   Very Low   Very Low     Middle
# 10434     Middle  Very High     Middle   Very Low   Very Low   Very Low
# 12047     Middle  Very High     Middle   Very Low   Very Low   Very Low
# 16280     Middle     Middle     Middle     Middle   Very Low   Very Low
# 13928     Middle     Middle     Middle   Very Low   Very Low   Very Low
# 17506     Middle     Middle     Middle   Very Low   Very Low   Very Low
# 8003      Middle     Middle     Middle   Very Low   Very Low  Very High
# 4328      Middle     Middle     Middle   Very Low   Very Low     Middle
# 17533  Very High     Middle   Very Low   Very Low       High       High
# 9253   Very High       High   Very Low   Very Low       High  Very High
# 14484  Very High     Middle   Very Low   Very Low   Very Low   Very Low
# 15046     Middle     Middle     Middle   Very Low   Very Low     Middle
# 15849     Middle   Very Low     Middle  Very High   Very Low   Very Low
# 17193     Middle     Middle     Middle   Very Low   Very Low     Middle
#
#               F6         F7 Decision Image
# 7547      Middle     Middle     Zero
# 10009  Very High  Very High     Zero
# 16973     Middle  Very High     Zero
# 5884      Middle     Middle     Zero
# 3236    Very Low   Very Low     Zero
# 13270   Very Low   Very Low     Zero
# 13215   Very Low   Very Low     Zero
# 9925    Very Low   Very Low      One
# 17265  Very High  Very High     Zero
# 13478     Middle     Middle     Zero
# 7834   Very High  Very High     Zero
# 13641  Very High  Very High     Zero
# 8343      Middle  Very High     Zero
# 4116      Middle   Very Low     Zero
# 8594      Middle   Very Low     Zero
# 17024        Low   Very Low     Zero
# 14494     Middle   Very Low     Zero
# 14346     Middle     Middle     Zero
# 9204   Very High       High     Zero
# 9354   Very High  Very High     Zero
# 10012        Low   Very Low      One
# 6413      Middle   Very Low     Zero
# 3398    Very Low   Very Low      One
# 9252         Low   Very Low     Zero
# 790       Middle   Very Low     Zero
# 16923     Middle     Middle     Zero
# 6760   Very High  Very High     Zero
# 1756   Very High  Very High     Zero
# 5428      Middle     Middle     Zero
# 13806   Very Low   Very Low     Zero
# ...          ...        ...      ...   ...
# 5577   Very High       High     Zero
# 10525     Middle   Very Low     Zero
# 4337      Middle     Middle     Zero
# 15768  Very High  Very High     Zero
# 5622    Very Low   Very Low      One
# 2867   Very High       High     Zero
# 14590  Very High  Very High     Zero
# 8046    Very Low   Very Low      One
# 15123     Middle     Middle     Zero
# 12119     Middle     Middle     Zero
# 3485      Middle     Middle     Zero
# 6276    Very Low   Very Low     Zero
# 15819     Middle   Very Low     Zero
# 1779      Middle   Very Low     Zero
# 14743     Middle   Very Low     Zero
# 8332      Middle     Middle     Zero
# 9823      Middle   Very Low     Zero
# 10434  Very High       High     Zero
# 12047     Middle     Middle     Zero
# 16280  Very High  Very High     Zero
# 13928  Very High  Very High     Zero
# 17506     Middle     Middle     Zero
# 8003    Very Low   Very Low     Zero
# 4328      Middle   Very Low     Zero
# 17533        Low   Very Low     Zero
# 9253         Low   Very Low     Zero
# 14484       High       High     Zero
# 15046     Middle   Very Low     Zero
# 15849     Middle     Middle     Zero
# 17193     Middle   Very Low     Zero
#
# [14318 rows x 10 columns]
# 161it [08:02,  2.99s/it]
# Finished!

# %% [markdown]
# ##### Brute Force

# %%
from Scripts.OptimizeBruteForce import OptimizeBruteForce as OptimizeBruteForce

optimizeBruteForce = OptimizeBruteForce(settings.variables, settings.constraints, settings.sigma_mean_params)
bruteforce_threshold = optimizeBruteForce.worker(settings.variables)
# Out:
# Global minimum: [0.40935938]
# Function value at global minimum: 0.03170833915351301
# Accuracy: 0.968291660846487
# Time: 2613.847734928131

# %% [markdown]
# ##### PSO

# %%
from Scripts.OptimizePSO import OptimizePSO as OptimizePSO

optimizePSO = OptimizePSO(settings.variables, settings.swarm_size, settings.dim, settings.epsilon, settings.iters, settings.options, settings.borders, settings.sigma_mean_params)
optimizePSO.worker(settings.variables)
# Out:
# 2019-03-29 02:26:44,410 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'c1': 0.5, 'w': 0.9, 'c2': 0.3}
# pyswarms.single.global_best: 100%|█████████████████████████████████████████████████████████████|20/20, best_cost=0.0318
# 2019-03-29 04:22:38,961 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.03177818131023891, best pos: [0.40961202]
# Global minimum: [0.40961202]
# Function value at global minimum: 0.03177818131023891
# Accuracy: 0.9682218186897611
# Time: 6954.564183950424
# array([0.40961202])

# %% [markdown]
# ##### Value Train without optimalization

# %%
from Scripts.ValueTrain import ValueTrain as ValueTrain
valueTrain = ValueTrain(settings.variables, threshold_value = -1)
valueTrain.worker(settings.variables)
# Out:
# Accuracy: 0.7797178376868278
# Precision: [0.28789986 0.99180328]
# Recall: [0.93806647 0.76358319]
# F-Score: [0.44058177 0.86285764]
# Support: [ 1324 12994]

# %% [markdown]
# ##### Value Train with optimalization

# %%
from Scripts.ValueTrain import ValueTrain as ValueTrain

valueTrain = ValueTrain(settings.variables, threshold_value = bruteforce_threshold)
valueTrain.worker(settings.variables)
# Out:
# Accuracy: 0.968291660846487
# Precision: [0.87116041 0.97695116]
# Recall: [0.77114804 0.98837925]
# F-Score: [0.81810897 0.98263198]
# Support: [ 1324 12994]

# %% [markdown]
# ##### Value Test without optimalization

# %%
from Scripts.ValueTest import ValueTest as ValueTest

valueTest = ValueTest(settings.variables, threshold_value = -1)
valueTest.worker(settings.variables)
# Out:
# Accuracy: 0.7782122905027933
# Precision: [0.27212179 0.98853302]
# Recall: [0.90793651 0.76569678]
# F-Score: [0.41874085 0.86296168]
# Support: [ 315 3265]

# %% [markdown]
# ##### Value Test with optimalization

# %%
from Scripts.ValueTest import ValueTest as ValueTest

valueTest = ValueTest(settings.variables, threshold_value = bruteforce_threshold)
valueTest.worker(settings.variables)
# Out:
# Accuracy: 0.9667597765363128
# Precision: [0.90495868 0.97124026]
# Recall: [0.6952381  0.99295559]
# F-Score: [0.78635548 0.98197789]
# Support: [ 315 3265]

# %% [markdown]
# ##### PSO K-Fold

# %%
from Scripts.OptimizePSOKFold import OptimizePSOKFold as OptimizePSOKFold

optimizePSOKFold = OptimizePSOKFold(settings.variables, settings.swarm_size, settings.dim, settings.epsilon, settings.iters, settings.options, settings.borders, settings.sigma_mean_params)
optimizePSOKFold.worker(settings.variables)
# Out:
# 2019-03-29 04:31:25,726 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'c1': 0.5, 'w': 0.9, 'c2': 0.3}
# pyswarms.single.global_best:  40%|████████████████████████▊                                     |8/20, best_cost=0.0317
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-692143693b29> in <module>()
#       2
#       3 optimizePSOKFold = OptimizePSOKFold(settings.variables, settings.swarm_size, settings.dim, settings.epsilon, settings.iters, settings.options, settings.borders, settings.sigma_mean_params)
# ----> 4 optimizePSOKFold.worker(settings.variables)
#
# ~\Documents\Studia\Magisterka\Projekt\Scripts\OptimizePSOKFold.py in worker(self, variables)
#      38             train_data = sorted_decision.iloc[train_index]
#      39             test_data = sorted_decision.iloc[test_index]
# ---> 40             cost, global_min = optimizer.optimize(self.optimizeFunctions.optFunc, iters=self.iters, sorted_decision = sorted_decision, variables = variables)
#      41             self.result_table = self.optimizeFunctions.setDecisions([global_min], test_data, variables)
#      42             test_accuracy = self.optimizeFunctions.getAccuracy(self.result_table)
#
# C:\Programy\Anaconda\envs\py35\lib\site-packages\pyswarms\single\global_best.py in optimize(self, objective_func, iters, fast, **kwargs)
#     181             # Compute cost for current position and personal best
#     182             # fmt: off
# --> 183             self.swarm.current_cost = objective_func(self.swarm.position, **kwargs)
#     184             self.swarm.pbest_pos, self.swarm.pbest_cost = compute_pbest(self.swarm)
#     185             # Set best_cost_yet_found for ftol
#
# ~\Documents\Studia\Magisterka\Projekt\Scripts\OptimizeFunctions.py in optFunc(self, x, sorted_decision, variables)
#      46     def optFunc(self, x, sorted_decision, variables):
#      47         n_particles = x.shape[0]
# ---> 48         j = [self.makeJob(x[i], sorted_decision, variables) for i in range(n_particles)]
#      49         return np.array(j)
#      50
#
# ~\Documents\Studia\Magisterka\Projekt\Scripts\OptimizeFunctions.py in <listcomp>(.0)
#      46     def optFunc(self, x, sorted_decision, variables):
#      47         n_particles = x.shape[0]
# ---> 48         j = [self.makeJob(x[i], sorted_decision, variables) for i in range(n_particles)]
#      49         return np.array(j)
#      50
#
# ~\Documents\Studia\Magisterka\Projekt\Scripts\OptimizeFunctions.py in makeJob(self, params, sorted_decision, variables)
#      39
#      40     def makeJob(self, params, sorted_decision, variables):
# ---> 41         result_table = self.setDecisions(params, sorted_decision, variables)
#      42         accuracy = self.getAccuracy(result_table)
#      43         accuracy_reverse = 1 - accuracy
#
# ~\Documents\Studia\Magisterka\Projekt\Scripts\OptimizeFunctions.py in setDecisions(self, params, sorted_decision, variables)
#      18                 decision_table.loc[index, 'Decision Fuzzy'] = variables['d_low']
#      19             elif decision_table.loc[index]['Predicted Value'] < params[0]:
# ---> 20                 decision_table.loc[index, 'Decision Fuzzy'] = variables['d_high']
#      21
#      22         return decision_table
#
# C:\Programy\Anaconda\envs\py35\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     187             key = com._apply_if_callable(key, self.obj)
#     188         indexer = self._get_setitem_indexer(key)
# --> 189         self._setitem_with_indexer(indexer, value)
#     190
#     191     def _validate_key(self, key, axis):
#
# C:\Programy\Anaconda\envs\py35\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#     613                 # scalar
#     614                 for item in labels:
# --> 615                     setter(item, value)
#     616
#     617         else:
#
# C:\Programy\Anaconda\envs\py35\lib\site-packages\pandas\core\indexing.py in setter(item, v)
#     536                     # set the item, possibly having a dtype change
#     537                     s._consolidate_inplace()
# --> 538                     s = s.copy()
#     539                     s._data = s._data.setitem(indexer=pi, value=v)
#     540                     s._maybe_update_cacher(clear=True)
#
# C:\Programy\Anaconda\envs\py35\lib\site-packages\pandas\core\generic.py in copy(self, deep)
#    5108         dtype: object
#    5109         """
# -> 5110         data = self._data.copy(deep=deep)
#    5111         return self._constructor(data).__finalize__(self)
#    5112
#
# C:\Programy\Anaconda\envs\py35\lib\site-packages\pandas\core\internals.py in copy(self, deep, mgr)
#    3918             new_axes = list(self.axes)
#    3919         return self.apply('copy', axes=new_axes, deep=deep,
# -> 3920                           do_integrity_check=False)
#    3921
#    3922     def as_array(self, transpose=False, items=None):
#
# C:\Programy\Anaconda\envs\py35\lib\site-packages\pandas\core\internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3579
#    3580             kwargs['mgr'] = self
# -> 3581             applied = getattr(b, f)(**kwargs)
#    3582             result_blocks = _extend_blocks(applied, result_blocks)
#    3583
#
# C:\Programy\Anaconda\envs\py35\lib\site-packages\pandas\core\internals.py in copy(self, deep, mgr)
#     776         values = self.values
#     777         if deep:
# --> 778             values = values.copy()
#     779         return self.make_block_same_class(values)
#     780
#
# KeyboardInterrupt:

# %% [markdown]
# ##### Brute Force K-Fold

# %%
from Scripts.OptimizeBruteForceKFold import OptimizeBruteForceKFold as OptimizeBruteForceKFold

optimizeBruteForceKFold = OptimizeBruteForceKFold(settings.variables, settings.constraints, settings.sigma_mean_params)
optimizeBruteForceKFold.worker(settings.variables)
