# %%
import settings as settings
from Scripts.OptimizePSO import OptimizePSO as OptimizePSO

# %%
optimizePSO = OptimizePSO(settings.variables, settings.swarm_size, settings.dim, settings.epsilon, settings.iters, settings.options, settings.borders, settings.sigma_mean_params)
optimizePSO.worker(settings.variables)
# Out:
# 2019-03-26 16:44:21,061 - pyswarms.single.global_best - INFO - Optimize for 20 iters with {'c2': 0.3, 'w': 0.9, 'c1': 0.5}
# pyswarms.single.global_best: 100%|███████████████████████████████████████████████████████████|20/20, best_cost=0.342
# 2019-03-26 16:47:13,452 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.3424908424908425, best pos: [0.07892687]
# Global minimum: [0.07892687]
# Function value at global minimum: 0.3424908424908425
# Accuracy: 0.6575091575091575
# Time: 172.41549849510193
